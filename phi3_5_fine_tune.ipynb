# %%
# !pip install transformers \
bitsandbytes \
sentencepiece \
transformers[sentencepiece] \
accelerate \
datasets \
trl \
seacrowd
# Out:
# Requirement already satisfied: transformers in /home/fachri/nusax/.conda/lib/python3.11/site-packages (4.47.0)
# Requirement already satisfied: bitsandbytes in /home/fachri/nusax/.conda/lib/python3.11/site-packages (0.45.0)
# Requirement already satisfied: sentencepiece in /home/fachri/nusax/.conda/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: accelerate in /home/fachri/nusax/.conda/lib/python3.11/site-packages (1.2.1)
# Requirement already satisfied: datasets in /home/fachri/nusax/.conda/lib/python3.11/site-packages (3.1.0)
# Requirement already satisfied: trl in /home/fachri/nusax/.conda/lib/python3.11/site-packages (0.12.1)
# Requirement already satisfied: seacrowd in /home/fachri/nusax/.conda/lib/python3.11/site-packages (0.2.2)
# Requirement already satisfied: filelock in /home/fachri/.local/lib/python3.11/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/fachri/.local/lib/python3.11/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /home/fachri/.local/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /home/fachri/.local/lib/python3.11/site-packages (from transformers) (4.67.0)
# Requirement already satisfied: torch in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from bitsandbytes) (2.5.1)
# Requirement already satisfied: typing_extensions>=4.8.0 in /home/fachri/.local/lib/python3.11/site-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: protobuf in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from transformers[sentencepiece]) (4.25.5)
# Requirement already satisfied: psutil in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from accelerate) (6.1.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from datasets) (18.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/fachri/.local/lib/python3.11/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from datasets) (3.10.10)
# Requirement already satisfied: rich in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from trl) (13.9.4)
# Requirement already satisfied: loguru>=0.5.3 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (0.7.2)
# Requirement already satisfied: bioc>=1.3.7 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (2.1)
# Requirement already satisfied: black~=22.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (22.12.0)
# Requirement already satisfied: flake8>=3.8.3 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (7.1.1)
# Requirement already satisfied: isort>=5.0.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (5.13.2)
# Requirement already satisfied: pre-commit>=2.19.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (4.0.1)
# Requirement already satisfied: jsonlines>=3.1.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (4.0.0)
# Requirement already satisfied: torchaudio>=0.11 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (2.5.1)
# Requirement already satisfied: soundfile in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (0.12.1)
# Requirement already satisfied: librosa in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (0.10.2.post1)
# Requirement already satisfied: nltk in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (3.9.1)
# Requirement already satisfied: zstandard in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (0.23.0)
# Requirement already satisfied: ffmpeg in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (1.4)
# Requirement already satisfied: conllu in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (6.0.0)
# Requirement already satisfied: openpyxl in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (3.1.5)
# Requirement already satisfied: translate-toolkit>=3.7.3 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from seacrowd) (3.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.17.1)
# Requirement already satisfied: lxml>=4.6.3 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from bioc>=1.3.7->seacrowd) (5.3.0)
# Requirement already satisfied: intervaltree in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from bioc>=1.3.7->seacrowd) (3.1.0)
# Requirement already satisfied: docopt in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from bioc>=1.3.7->seacrowd) (0.6.2)
# Requirement already satisfied: click>=8.0.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from black~=22.0->seacrowd) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from black~=22.0->seacrowd) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from black~=22.0->seacrowd) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /home/fachri/.local/lib/python3.11/site-packages (from black~=22.0->seacrowd) (4.3.6)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from flake8>=3.8.3->seacrowd) (0.7.0)
# Requirement already satisfied: pycodestyle<2.13.0,>=2.12.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from flake8>=3.8.3->seacrowd) (2.12.1)
# Requirement already satisfied: pyflakes<3.3.0,>=3.2.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from flake8>=3.8.3->seacrowd) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/fachri/.local/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/fachri/.local/lib/python3.11/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fachri/.local/lib/python3.11/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: cfgv>=2.0.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from pre-commit>=2.19.0->seacrowd) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from pre-commit>=2.19.0->seacrowd) (2.6.1)
# Requirement already satisfied: nodeenv>=0.11.1 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from pre-commit>=2.19.0->seacrowd) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from pre-commit>=2.19.0->seacrowd) (20.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fachri/.local/lib/python3.11/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: networkx in /home/fachri/.local/lib/python3.11/site-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /home/fachri/.local/lib/python3.11/site-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/fachri/.local/lib/python3.11/site-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/fachri/.local/lib/python3.11/site-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fachri/.local/lib/python3.11/site-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: wcwidth>=0.2.10 in /home/fachri/.local/lib/python3.11/site-packages (from translate-toolkit>=3.7.3->seacrowd) (0.2.13)
# Requirement already satisfied: audioread>=2.1.9 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from librosa->seacrowd) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /home/fachri/.local/lib/python3.11/site-packages (from librosa->seacrowd) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from librosa->seacrowd) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from librosa->seacrowd) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/fachri/.local/lib/python3.11/site-packages (from librosa->seacrowd) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from librosa->seacrowd) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from librosa->seacrowd) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from librosa->seacrowd) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from librosa->seacrowd) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from librosa->seacrowd) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from soundfile->seacrowd) (1.17.1)
# Requirement already satisfied: et-xmlfile in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from openpyxl->seacrowd) (2.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/fachri/.local/lib/python3.11/site-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: pycparser in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from cffi>=1.0->soundfile->seacrowd) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from numba>=0.51.0->librosa->seacrowd) (0.43.0)
# Requirement already satisfied: six>=1.5 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa->seacrowd) (3.5.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit>=2.19.0->seacrowd) (0.3.9)
# Requirement already satisfied: propcache>=0.2.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from intervaltree->bioc>=1.3.7->seacrowd) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fachri/.local/lib/python3.11/site-packages (from jinja2->torch->bitsandbytes) (3.0.2)

# %%
# !pip install -U peft
# Out:
# Requirement already satisfied: peft in /home/fachri/nusax/.conda/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.17 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/fachri/.local/lib/python3.11/site-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from peft) (6.1.0)
# Requirement already satisfied: pyyaml in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from peft) (2.5.1)
# Requirement already satisfied: transformers in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from peft) (4.47.0)
# Requirement already satisfied: tqdm in /home/fachri/.local/lib/python3.11/site-packages (from peft) (4.67.0)
# Requirement already satisfied: accelerate>=0.21.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from peft) (1.2.1)
# Requirement already satisfied: safetensors in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from peft) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.25.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from peft) (0.26.2)
# Requirement already satisfied: filelock in /home/fachri/.local/lib/python3.11/site-packages (from huggingface-hub>=0.25.0->peft) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from huggingface-hub>=0.25.0->peft) (2024.9.0)
# Requirement already satisfied: requests in /home/fachri/.local/lib/python3.11/site-packages (from huggingface-hub>=0.25.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/fachri/.local/lib/python3.11/site-packages (from huggingface-hub>=0.25.0->peft) (4.12.2)
# Requirement already satisfied: networkx in /home/fachri/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /home/fachri/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/fachri/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/fachri/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fachri/.local/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from transformers->peft) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from transformers->peft) (0.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fachri/.local/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fachri/.local/lib/python3.11/site-packages (from requests->huggingface-hub>=0.25.0->peft) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.25.0->peft) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.25.0->peft) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.25.0->peft) (2024.8.30)

# %%
import torch
import transformers
import argparse
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
from peft import (
        get_peft_model,
        prepare_model_for_kbit_training,
        LoraConfig
    )
from trl import SFTTrainer
# Out:
# 2024-12-16 05:18:18.258439: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-16 05:18:18.641681: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-16 05:18:18.641764: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-16 05:18:18.712203: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-16 05:18:18.850640: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-16 05:18:19.818353: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = load_dataset("SEACrowd/indo_general_mt_en_id", trust_remote_code=True)
data_train, data_test, data_val = data["train"], data["test"], data["validation"]
# Randomly select 10k indices
import random
random_indices = random.sample(range(len(data_train)), 10000)

# Select the 10k rows
data_train = data_train.select(random_indices)
print(data_train, data_test, data_val)

# example
data_train[0]
# Out:
# Dataset({
#     features: ['id', 'src', 'tgt'],
#     num_rows: 10000
# }) Dataset({
#     features: ['id', 'src', 'tgt'],
#     num_rows: 2000
# }) Dataset({
#     features: ['id', 'src', 'tgt'],
#     num_rows: 2000
# })
# {'id': '1341140',
#  'src': '"It was developed by Visual Concepts and published by 2K Sports, a subsidiary of Take-Two Interactive."',
#  'tgt': '"Civilization VI dikembangkan oleh Firaxis Games, diterbitkan oleh 2K Games, dan didistribusikan oleh Take-Two Interactive."'}

# %%
model_name = "microsoft/Phi-3.5-mini-instruct"
model = AutoModelForCausalLM.from_pretrained(model_name,
                                            load_in_8bit=True,
                                             torch_dtype=torch.float16,
                                            device_map="auto"
                                            )
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Define LoRA configuration
lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["qkv_proj", "o_proj"],  # Adjust based on your model architecture
    lora_dropout=0.1,
    bias="none",
    task_type="SEQ_2_SEQ_LM",
    # bnb_8bit=True  # Enable bitsandbytes 8-bit quantization
)

# %%
# this should be set for finutning and batched inference
tokenizer.add_special_tokens({"pad_token": "<PAD>"})
model.resize_token_embeddings(len(tokenizer))
model = prepare_model_for_kbit_training(model)
model = get_peft_model(model, lora_config)

# %%
from peft import PeftModel

peft_model_id = "checkpoint-620"
peft_model = PeftModel.from_pretrained(model, peft_model_id, torch_dtype=torch.float16, offload_folder="lora_results/lora_7/temp")
# Out:
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/peft/peft_model.py:599: UserWarning: Found missing adapter keys while loading the checkpoint: ['base_model.model.base_model.model.model.layers.0.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.0.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.0.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.0.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.1.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.1.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.1.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.1.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.2.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.2.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.2.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.2.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.3.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.3.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.3.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.3.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.4.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.4.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.4.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.4.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.5.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.5.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.5.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.5.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.6.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.6.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.6.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.6.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.7.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.7.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.7.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.7.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.8.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.8.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.8.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.8.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.9.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.9.self_attn.o_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.9.self_attn.qkv_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.9.self_attn.qkv_proj.lora_B.default.weight', 'base_model.model.base_model.model.model.layers.10.self_attn.o_proj.lora_A.default.weight', 'base_model.model.base_model.model.model.layers.10.self_attn.o_proj.lora_B.def ...
#   warnings.warn(f"Found missing adapter keys while loading the checkpoint: {missing_keys}")

# %%
def generate_prompt(dialogue, output=None, eos_token="</s>"):
  instruction = """
Translate the following sentences from English to Indonesian:

English: I am going to the market. What do you want to buy?.
Indonesian: Saya akan pergi ke pasar. Apa yang ingin kamu beli?.

English: """
  input = f"{dialogue}\n"
  output = f"""Indonesian:
#answer: 
{output + ' ' + eos_token if output else ''} """
  prompt = (" ").join([instruction, input, output])
  return prompt

# %%
input_prompt = generate_prompt(data_test[37]["src"])
input_tokens = tokenizer(input_prompt, return_tensors="pt")["input_ids"].to("cuda")
with torch.amp.autocast('cuda'):
    generation_output = peft_model.generate(
        input_ids=input_tokens,
        max_new_tokens=100,
        do_sample=True,
        top_k=10,
        top_p=0.9,
        temperature=0.3,
        repetition_penalty=1.15,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
    )
output_text = tokenizer.decode(generation_output[0], skip_special_tokens=True)
translated_text = ""
if "#answer" in output_text:
    # Split by lines and find the text after '#answer'
    lines = output_text.split("\n")
    try:
        index = next((i for i, line in enumerate(lines) if line.startswith("#answer")), -1) +1# Get the line after '#answer'
        translated_text = lines[index].strip()  # Clean up any extra spaces
        translated_text = translated_text.replace("Indonesian:", "").strip()
    except IndexError:
        translated_text = "Translation not found."
else:
    translated_text = "No '#answer' marker in output."
print(output_text)
print(translated_text)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Translate the following sentences from English to Indonesian:
#
# English: I am going to the market. What do you want to buy?.
# Indonesian: Saya akan pergi ke pasar. Apa yang ingin kamu beli?.
#
# English:  Now a damane.
#  Indonesian:
# #answer:
#   Sekarang ada daerahan.
# Sekarang ada daerahan.

# %%
import torch
import csv
import numpy as np
import os
from nltk.translate.bleu_score import sentence_bleu
# Check if CUDA (GPU) is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# List to store translations
translations = []
bleu_scores = []
# Process each sentence in the test dataset
start = 229
for key, (input_text, output_text_real) in enumerate(zip(data_test['src'][start:], data_test['tgt'][start:]), start=229):    # Create the prompt for the current sentence
    
    # Tokenize the prompt
    inputs = tokenizer(generate_prompt(input_text), return_tensors="pt").to("cuda")

    # Generate the translation
    # generate_ids = model.generate(inputs['input_ids'], max_length=500)
    # with torch.amp.autocast('cuda'):
    #     generation_output = peft_model.generate(
    #         input_ids=inputs,
    #         max_new_tokens=300,
    #         do_sample=True,
    #         top_k=10,
    #         top_p=0.9,
    #         temperature=0.3,
    #         repetition_penalty=1.15,
    #         num_return_sequences=1,
    #         eos_token_id=tokenizer.eos_token_id,
    #     )
    with torch.no_grad():
        with torch.amp.autocast(device_type="cuda", dtype=torch.float16):
            generation_output = peft_model.generate(
                input_ids=inputs["input_ids"],
                attention_mask=inputs["attention_mask"],
                max_new_tokens=150,  # Shortened for efficiency
                do_sample=True,
                top_k=50,
                top_p=0.95,
                temperature=0.8,
                repetition_penalty=1.15,
                num_return_sequences=1,
                eos_token_id=tokenizer.eos_token_id,
            )
    
    # Decode the output and extract the translation
    output_text = tokenizer.decode(generation_output[0], skip_special_tokens=True)
    
    # Extract the sentence one line below `#answer`
    translated_text = ""
    if "#answer" in output_text:
        # Split by lines and find the text after '#answer'
        lines = output_text.split("\n")
        try:
            # index = lines.index("#answer") + 1  # Get the line after '#answer'
            index = next((i for i, line in enumerate(lines) if line.startswith("#answer")), -1) +1
            translated_text = lines[index].strip()  # Clean up any extra spaces
            translated_text = translated_text.replace("Indonesian:", "").strip()
        except IndexError:
            translated_text = "Translation not found."
    else:
        translated_text = "No '#answer' marker in output."
    # Calculate BLEU score for this sentence
    bleu_score = sentence_bleu([output_text_real], translated_text)
    with open('predictions_phi35_finetune_one_shot_test.csv', mode='a', newline='') as file:
        if not os.path.exists('predictions_phi35_finetune_one_shot_test.csv'):
            writer.writerow(['Index', 'Input', 'Predicted Output', 'Correct Output', 'BLEU Score'])
        writer = csv.writer(file)
        writer.writerow([key + 1, input_text, translated_text, output_text_real, bleu_score])
    # Print the results
    print(f"Key: {key}")
    print(f"Input: {input_text}")
    print(f"Predicted: {translated_text}")
    print(f"Reference: {output_text_real}")
    print(f"BLEU Score: {bleu_score:.4f}")
    print("-" * 50)
    bleu_scores.append(bleu_score)
print(np.mean(bleu_scores))
# Out:
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Key: 229
# Input: He also ordained Richard Whatcoat and Thomas Vasey as presbyters.
# Predicted: Dia juga memperintah Richard Whatcote dan Thomasasuspresbiterannya.
# Reference: Ia juga menahbiskan Richard Whatcoat dan Thomas Vasey sebagai presbiter.
# BLEU Score: 0.5884
# --------------------------------------------------
# Key: 230
# Input: "On the way back to Thessaly, Medea prophesied that Euphemus, the helmsman of Jason's ship, the Argo, would one day rule over all Libya."
# Predicted: Belum diindikasikan dalam benda-benda kembali Ke Tesiselan, Medea coba tercipta prekaryanya bahwa Eufemeiah, pil dan kapitan laut Pergubun jari Janyasa Prambawa sampai tinggal menjabat osewasi setiap Kabupaten Lifuri pada masa edfesi akhirnya dulu ya?
# Reference: "Dalam perjalananya, Medeia meramalkan bahwa Eufemos, jurumudi kapal Argo, suatu hari akan berkuasa di Libya."
# BLEU Score: 0.2016
# --------------------------------------------------
# Key: 231
# Input: "In 2014, the attendance is 4,000 persons."
# Predicted: Belum dalam tahun 2014, kelasan sampai dengan sekali orang 4.000 warga.
# Reference: "Pada 2012, eparki tersebut memiliki 4.000 anggota."
# BLEU Score: 0.2007
# --------------------------------------------------
# Key: 232
# Input: A coronary angiography is performed only after a stress test or ECG shows a sign of coronary ischemia or CAD.
# Predicted: Percobaan kardiovaskuler (PC) atau teledaerasi sering muncul sebagai acuan terlebih dahulu untuk melakukan koronarkesi jantung di bawah stres saatnya, menandakan gejala sirkulatif pendaratan dan/atau Kecuriga Pengganda Jalara Alir.(Kardio-Angioskopik dilaksikan karena tes periode akut dalam suatu situasionalisme alami).
# Reference: Angiography koroner dilakukan setelah stress test atau EKG memperlihatkan tanda-tanda dari iskemia koroner atau penyakit arteri koroner.
# BLEU Score: 0.2127
# --------------------------------------------------
# Key: 233
# Input: Blessed is He that cometh in the name of the Lord.
# Predicted: Injillah setiap orang yang datang dalam nama Raja Tuhan/Bir Rakah (Assalatu Alayhimillahi Wajibul Aslim).
# Reference: Ngesti artinya upaya batiniah yang didasari dengan permohonan kepada Tuhan Yang Maha Esa.
# BLEU Score: 0.2177
# --------------------------------------------------
# Key: 234
# Input: "For reasons of orbital stability, such multi-star systems are often organized into hierarchical sets of binary stars."
# Predicted: Perilaku stabil lingkaran sehingga sistem bintang lebih dari satu biasanya diorganisir menjadi rangka set listrik binaris mengikuti aturannya khususnya.
# Reference: Sistem multibintang yang demikian seringkali secara hierarkis tersusun dari beberapa bintang biner untuk mempertahankan stabilitas orbit bintang-bintangnya.
# BLEU Score: 0.3624
# --------------------------------------------------
# Key: 235
# Input: "A rule for Catholics who are members of the Latin Church is: ""A person who is to receive the Most Holy Eucharist is to abstain for at least one hour before holy communion from any food and drink, except for only water and medicine."""
# Predicted: Perlakuan untuk katolik-katolis tempat memiliki Latinitas Kristen adalah seperti ini: “Seorang seseorang diyakini melaksanakan Tertua Holaka hingga enam jam setelahnya saat makannya dan minum air tanpa unduh kecuali benda vandular serta obatan.”
# Reference: "Salah satu aturan bagi umat Katolik yang menjadi anggota Gereja Latin menyebutkan: ""Seseorang yang akan menerima Ekaristi Mahakudus harus berpantang dari segala macam makanan dan minuman, kecuali air semata dan obat-obatan, sekurang-kurangnya satu jam sebelum komuni kudus."""
# BLEU Score: 0.3989
# --------------------------------------------------
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Key: 236
# Input: """Theme park plan still on, timing unclear: GEN Malaysia""."
# Predicted: Pengaturan taman hiburan masih berjalannya, waktunya ketidakklarifikasional dalam RAN MALAYSIHA.:
# Reference: """Venue Menembak Asian Para Games Belum Beres, Adaptasi Indonesia Minim"". detiksport."
# BLEU Score: 0.0000
# --------------------------------------------------
# Key: 237
# Input: Rows in blue are not present in ISO 3166-2.
# Predicted: Rowan unggul di biru tidak ada dalam ISOTO3166-2.
# Reference: Kode-kode ini tidak terdaftar dalam ISO 3166-2.
# BLEU Score: 0.4547
# --------------------------------------------------
# Key: 238
# Input: "Three days after the announcement, Indian National Congress president Sonia Gandhi called Science & Technology minister Kapil Sibal to express her concern about Sibal's 30 December public warning being ""hogwash""."
# Predicted: India Raja Bintang Sarjana (Sebelum) - Perdana Menteripnanti Teknik dan Pengetahuan Telatan Indon Sergio Kandhalib diberitakan dua hari seteret dikerjakannya melawan pemutuh kegiatankamunnyih mengatakatlah sebuyanya berboikot terhadap warna-warni Nikmat Waktur Terakhir Suroju Januarsendulika dengan menjelaskarkan dirimorlan adalah bocok tadi ("babuk").
# Reference: "Tiga hari setelah pengumuman tersebut, Presiden Kongres Nasional India Sonia Gandhi memanggil Menteri Sains dan Teknologi Kapil Sibal untuk memberitahu bahwa peringatan masyarakat Sibal tanggal 30 Desember adalah omong kosong (hogwash)."
# BLEU Score: 0.2833
# --------------------------------------------------
# Key: 239
# Input: "Flowers fall off the ageing spikes, which swell and develop follicles containing up to two viable seeds each."
# Predicted: Flower berkurung dari kantong tua diiringan berbunyi dan tumbuh tanah gula dengan bulos dalam mengandung sampai dua bijil vaha sendiri.
# Reference: "Bunga jatuh dari bulir yang menua, yang membengkak dan berkembang menjadi folikel berisi hingga dua biji hidup."
# BLEU Score: 0.3308
# --------------------------------------------------
# Key: 240
# Input: "The district is funded by a combination of local earned income tax, local real property tax, real estate transfer tax, and per capita tax, coupled with substantial funding from the Commonwealth of Pennsylvania and the federal government."
# Predicted: Kecamatan dijamin dengan kombinasi pendapatan melalui aduan warisan sementara (mata uang alat), atau penjualan tanah bulat inklusif terutama tukad dan tariff transaksi medeniyet substansial diikuti sumbursanya oleh Pemerintaha Pennsylvania serta kesehatan Federalitas Amerika Serika.
# Reference: "Tingkat pendapatan suatu daerah dapat diukur antara lain dari pendapatan per kapita, penerimaan Pajak Bumi dan Bangunan (PBB), Pendapatan Asli Daerah (PAD) serta gambaraan kualitatif tentang keadaan sandang, pangan dan perumahan masyarakat."
# BLEU Score: 0.3348
# --------------------------------------------------
# Key: 241
# Input: "In the same time period, new technological systems were introduced, most significantly electrical power and telephones."
# Predicted: Perlahan-palung periode waktu samaan diikuti penyampaikan sistem teknologis baru sekaligus, paling signifikan listrik dan telefonon..
# Reference: "Dalam periode waktu yang sama, sistem teknologi baru diperkenalkan, yang paling signifikan adalah listrik dan telepon."
# BLEU Score: 0.6318
# --------------------------------------------------
# Key: 242
# Input: "According to a 2014 BBC World Service Poll, 75% of Pakistanis view China's influence positively with only 15% expressing a negative view."
# Predicted: Perhitungan dari Pengujung-Ujung Tahun 2014 oleh Web Media Global BBW SDP menyatakan bahwa sekitar 75 % Pasifikansa melihat pendapatnya Cina termasuk negatif dengan sedikit lebih kecil lagi tanpa satu persenya terhadap tujuannya dibawaha atau salah bayaran - hanya kursi beberapa percent adalah dua puluh enam %.
# Reference: "Menurut Jajak Pendapat BBC World Service pada tahun 2014, 75% warga Pakistan melihat pengaruh Tiongkok secara positif dengan hanya 15% yang mengekspresikan pandangan negatif."
# BLEU Score: 0.2754
# --------------------------------------------------
# Key: 243
# Input: This probably has something to do with his detention of the couple.
# Predicted: Ini mungkin kepada situasi penahan suami-perempuan mereka sebelumnya.
# Reference: Hal ini diyakini bisa mendatangkan kesialan bagi pasangan tersebut.
# BLEU Score: 0.1612
# --------------------------------------------------
# Key: 244
# Input: "Backed by Brandenburg and Austria, internal enemies of Sobieski even planned to dethrone him and elect Charles of Lorraine."
# Predicted: İngilizce : Daha fazlasında Brandenburğun ve Avustan üzerine sürücün kötülük planlarken sobişli'nin kaldırmasına veya Chary Louise-Bosnas içinde sevgisini atmak istedi.
# Reference: "Dengan dukungan Brandenburg dan Monarki Habsburg, para seteru Yohanes di dalam negeri bahkan berencana untuk memakzulkannya dan memilih Karl dari Lothringen sebagai raja pengganti."
# BLEU Score: 0.1879
# --------------------------------------------------
# Key: 245
# Input: "As a result, the extended session of parliament would only have to deal with C-38."
# Predicted: Bahan hasilnya menyebabkan sessi spekta parlamenter terlalu penuh hanya memperlakukan standaris Kode - 1972 (Codifikasi).
# Reference: "Sampai saat ini, aktivitas industri hanya terpusat di Jl."
# BLEU Score: 0.1219
# --------------------------------------------------
# Key: 246
# Input: "With water it forms the trihydrate, Pb(CH3COO)2·3H2O, a colourless or white efflorescent monoclinic crystalline substance."
# Predicted: به การเคลื่อนไหวของน้ำจะสร้าง Triohidrat, L-Pn (C5 H7 NO4), Sedunia cukup sedimenter lebat kemerahan atau putih dengan struktur batu keriting melingkupikrom Monoklinkes।
# Reference: "Jika bereaksi dengan air, senyawa ini akan membentuk trihidrat Pb(CH3COO)2·3H2O, yaitu senyawa kristalin monoklinik berkilauan yang tidak berwarna atau berwarna putih."
# BLEU Score: 0.2784
# --------------------------------------------------
# Key: 247
# Input: "His formal deposition did not take instrument until 12 February 1689, by a declaration of the convention of old parliamentarians at Westminster (see ""Glorious Revolution""), which backdated the ""abdication"" to 11 December."
# Predicted: Perdeponsiif suara dia tidak diperoleh insentrik hingga tanggal 12 Februari 1689 oleh ketuntasan konvension dini parlamentius dalam Old Parliament London ("Revolusion Gresful") menuliskal pengharapan abdikasi sekitar dengan datum pagadilmu tersebut tadi-tani delatar Tanggal 11 Desember .
# Reference: "Penyingkirannya secara resmi tidak berlaku sampai tanggal 12 Februari 1689, berdasarkan deklarasi dari konvensi parliamentarian sebelumnya di Westminster (lihat ""Glorious Revolution""), yang diberi tanggal mundur ke ""abdication"" (pelepasan tahta) tanggal 11 Desember."
# BLEU Score: 0.4613
# --------------------------------------------------
# Key: 248
# Input: "Yongsan Electronics Market is a retail area in Seoul, South Korea."
# Predicted: Yongsan Elektronik Pasar adalah daerah berperpustakaan di Seul Selatan Timur Kita (Korea Utara).
# Reference: "Pasar Elektronik Yongsan (용산전자상가) adalah sebuah pusat perbelanjaan barang-barang elektronik di Yongsan-gu, Seoul, Korea Selatan."
# BLEU Score: 0.3963
# --------------------------------------------------
# Key: 249
# Input: "In the United States, many vodkas are made from 95% pure grain alcohol produced in large quantities by agricultural-industrial giants Archer Daniels Midland, Grain Processing Corporation, and Midwest Grain Products (MGP)."
# Predicted: Amerika Serikat banyak minuman kerosiny dari alkohol tiga emas tersebut diproduksikan oleh gigant industri petrokimia lautan agraria seperti ADM , Penghasil Gresek Konsumen dan MIPG .
# Reference: "Di Amerika Serikat, banyak vodlka dibuat dari etanol 95% yang diproduksi dalam jumlah besar oleh industri agrikultur besar."
# BLEU Score: 0.3623
# --------------------------------------------------
# Key: 250
# Input: "In the season two episode ""Fractured"", a version of Bat-Mite is introduced who claims to be Robin's ""DNA buddy"" (genetic twin)."
# Predicted: ภารกิจที่แสดงในเชื้อปัจจุบันของ Season 2, Episode "Fractured," Jason Fraser unveils versio batmitaibis gendengkritik kongenialan ("genetisk tandem") di mana ungkapna adalah Buddi DNA dari Robynnya.
# Reference: "Di musim dua episode ""Fractured"", versi Bat-Mite diperkenalkan yang mengklaim sebagai ""DNA buddy"" Robin (kembar genetik)."
# BLEU Score: 0.2579
# --------------------------------------------------
# Key: 251
# Input: "The opposite of ""heavy"" is ""light""."
# Predicted: Indonésia: Oppositif dari “berat” adalah “lembab”.
# Reference: "Lawan kata ""berat"" adalah ""ringan""."
# BLEU Score: 0.2394
# --------------------------------------------------
# Key: 252
# Input: "Strangely, this pillar of British colonialism was the father of the Irish revolutionary Lord Edward FitzGerald."
# Predicted: Ingatnya seorang pilar kolonialisme Britanya merupakan ayah revolusionaris Ireland terhanyal bertentang kepada lord Edwinisia Fitgeraldina.
# Reference: "Anehnya, pendukung kolonialisme Britania ini adalah ayah dari revolusionaris Irlandia Lord Edward FitzGerald."
# BLEU Score: 0.4757
# --------------------------------------------------
# Key: 253
# Input: "The use of aircraft in the close air support of ground forces dates back to World War I, the first significant use of aerial units in warfare."
# Predicted: ​"Penggunaan pesawat di bantuan penerbang tangkapan dekat terhadap swadia kepala dulu menjadi abad Kesatuani Perang Dunia dengan pertambahnya rangsanya kombinasikan untuk tujuan kontrasidetik dalam benteng lain-lain".
# Reference: "Sejarah penggunaan pertahanan udara secara luas dimulai sejak Perang Dunia I, saat pesawat tempur pertama kali digunakan."
# BLEU Score: 0.2845
# --------------------------------------------------
# Key: 254
# Input: Judit Polgár (born 23 July 1976) is a Hungarian chess grandmaster.
# Predicted: Judi Pólgar(lajutan tanggal 23 Juli 1976 ) adalah bintang gerak ajeng honggoe atlet tic takluk .
# Reference: Judit Polgár (lahir 23 Juli 1976) adalah seorang grandmaster catur Hongaria.
# BLEU Score: 0.3549
# --------------------------------------------------
# Key: 255
# Input: "Cora is clearly unstable and throughout the scene, she speaks to Norwood as if he were alive and in the room with her."
# Predicted: Indonésia : Cora tampak kesetaraan dan selama gerbiknya bicarap berlangsung dengan Orwold seperti adalah hidupiah di ruangannya juga sisa-saing-.
# Reference: "Samantha sering mengunjungi kenalannya di kota, jadi kamu akan sering melihatnya di penginapan, dan tempat lain ketika dia tidak di rumah."
# BLEU Score: 0.2834
# --------------------------------------------------
# Key: 256
# Input: Public discussion about the revolution was suppressed in Hungary for more than 30 years.
# Predicted: Bahasa Melayalam : Percakapan Umum tentang revolusi diunggu telah damping-dining selama lebih delaporkan lima puluh tahun dalam Hungrisia.
# Reference: Pembahasan mengenai revolusi ini dilarang di Hongaria selama lebih dari 30 tahun.
# BLEU Score: 0.3257
# --------------------------------------------------
# Key: 257
# Input: Some have described Toth as a compulsive liar.
# Predicted: Beberapa telah mengungkapkannya sebagai orang-orang lahir kasih kalaupunnya (compulsif penyalur semua)."
# Reference: Purana lainnya menyebutkan bahwa Mertyu adalah tokoh yang bersifat jahat.
# BLEU Score: 0.1983
# --------------------------------------------------
# Key: 258
# Input: Kang Min-hyuk as Kwak Hyun Son of a famous well known surgeon.
# Predicted: Khang Mingxi ujar, ibunya adalah Dr. Joo Hyeon Song dari dokter banyak terkenal dan dipercaya sambil tersembuhnya setiap orang dengan siaga serta ilmiah melayani saya kini..
# Reference: Kang Min-hyuk sebagai Kwak Hyun Anak seorang dokter terkenal.
# BLEU Score: 0.1939
# --------------------------------------------------
# Key: 259
# Input: Clarke and mr.
# Predicted: Clark dan seorang guru/Mr./Siritong (Jika memerlukan nama spesifik, unggul pikirkannya)
# Reference: Klerks dan Zr.
# BLEU Score: 0.0554
# --------------------------------------------------
# Key: 260
# Input: "Jinnah stated, ""If I live to see the ideal of a Muslim state being achieved in India, and I was then offered to make a choice between the works of Iqbal and the rulership of the Muslim state, I would prefer the former."""
# Predicted: Jinnah menyebutlah,""Kalau saya hidup sampai melihat idealisme Nusantara muslim di dunia Indie dan kalau kemudian dipilih oleh karakter-karaketer seperti iqbali atau pendudukan negeri Islam itu, saya lebih suka hal pertama.””
# Reference: "Ia berkata: ""Jika Aku hidup untuk melihat gagasan sebuah negara Muslim yang diraih di India, dan Aku kemudian ditawarkan untuk membuat sebuah pilihan antara karya-karya Iqbal dan pemerintahan negara Muslim, Aku akan memilih pilihan pertama."""
# BLEU Score: 0.4090
# --------------------------------------------------
# Key: 261
# Input: "Nasution escaped the attempt, but in the event, his daughter Ade Irma Suryani Nasution and the First Lieutenant Pierre Tendean was murdered."
# Predicted: Indonésia : Nasaun meludah penggalaksiannya tetapi dalam situasi itulah Anggota Bua dari nasuk Dan Lelat Pertama Peter Tanendren terima kematian .
# Reference: "Dalam peristiwa tersebut, putri kedua dia, Ade Irma Suryani Nasution dan ajudannya, Kapten Anumerta Pierre Andreas Tendean gugur."
# BLEU Score: 0.2646
# --------------------------------------------------
# Key: 262
# Input: He died at the age of 79 of a heart attack.
# Predicted: Dia matalanya sebanyak-batilah tujuh puluh sembilan saat kecelaka jantungnya..
# Reference: Ia meninggal dunia pada usia 73 tahun akibat serangan jantung.
# BLEU Score: 0.2174
# --------------------------------------------------
# Key: 263
# Input: It is one of the best-preserved monuments of this type in south east England.
# Predicted: Çita salah satu monument tercinta dengan kekhasan paling diperhatikan, berkembangnya situs semester selatan Inggris.."
# Reference: Istana tersebut merupakan salah satu dari bangunan bersejarah yang terpelihara baik di Inggris bagian tenggara.
# BLEU Score: 0.3598
# --------------------------------------------------
# Key: 264
# Input: "The word 'Antichrist' is translated from the combination of two ancient Greek words αντί + χριστος ('anti + khristos), which can mean anti ""opposite"" (of) khristos ""anointed"" therefore ""opposite of Christ"" (the meaning of christ as the 'anointed one', having become secondary to its meaning as the honorific of Jesus of Nazareth) or anti ""as"" (if) khristos ""messiah"" thus ""in place of Christ"" or a substitute for Christ."
# Predicted: Bahasa indonesia : Penggunaan kombinasi dua angka salah satu dalam frase ''antikris'' dari benda-benda latinis seperti latim antí plus chrīstus ("antidi" dan krētós). Bisa artikan meani adalah diyat sempitkala grieks merupakan oppsi kirilista Kristus, jadi kontra Kirillitas atau tempat terdekatan Cristo serta substitusioni oleh Crisot inkluzive takrifnya karena dimana kerjasama Kronologias dengan Karakter Jeroesi nazaret berart
# Reference: "Dimana kata tersebut terdiri dari dua akar kata αντί + Χριστός (anti + Kristos). ""αντί"" (anti) berarti mengganti, melawan atau mengambil tempat orang lain, dan ""Χριστός"" (Kristos) berarti Kristus, yang dalam bahasa Yunani sama dengan ""Mesias"" yang berarti ""yang diurapi"", dan mengacu kepada Yesus dari Nazaret dalam teologi Kristen."
# BLEU Score: 0.3515
# --------------------------------------------------
# Key: 265
# Input: Before the start of the 2013 season Romanovs joined Indonesian Premier League newcomers Pro Duta.
# Predicted: Sebelum dimulai musim tahunan 2013, Romanovs ikut menyetir pemain bareng nasional IPL muda dari PDUTA.
# Reference: Sebelum awal musim 2013 Romanov bergabung dengan pendatang baru Indonesia Premier League Pro Duta.
# BLEU Score: 0.3697
# --------------------------------------------------
# Key: 266
# Input: The Walt Disney Company France also produces content as well with other media companies.
# Predicted: Pabrik Karya Hiburan Dunia Wilis jugna menghasil konten serupa dengan bersama-sama medeayor lainnya di Francia.
# Reference: Walt Disney Productions juga memasuki bidang-bidang hiburan yang lain.
# BLEU Score: 0.2019
# --------------------------------------------------
# Key: 267
# Input: "Unlike its twin, Hotel Arts, this tower is a mixed use tower."
# Predicted: ,"Sama seperti kawan dibesabenya atau hotel arts ini torre itulah berdasarkan pengguna kombinasi-kombinat".
# Reference: "Tidak seperti kembarannya, Hotel Arts Barcelona, menara ini merupakan menara campuran."
# BLEU Score: 0.2773
# --------------------------------------------------
# Key: 268
# Input: Multiplayer games usually require players to share the resources of a single game system or use networking technology to play together over a greater distance.
# Predicted: Permainan multiplayern biasanya memerlukandakapasitasisirpelayudengalokaberdarioperaseksystem singa tahun atau menggunakanneteknologipersaturlasaibentuharsama jumlah lebih dikelola jarak panjang maksimumnya .
# Reference: Permainan pemain jamak biasanya menggunakan teknologi jaringan internet untuk bisa bermain bersama antar jarak yang jauh.
# BLEU Score: 0.3414
# --------------------------------------------------
# Key: 269
# Input: "Yule notes that the 1st-century AD Periplus mentioned that people of Thinae (Sinae) were rarely seen, because of the difficulties of reaching that country."
# Predicted: Penghats Yula mengatakan bahwa Notal pada abad pertama sila menyebut seorang pelaku dari Tinadean rasa jarang dijumpas karena kesulitan untuk bisa tercapainya negara itu.
# Reference: "Namun, Yule menyatakan bahwa Periplus dari abad ke-1 menyebutkan bahwa orang dari Thinae (Sinae) terlihat pada kesempatan langkah, pada catatan tentang kesulitan mencapai negara tersebut."
# BLEU Score: 0.4697
# --------------------------------------------------
# Key: 270
# Input: "Alberto Gonçalves da Costa (born 31 December 1980), commonly known as Beto Gonçalves, is a Brazilian-born Indonesian footballer who currently plays for Liga 1 club Persija Jakarta, on loan from Madura United as a striker."
# Predicted: Alberto Gonzâlvez Da Costa ((laun tanggal 31 Desember 1980)) biasanya dikenal sebagai Beta Gonsálves adalah futsal terbakat Brasil - oranya jenis atas Pasuk liga kabupaten Jawa Timur bernama persijadi jakarta serta memain di lewat lendir limajut Seres dan menjatuh pisiknya .
# Reference: "Alberto Gonçalves da Costa atau yang biasa dikenal sebagai Beto (lahir di Brasil, 31 Desember 1980; umur 38 tahun) adalah seorang pemain sepak bola Indonesia kelahiran Brasil yang berposisi sebagai penyerang dan saat ini ia bermain untuk klub Persija di Liga 1."
# BLEU Score: 0.4786
# --------------------------------------------------
# Key: 271
# Input: "During a 1670 trip to France, Pallu obtained from Louis XIV a letter to King Narai, which, together with a letter from the Pope, he remitted in Ayutthaya in October 1673 and which was received with great reverence."
# Predicted: ​Englandan pada sejumlah kartu persetujuan memasuki Francia di tahun 1670 Bapak Paluduk mendapat surat dari Raja Luwawati Ludwig XVI untuk Keraja Negara Narrha, itulah serta lapor dari Papa dengannya menurunkan saya bulan Oktober Tembilikayor dalam awal anggaran tersebut dicintai sangat hormone .
# Reference: "Selama perjalanan 1670 ke Prancis, Pallu memperoleh surat dari Louis XIV kepada Raja Narai, yang pada saat yang sama membawa sebuah surat dari Paus, dan dikirim ke Ayutthaya pada bulan Oktober 1673, lalu diterima dengan sangat hormat."
# BLEU Score: 0.4259
# --------------------------------------------------
# Key: 272
# Input: "After some hesitation, Wajda cautiously accepted this promotion."
# Predicted: Indonésia : Setelah kesadaran sedikitnya, Wajda akuntalis mengantuk dengan hati secara bertanggung jawab melaksanakannya promosi ini .
# Reference: Dengan berat hati akhirnya Goujian menerima hukuman itu.
# BLEU Score: 0.1670
# --------------------------------------------------
# Key: 273
# Input: Xuanzang or Xuan Zang is a 2016 Chinese-Indian historical adventure film based on Xuanzang's seventeen-year overland journey to India during the Tang dynasty in the seventh century.
# Predicted: ภาษาฝรั่งเศสของไลน์ : "Xuanzang,หรือ Xuan Zhangคือแนวประยุกต์ชีวิดทาโพธิคณิตจากบรูปมี 738 -  95年 xuánzàng dùnluòduì gōntú wèishēqīdiǎnlǜ zhé diànhuá qūděiyíndājié kûnpínwénchíjǐlüè fǔrènkēixìnyún
# Reference: Xuanzang atau Xuan Zang adalah sebuah film petualangan sejarah Tiongkok-India 2016 yang berdasarkan pada perjalanan darat tujuh belas tahun Xuanzang ke India pada zaman dinasti Tang pada abad ketujuh.
# BLEU Score: 0.1168
# --------------------------------------------------
# Key: 274
# Input: It also had an elaborate system of commentary in marginal glosses.
# Predicted: İngilizce "It also had an elaborate system of commentary in marginal glosses." de Türkçeye birlikte metni nasıl ifade edilebiliyor olabilir?
# Reference: Juga memiliki sistem komentar rumit di marjinal glosses.
# BLEU Score: 0.2070
# --------------------------------------------------
# Key: 275
# Input: "C. gachua is native to freshwater habitats in southern Asia, where it has a wide distribution from Iraq to Indonesia."
# Predicted: C. Gauchus asal air lingkungan segara danikasi di bumi Selasa Utara, dimana mereka memiliki pereksposisi berlain-lawinya dari Kepulauhan Iransyen hingga Nusantara (Indoneksia).
# Reference: "Istilah taucang digunakan oleh Tionghoa perantauan dari kelompok Hokkien yang banyak berimigrasi di Asia Tenggara, termasuk Indonesia dalam periode Qing."
# BLEU Score: 0.2938
# --------------------------------------------------
# Key: 276
# Input: She is best friend with Ting.
# Predicted: Dia adalah teman terdekat dengan Tiŋ.
# Reference: Dia adalah teman baik dari Io.
# BLEU Score: 0.4919
# --------------------------------------------------
# Key: 277
# Input: "Formed in May 2015, M.A.S 0094 were an independent group who performed and covered well-known songs in public with all profits going to charity for comfort women victims."
# Predicted: "Dinas Formasi diselenggarakan pada Mei 2015, Grup LSM -o NPM MDN APBP3/MDKAPC (Mahasiswa Alumnus Sarjana dalam Matematika dan Komputer) atau biasanya diikutuk dengan alasalama ‘MSMM’ berkisir dari Kota Bandung adatkandai mereka menyambunya terdesentralisa sesinggara tadi kembali melibur hulpindera untig warga komunitere orde barua Pancasila serta bebas mendapatnya manfaatan
# Reference: "Dibentuk pada Mei 2015, M.A.S 0094 merupakan grup independen yang tampil dan mengcover lagu populer di publik dengan semua keuntungan akan diamalkan untuk korban Ianfu."
# BLEU Score: 0.2011
# --------------------------------------------------
# Key: 278
# Input: Raney nickel is used in organic synthesis for desulfurization.
# Predicted: Ranyal nikkel digunakan dalam sintesi organik untuk sulfatasi berkisah..
# Reference: Kegunaan utama nikel Raney pada sintesis organik adalah desulfurisasi.
# BLEU Score: 0.4647
# --------------------------------------------------
# Key: 279
# Input: The group started as a sextet in 1927 in Central Havana.
# Predicted: Grup berjalan dimula dari klipsen tiga pada tahun 1927 di Tuas Perdamaian Pulau Negri Cibubur.
# Reference: Festival itu dimulai 1957 di Den Haag.
# BLEU Score: 0.1506
# --------------------------------------------------
# Key: 280
# Input: "The corporate signage, stationery and literature of TfL services, including LRS, use the New Johnston typeface."
# Predicted: İngilizce : "TbLL servisler tarafından kullandığı Nye Jonston tifftesiyle birlikte panolarlardaki organizatiftir sigana ve dersaydere gibidir".
# Reference: "Tanda nama perusahaan dan stasiun ditulis dengan tipe huruf New Johnston, sama dengan layanan TfL lainnya."
# BLEU Score: 0.1507
# --------------------------------------------------
# Key: 281
# Input: The present list was established in 1917.
# Predicted: Listasi de hari semasa sudah diperusunan pada tahun 1917.
# Reference: Daftar yang digunakan sekarang diberlakukan pada tahun 1917.
# BLEU Score: 0.4209
# --------------------------------------------------
# Key: 282
# Input: The larvae are parasitic.
# Predicted: Larvanya adalah endoparasitean.
# Reference: Beberapa cnidaria bersifat parasit.
# BLEU Score: 0.2310
# --------------------------------------------------
# Key: 283
# Input: Magdalena was betrothed to Ladislaus the Posthumous however he died suddenly in Prague on 23 November 1457 while preparing for his marriage.
# Predicted: Megadiana diperkawin dengan Laskaris la Deadus pada Praha tanggal 23 November 1457, sedang berbareng dalam pelaksanaan kawinnya itu menahujani nyawa dia sendiri sementara melanda tukungannya..
# Reference: "Magdalena dijodohkan dengan Ladislaus V, Raja Bohemia, namun ia tiba-tiba meninggal di Praha pada tanggal 23 November 1457 sewaktu mempersiapkan pernikahannya."
# BLEU Score: 0.4413
# --------------------------------------------------
# Key: 284
# Input: "Japan Railways locomotive numbering and classification SoftBank Telecom – former Japan Telecom, an affiliated company of JNR established in 1984 Ishino, Tetsu et al. (eds.) (1998)."
# Predicted: 'Nomer kendaraan kereta listrik Tanah Yamuna - sebelumnya Nippon Telegraph & Communication Anggota Yen Pembina Nasional Eka Buana Lainnya Dua Penulis-edisi Beberapa tahun lalu Injoyo Shimano Takashi Misutani Shoichi Toyoda Sekolah Keperguruan Umum Tokyo'
# Reference: "Sistem penomoran dan klasifikasi lokomotif kereta api di Jepang SoftBank Telecom – penerus Japan Telecom, sebuah perusahaan telekomunikasi yang berafiliasi dengan JNR ^ ""JNR/JR 25年の大アルバム""."
# BLEU Score: 0.1873
# --------------------------------------------------
# Key: 285
# Input: England and the United States follow this rule.
# Predicted: Ingilit dan Amerika Serikat memelintas aturan ini.
# Reference: Langkah ini diikuti oleh Inggris dan Amerika.
# BLEU Score: 0.3677
# --------------------------------------------------
# Key: 286
# Input: "An example of this is Cooma, Australia, where it is flown to commemorate South African workers in the Snowy Mountains Scheme alongside the Canadian Red Ensign, 49 star US flag, and other flags from 1959 when the Avenue was dedicated."
# Predicted: "Contohnya adalah Koomba Selatan Timur Asien di mana dipajak untuk merayap karyawan Swamy Tonbatu sesudah direkam dengan Bendera Gerani Tionghoa Serikat (Canada), Semadaran Biruan Delapan Star Amerika serta pembungkuannya lain-lain dari tahun 1959 saat alas Jl Setia Untuk Keseluruhan Terbit".
# Reference: "Sebuah contoh dari kasus ini ialah pembentangan bendera ini dari Snowy Mountains Scheme bersamaan dengan bendera Merah Kanada, bendera Amerika Serikat yang masih menggunakan 49 bintang, dan bendera lainnya sejak diterapkan pada 1959 untuk memperingati buruh Afrika Selatan di Cooma, Australia."
# BLEU Score: 0.4327
# --------------------------------------------------
# Key: 287
# Input: "He is notable as the only actor to be honored with the Tony Award, Drama Desk Award, Outer Critics Circle Award, Clarence Derwent Award, and Theatre World Award for the same role."
# Predicted: ia berlisensir sebagai aktor tersendiri dengan hadiah Tony Awards, Hadiah Drameduk derksenya, Aloha Kritikus Kini Pengawisitas Budapessyen (CC), Alasan Cirencester dan Premio Lunas del Mundo untuk bagian sama dalam drama teater itu .
# Reference: "Namanya tercatat sebagai pemeran yang menerima penghargaan dari Tony Award, Drama Desk Award, Outer Critics Circle Award, Clarence Derwent Award, and Theatre World Award untuk peran yang sama."
# BLEU Score: 0.3053
# --------------------------------------------------
# Key: 288
# Input: Nearly 10 million people migrate to Pakistan and India.
# Predicted: Jutaan orang berdekatan melakukan migrasi kepada Pakistan dan India.
# Reference: Bahasa ini dipakai sekitar kurang lebih 100 juta masyarakat Muslim di Pakistan dan India.
# BLEU Score: 0.3526
# --------------------------------------------------
# Key: 289
# Input: "Rudolf Swoboda the younger (1859–1914) was a 19th-century Austrian painter, born in Vienna."
# Predicted: Rudolf Sooboda pria laki-laki muda (1859–1914), adalah seniman Habsburan abad XIX, dibantuhlah oleh Vienne bertumbuh lama.-Jawaban Indonésia : Rudolph Sofovda budayanya benarkala sekali menjadi SenimanHabsburgoabdadalamurhabutvienyenilatmanKotaVienneguncampungpertanihnyaGundiviekaLakirTulisindikasikan dengan tanda ("—" untuk periode dan ",", "-") atau simbol separasi sp
# Reference: Rudolf Swoboda si muda (1859–1914) adalah seorang pelukis Austria abad ke-19 kelahiran Wina.
# BLEU Score: 0.1509
# --------------------------------------------------
# Key: 290
# Input: "Setting off on May 8, her flight was uneventful although the large crowds that greeted her at Newark, New Jersey were a concern, because she had to be careful not to taxi into the throng."
# Predicted: 15 Meletinstir di tanggal Rabu 8 Maret pembelajarannya tidak mengalami suatu krisis apapun tapi massyah besar-besaran seperti menjemput dia oleh para pelaku dan servis dengan cermat sayuran terdamping jauhi karena harus rajin untuk memerhatikan agung angkut laluway dari ratusabrata lakiri inilai sedikit itulad nyawa sama sempat bertentangganya selesempekerjana punya tanjakannyal turustafia ya manfaatan
# Reference: "Pada penerbangannya tidak terdapat banyak peristiwa walaupun banyak kerumunan orang yang menemuinya di Newark, New Jersey adakah kekhawatiran dan ia harus berhati-hati tidak untuk berjalan keluar dari landasan pesawat ke kerumunan orang."
# BLEU Score: 0.2702
# --------------------------------------------------
# Key: 291
# Input: "The result of this development was the CinemaScope/Todd-AO motion picture sound system, which was first used in movies such as The Robe (1953) in 35mm and Oklahoma (1955) in 70mm (and also in 35mm)."
# Predicted: İngilizce:"Resultat bu tasarruf oldu olan gelişim cinemasyon hikaye fonksiyonel resmi ses sistemi Cinemascope / Todd-Ao, ki bunlarından biriyle ilgili olmuştur; Bu son dereceye 'Robet'lerdeki filmü sağlamak içinde ve Yukala daireleme filminizi kullanmaktadır - üzerinden sini tamamlayacaksaki bir formül özellikte almayız ('Mütayen veriler', uygulama alt metre), ancak genel
# Reference: "Hasil pengembangan ini adalah sistem suara gambar bergerak CinemaScope/Todd-AO, yang pertama kali digunakan dalam film-film seperti The Robe (1953) dalam pita 35mm dan Oklahoma (1955) dalam 70mm (dan juga 35mm)."
# BLEU Score: 0.1676
# --------------------------------------------------
# Key: 292
# Input: "The largest conference in the region held in Doha, Qatar, held each January at the Qatar National Convention Center."
# Predicted: Konferensi terbesar di wilayah itu hadir setiap Januari pada Pusat Persanding Negara Kesatuan Katargot (QNNC).
# Reference: "Konferensi terbesar di wilayah tersebut diadakan di Doha, Qatar, yang diadakan setiap bulan januari di Qatar National Convention Center."
# BLEU Score: 0.4096
# --------------------------------------------------
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Key: 293
# Input: "These scholars fear that users will be unable to "" beyond narrow self-interest"" as filter bubbles create personalized social feeds, isolating them from diverse points of view and their surrounding communities."
# Predicted: هذا الفقهاء خوف أن تكون المستخدمين غير بعيدة جدًا عن "المصلحة الشخصية"، כثير الزبائن الإضافية؛ حيث تظهر أحزمة الفضاء الآلي DNA الشخصي النشط للتغذية الاجتماعية، وهذه الحزم التفاعل
# Reference: "Para sarjana ini khawatir bahwa pengguna tidak akan dapat "" di luar kepentingan pribadi yang sempit"" karena gelembung filter membuat umpan sosial yang dipersonalisasi, mengisolasi mereka dari beragam sudut pandang dan komunitas sekitar mereka."
# BLEU Score: 0.0000
# --------------------------------------------------
# Key: 294
# Input: Nick Raider's stories are set in New York City.
# Predicted: Stori Nikk raidir terjebos di Kota Jalan Besar NYCnya.
# Reference: Konflik Nick Jago terjadi di Skotlandia.
# BLEU Score: 0.2153
# --------------------------------------------------
# Key: 295
# Input: "In 2008, he suffered an injury which kept him of the field for nearly 1 year."
# Predicted: ​"Selasa 2008, dia menderita kecelakan sehingga hinggalam matikan pelatih selama kurun waktu berapa bulannya".
# Reference: "Di Piala Dunia 2006, ia mendapat cedera parah yang membuatnya harus absen dari lapangan hijau hampir satu tahun lamanya."
# BLEU Score: 0.2408
# --------------------------------------------------
# Key: 296
# Input: The Minahasa Union party (Perserikatan Minahasa) included both civilian and military members.
# Predicted: Partai Persatuan Minahasawon mengandung siapapun bertipe civili dan militer.
# Reference: "Pada waktu itu, keanggotaan Perserikatan Minahasa termasuk orang-orang sipil dan militer."
# BLEU Score: 0.3892
# --------------------------------------------------
# Key: 297
# Input: Profile at the official FC Zenit St. Petersburg website Profile at the official Russian Premier League website (in Russian) Profile at the official FC Krylia Sovetov Samara website (in Russian) Photo gallery at the Wayback Machine (archived 28 September 2007)
# Predicted: Profil di situs web pribadi ujung FKZeniT Pelajaran Saint-Petersburg Profil dari Situs Web Perlembagaan Premium Rusia(dalam bahasa RUSIA)Galeri Gambar Dilaporkasi Buka Pewaze Permain dan tanggal sampai dengan9 Agustus,2007
# Reference: (Inggris) Profil Aleksandr Anyukov pada situs FC Zenit St. Petersburg (Rusia) Profil Aleksandr Anyukov pada situs Russian Premier League (Rusia) Profil Aleksandr Anyukov pada situs FC Krylia Sovetov Samara (Rusia) Galeri Foto Aleksandr Anyukov
# BLEU Score: 0.3086
# --------------------------------------------------
# Key: 298
# Input: "His solo debut as a director started in 1972 with the film Revenge of the Child Haram, in which the screenplay was also written by him."
# Predicted: Bahasa Indonézia : "Debyok sederhana pertama seorang direktur dimulai pada tahun 1972 dengan filman Kembali Dilupuh Keharamen Anak," di mana versiyelan tebar dalamnya juga diturunkan oleh dirinya sendiri.
# Reference: "Debut sutradaranya dimulai pada tahun 1972 dengan film ""Dendam si Anak Haram"", yang skenarionya juga ditulis olehnya."
# BLEU Score: 0.3686
# --------------------------------------------------
# Key: 299
# Input: The People's Daily also maintains a multilingual internet presence; and established the People's Daily Online (人民网) in 1997.
# Predicted: Informatif Republik Pemuda juga mempertahankan adanya tembakau internasional dalam dunia Internet, dan mendirikan Perkumpulan Gawat Dini PRD online pada tahun 1997.
# Reference: "Koran ini memelihara kehadiran internet multibahasa, dan mendirikan People's Daily Online (人民网) pada tahun 1997 dan mesin pencari Jike (即刻 ""segera"") pada tahun 2010."
# BLEU Score: 0.4133
# --------------------------------------------------
# Key: 300
# Input: "As of the seventh annual ceremony on April 26, 2014, the ceremony began to be televised in full a day after a tape delay, as the network attempts to compete with Nickelodeon's Kids' Choice Awards in airing awards programming."
# Predicted: iapun kedalam sampai pelakaran selama setahun teranjur lima enam april delapan kilenta sembilasnya lewat lapor tanggal sehingga masyarakat-masyarakati dapat melihat halaman pengidaikan oleh rangkaistainetnetik jika bertanya tentusa menekankannya dengan persentase kompetisi serupa dihaluan nikeloden kanorion disambungansemua aksiaris programming showprogram;
# Reference: "Pada acara tahunan ketujuh pada tanggal 26 April 2014, acara ini mulai ditayangkan di televisi secara sehari penuh setelah tape delay, sebagai jaringan dalam bersaing dengan Nickelodeon Kids' Choice Awards di penayangan pemrograman penghargaan."
# BLEU Score: 0.3144
# --------------------------------------------------
# Key: 301
# Input: "She is close to Michael's brother, Craig."
# Predicted: Dia dekat dengan kak Tomo, Criklenggungannya.
# Reference: "Dia adalah teman dari kakak Karen, Naoto."
# BLEU Score: 0.2162
# --------------------------------------------------
# Key: 302
# Input: "Toriyama explained in 1995 that for video games, because the sprites are so small, as long as they have a distinguishing feature so people can tell which character it is, he can make complex designs without concern of having to reproduce it like he usually would in manga."
# Predicted: Tora-iyam menjelaskan pada tahun 1995 bahwa untuk game kartir seiring saja sprite sangat terlalu kecil, jika mereka mempunyai ciri berbeda orang bisa membedakannya tanpa sedikit rasa malasnya hampiriak karena biasanya diperintih balita satu sisi nilaikan ucapiku serupapunggal oleh dia dalam mangga saya gajipuduhini ya?
# Reference: "Toriyama menjelaskan untuk permainan video, karena en (sprite)-nya sangat kecil, selama mereka memiliki penampilan khusus sehingga orang-orang bisa membedakan antara masing-masing karakter, dia bisa membuat sebuah desain yang rumit tanpa khawatir harus membuatnya ulang seperti yang dia bisa lakukan di manga."
# BLEU Score: 0.4945
# --------------------------------------------------
# Key: 303
# Input: "Asmodeus told Solomon that the shamir was given by God to the Angel of the Sea, and that Angel entrusted none with the shamir except the moor-hen, which had taken an oath to watch the shamir carefully."
# Predicted: Asmodayun berbohong kepada Salomo bahwa semerleng diberikan Omoyen Gunung Cerminy saatnya ituliskan dengan angel laut dan melindungisik pilihan terlebih dahulu hanya duwukok masyarak (melambai) untuk menjaga sedot Semeril secara sangsietos sekaligurihairenya meticulously..
# Reference: "Berkata Al-Hafizh Ibnu Hajar dalam Fathul Bari: “’Ain adalah pandangan suka disertai hasad yang berasal dari tabiat yang jelek, yang dapat menyebabkan orang yang dipandang itu tertimpa suatu bahaya.”."
# BLEU Score: 0.1845
# --------------------------------------------------
# Key: 304
# Input: "Adversely, charging the hoarder with only one count reduces the burdens on the system, the prosecutors, and the animal agencies, but undermines the severity of the charges."
# Predicted: Bahasa Indonésia : Penyalahgunaannya mengadjudikasi hulubai dengan satu ketentukan memudat beberapa masalah di sistem seperti pada pihak prosesors dan lembaga-lembaga animalek namun membungkin tanggal atas intensitas tindak pidana tersebut..
# Reference: "Dia memberi teladan untuk hidup sederhana, jumlah staff dan pejabatnya dikurangi untuk mengurangi beban pajak rakyat."
# BLEU Score: 0.1761
# --------------------------------------------------
# Key: 305
# Input: "First established in 2016 by SCTV, the Indonesian Social Media Awards are an annual awards were honour for celebrity and voted by fans in each social media, such as Facebook, Snapchat, Twitter and Instagram."
# Predicted: Bahasa Indonésia : Pertama diperintah oleh SKT pada tahun 2016, Kesatuan Award Medium sosial ialah perlindunga setiap jiwa berkomunitas dari penjual dan dipilihan masyarakat melawan satuan seluler seperti Fb, Snappcadhar, Twiiter serta instagrame .
# Reference: "Indonesian Social Media Awards 2016 (ISMA 2K16) adalah sebuah ajang penghargaan bagi insan insan selebriti indonesia melalui sosial media yaitu Facebook, Twitter, Instagram & Youtube."
# BLEU Score: 0.3066
# --------------------------------------------------
# Key: 306
# Input: Despite the community differences the rivalry between supporters is fairly amicable and brings financial benefits to both clubs.
# Predicted: Meskipun adanya ketidaknyamanan komunitas, persilidan antara peserta-peserta masih bertahap baik dan memberikan manfaat finansial untuk dua klub serius itu sendiri..
# Reference: Walaupun berbeda suku tetapi rasa kekeluargaan sangat kental dan hidup secara berdampingan.
# BLEU Score: 0.1582
# --------------------------------------------------
# Key: 307
# Input: She enrolled for the diploma course to teach physics and mathematics in secondary schools (section VIA) at the same time as Albert Einstein.
# Predicted: Dia mendaftarkan pelajaran kursil untuk melatih fisika dan matematik pada sekolah menengah IV bersama tepatnya dengan Alberta Einstein.
# Reference: Dia terdaftar untuk program diploma untuk mengajar fisika dan matematika di sekolah menengah (bagian VIA) pada waktu yang sama seperti Albert Einstein.
# BLEU Score: 0.5968
# --------------------------------------------------
# Key: 308
# Input: "However, he fails to do so."
# Predicted: ,"Tetapi dia gagal untuk melakukannya"。
# Reference: Namun ia tidak berhasil melakukannya.
# BLEU Score: 0.4161
# --------------------------------------------------
# Key: 309
# Input: "Her third album, Teenage Dream (2010), ventured into disco, and was her first album to top the U.S. Billboard 200."
# Predicted: Pergelaran ketiga dari hamilnya Tegen Dosis Anak-anak(2010) meluncur dipilih dalam stil diskoklash dan terjadi pertama di atas US Billboard Hot 200..
# Reference: "Album ketiganya, Teenage Dream (2010), campuran dari disko, dan merupakan album pertamanya yang memuncaki Billboard 200 AS."
# BLEU Score: 0.3890
# --------------------------------------------------
# Key: 310
# Input: "Gordon was fined $50,000 and docked 50 drivers' points."
# Predicted: Gordon dibujikan ulasan keluh seratus ribu dolara dan dikelupakkannya lima pulau pelayan pemegawai sekalipun/.
# Reference: Gordon dihukum denda 100.000 dolar AS dan pemotongan 25 poin di klasemen.
# BLEU Score: 0.2595
# --------------------------------------------------
# Key: 311
# Input: "This area includes the Malay Peninsula, the coastal areas of Sumatra and Borneo, and the smaller islands in between."
# Predicted: ia wilayah tersekutnya termasuk Tanah Melayu, daerah tenggelam dari Sumatra dan Bornem serta kepulauan lebih kecil diantara saya-saya itu.
# Reference: "Daerah ini meliputi Semenanjung Malaya, daerah pesisir Sumatera dan Kalimantan, dan pulau-pulau kecil di antaranya."
# BLEU Score: 0.3642
# --------------------------------------------------
# Key: 312
# Input: "Long-time friend and bandmate Chris Poland said about Samuelson: ""He was a true friend."
# Predicted: ​"Chris Polonia, teman jahat waktu dan sekmana musiker diucapai bantuan Samwerloman menyampaikan: 'Dia adalah sahabat nyata.'”
# Reference: "Teman lama dan rekan setimnya, Chris Poland, bercerita tentang Samuelson: ""Dia adalah teman sejati."
# BLEU Score: 0.3737
# --------------------------------------------------
# Key: 313
# Input: Clinical Physiology.
# Predicted: Fisiologi Kulit Dosen/Klinis
# Reference: Poliklinik Fisikologi.
# BLEU Score: 0.3213
# --------------------------------------------------
# Key: 314
# Input: "In view of the consideration that the cow and its entire progeny must be saved to provide milk, as well as manure, it becomes imperative to impose a complete ban on the cow slaughter."""
# Predicted: Dengan pemikirannya bahwa kaca dan anaknya seluruh mereka harus disertapkan untuk mendapat air susu serta depo-depositum inilah membutuhkan imposed lagalat semua jadwal matigai hambari kalb tersebut .
# Reference: "Di lihat dari pertimbangan bahwa sapi dan seluruh keturunan harus diselamatkan untuk memberikan susu, serta pupuk kandang, menjadi penting untuk memaksakan larangan lengkap tentang sapi disembelih."""
# BLEU Score: 0.4389
# --------------------------------------------------
# Key: 315
# Input: "In addition, the research performed in this manner is typically discontinuous and generally of low impact."
# Predicted: Indonésia : Selain itu, penelitian tersebut biasanya hilang tetap dan umumnya memiliki dampak rendah sepenuhnya.
# Reference: Dan yang patut dicontoh lagi adalah kehidupannya yang tetap sederhana dan low profil.
# BLEU Score: 0.2410
# --------------------------------------------------
# Key: 316
# Input: Pyramus and Thisbe are lovers whose parents forbid them to marry.
# Predicted: Piram dan Thiseba adalah romantisyen di mana ayah mereka telat memperbolehkannya untuk menikah-nikkahn..
# ...
# Predicted: Fatwa itu menjadi dasar pelaksanaan praktik kripto Islam oleh morisk diurut dalam periode pemberantasan antara tahun 1609 dan 1614.
# Reference: Fatwa inilah yang menjadi landasan praktik Islam sembunyi-sembunyi oleh orang-orang Morisco hingga mereka pernah diusir pada 1609-1614.
# BLEU Score: 0.4580
# --------------------------------------------------
# Key: 863
# Input: "The Guardian calls it ""audacious""."
# Predicted: İngilizce:" The Guardian's call is called 'audacity'."
# Reference: "Pernyataan tersebut oleh The Guardian disebut ""sulit dipercaya."""
# BLEU Score: 0.2466
# --------------------------------------------------
# Key: 864
# Input: "It included large parts of the Canisius catechisms including his addition to the Hail Mary: Holy Mary, Mother of God, pray for us sinners."
# Predicted: ,""Dukung hadirkan keseluruhan bagian besar Cathechesa Kansiyus mengandung penambahannya pada Terjemah Mercy Madyatun Holika di Rona Jalani Penyebut:"Holy Maria Tuas Budayaknyana dikenalkan Diria Allah Sah Dari Semuduranya Pintik Aniskara Servi Pepeker sebagai Tersetia Injil dan Pelindon-pelindo Suci Yemainnen Sakit Negeri Benda Selamatan Ngebendotanyo Berjalankan Wihatih Sekta Dan Reflamen Cathars
# Reference: "Katekismus tersebut meliputi sebagian besar katekismus Canisius termasuk kalimat tambahannya pada doa Salam Maria: Salam Maria, Bunda Allah, doakanlah kami yang berdosa ini."
# BLEU Score: 0.2145
# --------------------------------------------------
# Key: 865
# Input: "The film was released on September 13, 2013, and received negative reviews."
# Predicted: Film dikeluarkan pada tanggal 13 September 2013 dan mendapat ulasan negatif.
# Reference: "Film ini dirilis pada tanggal 13 September 2013, dan menerima tinjauan negatif."
# BLEU Score: 0.6571
# --------------------------------------------------
# Key: 866
# Input: "Its budget was boosted by private donations, which resulted in another 100 million dollars."
# Predicted: İnceapnya dibantah sekunder bersambung dengan bayaran privat sadari tadi berarti lebih $100 miljardi lagi..
# Reference: "Anggaran tersebut membengkak berkat sumbangan-sumbangan pribadi, yang memasok 100 juta dolar lainnya."
# BLEU Score: 0.2946
# --------------------------------------------------
# Key: 867
# Input: "According to one source, it was only by the entreaties of Emperor Wilhelm I that a separation never occurred."
# Predicted: Bahasa indonesia: Sesuai sumber satu kata, rapat tidak ada terjadi karena tutup kerasnyawa Yang Adipunan Willem I..
# Reference: Hanya karena Kaisar Wilhelm I perpisahan tidak pernah terjadi.
# BLEU Score: 0.2635
# --------------------------------------------------
# Key: 868
# Input: Bayan imprisoned Chunghye in 1340.
# Predicted: Perempuan menimbacah Heng-sai pada tahun 1340.
# Reference: Bayan memenjarakan Chunghye pada tahun 1340.
# BLEU Score: 0.5000
# --------------------------------------------------
# Key: 869
# Input: "To be free of his mother's consistent prodding, Cyrus offers Samsoon a love contract-in which she must act as his girlfriend in exchange for a huge amount of money."
# Predicted: "Untuk kebebasan dari pelajaran tetapnya ibu Krisus samakandanya mengabaikan kontrakt pikiran cinta di mana dia harus berperilaku sebagai boybandia itulah bagi dirimanyenyata juta rupiah"
# Reference: "Sementara ayahnya mewarisi tradisi kebebasan intelektual, ibunya yang memiliki kecenderungan kekiri-kirian (antikemapanan) menekankannya pentingnya keseimbangan untuk bertindak sebagai pemikir yang sekaligus aktivis."
# BLEU Score: 0.3228
# --------------------------------------------------
# Key: 870
# Input: The squad numbers were revealed on 2 June.
# Predicted: Numeran tim diperlihatkannya pada tanggal 2 Juni.
# Reference: Nomor punggung diumumkan pada tanggal 2 Juni.
# BLEU Score: 0.5196
# --------------------------------------------------
# Key: 871
# Input: The album includes the group's first two mini-albums in Japan and songs from their third mini-album in South Korea.
# Predicted: Album memandang kumpulan pertama dua musik dari minisolusi di Jepang dan lagu daripada tiga solosia dalam Kesempatan Pertama Sudah Koreakara,Album menampilir tempat bandawapa anggota pria terdepannya kursi japani dengan muncul seribu benda laksana melodi penunda sudah korelinekatas saja katapaling sungguhnya beserta kalaupengendong suatu komposisi untuk gitar barigsaikan sehingga sayur keredha warna budayaku jadi sang
# Reference: Album ini berisi dua album mini pertama mereka di Jepang dan lagu-lagu dari album mini ketiga mereka di Korea Selatan.
# BLEU Score: 0.1937
# --------------------------------------------------
# Key: 872
# Input: "In 2008, Tabor was added to the guitar show ""Chop Shop's"" list of ""Top 100 Most Complete Guitar Players of All Time"" at number 84."
# Predicted: "Pada tahun 2008, Boro masuk dalam daftar gigitan pelajaran sakuntongan '"Komplet Negara Gitarren" sebanyak angka ketiga ratus delapan bagi 'Chopper Chops'.
# Reference: "Pada 2013, Weaving mempersembahkan kembali peran tersebut untuk iklan General Electric. ^ ""The 100 Greatest Movie Characters| 84."
# BLEU Score: 0.1582
# --------------------------------------------------
# Key: 873
# Input: Their marriage took place between 1196 and 1200.
# Predicted: Kererawan mereka terjadi antara tahun 1196 dan 1200.
# Reference: Pernikahan mereka berlangsung antara tahun 1196 dan 1200.
# BLEU Score: 0.6644
# --------------------------------------------------
# Key: 874
# Input: "A few survive from later times, including a first milestone near the porta Appia."
# Predicted: 「Banyak hidup dari zaman berikutnya termasuk tujuhannilatan awal dekat Portae Apiae.»
# Reference: "Beberapa penanda jarak yang masih terlestarikan dibuat di kemudian hari, termasuk batu jarak pertama dekat porta Appia."
# BLEU Score: 0.2536
# --------------------------------------------------
# Key: 875
# Input: "The pectoral fin is falcate, and also longer than the head."
# Predicted: Perikard tulis ada faktafal kanan dan juga lebih panjang daripada kepala.
# Reference: "Sirip pektoral (dada) dengan ujung membulat, panjangnya lebih dari panjang kepala."
# BLEU Score: 0.4021
# --------------------------------------------------
# Key: 876
# Input: "The Samsung Galaxy S II is a touchscreen-enabled, slate-format Android smartphone designed, developed, and marketed by Samsung Electronics."
# Predicted: "Galaxy SII Sony Ericsson adalah telepon seluler android dari bentuk peta format sled (skrin layar tertulis) dan dipercepat oleh kantor elektronik Siemens Erickson".
# Reference: "Samsung Galaxy S adalah sebuah telepon pintar Android format datar layar sentuh yang dirancang, dikembangkan, dan dipasarkan oleh Samsung Electronics."
# BLEU Score: 0.4305
# --------------------------------------------------
# Key: 877
# Input: "In one model, the average temperature of Earth following a full thermonuclear war falls for several years by 7 to 8 degrees Celsius on average."
# Predicted: İngilizce:"Dört modellede üstsel içinde Kar Planet'ın ortalama sıcaklığı beş ila sekiz dördügen boyunca ekipman bir termonyukleer ferman altı romboslu ve ikisel olarak azaldır.," Mutfarkta Javanese :   Dapat dirimani kota devar gondan tepatum anandina serdu mifatik bongsu bilimi bohoni karna barata rajja tetur-tetuka pantura niraju adha daci mane tuwaha mahanika
# Reference: "Dalam satu model, suhu setelah perang termonuklir penuh jatuh selama beberapa tahun menjadi rata-rata 7 sampai 8 derajat Selsius ."
# BLEU Score: 0.1226
# --------------------------------------------------
# Key: 878
# Input: "However, McRae describes the link between Bodhidharma (and therefore Sengcan) and the Lankavatara Sutra as “superficial”."
# Predicted: ,"Tetapi Mac Rae membicilikan hubungan antara Buddha Dharmapada (dan dari itu Sang San Ca) dengan Latnakvarta sutrasia sebagai ”terhadapnya superatif".
# Reference: "Namun, McRae menggambarkan hubungan antara Bodhidharma (dan karena itu Sengcan) dan Lankavatara Sutra sebagai ""dangkal""."
# BLEU Score: 0.4406
# --------------------------------------------------
# Key: 879
# Input: Almost all of the x86 systems provided a version of MS-DOS.
# Predicted: Seluruh sistem X86 memberikan versi dari DOS Microsoft awalnya, sekitar semua itulah.
# Reference: Hampir semua instalasi Unix memiliki satu versi dari vi.
# BLEU Score: 0.3106
# --------------------------------------------------
# Key: 880
# Input: "It was released by Rhythm Zone on 26 May 2010 in two versions: Jacket A, a CD+DVD version which includes a music video with 4 tracks, and Jacket B, a CD only version which contains 5 tracks."
# Predicted: "Diumrahli oleh Zona Rimba pada 26 Mei 2010 dengan dua versi kali pertama; Jamcase E ja jam Case F saatnya - Versi KTP-CD/VHS menampikan musikkvideo serta sembilir dapat dibeli sekitar empuk lima traksus".
# Reference: "Album ini dirilis oleh Rhythm Zone pada tanggal 26 Mei 2010 dalam dua versi: Jacket A, versi CD+DVD yang termasuk video musik dengan 4 lagu, dan Jacket B, versi hanya CD yang berisi 5 lagu."
# BLEU Score: 0.3733
# --------------------------------------------------
# Key: 881
# Input: Work and thus energy is frame dependent.
# Predicted: Bahasa Inggris : Beberapa dan sebagainya, energi terkadang bergantung pada kerangka waktu-waktu itulah tradisi kosmologii saat ini mengaku untuk merupakan fenomena berkali purun atau hilir dari suatu penyebab lainnya serta adanya hipoteses lebih lanjut berikut diudaha melalui sistem observasi multimensura dalam periode tertentu jika nilai persamaannya sampel cair (random) makna semua kombination data dengan rinci tan
# Reference: Kerja dan energi adalah tergantung kerangka.
# BLEU Score: 0.0829
# --------------------------------------------------
# Key: 882
# Input: "Acupuncture: Acupuncture, the traditional Chinese medicinal practice of inserting needles into specific points of the body for therapeutic purposes and relieving pain, was first mentioned in the Huangdi Neijing compiled from the 3rd to 2nd centuries BC (Warring States period to Han Dynasty)."
# Predicted: Penggunaan tatacara acupunktura : Tatacaruan akupuntur adalah praktik medis tradisional Cina melainkan memindai kantung neeple pada titik spekifik dunia unt tuju waktu pelunasannya dan mengatasim serta nyeri; didominasi oleh catatan dalam Sang Kancil Kejatuhan Yangjelasken di Hua Di Niejing dengan data kompiled antara abad III hingga II Mnyapat Warga Jati Warong Saudaran ganda Tuji han dynastie.
# Reference: "Tusuk jarum: Tusuk jarum, praktik pengobatan Tionghoa tradisional dengan menusukkan jarum-jarum ke titik-titik tertentu dari tubuh untuk keperluan terapi dan memulihkan luka, pertama kali disebutkan dalam Huangdi Neijing yang dikompilasikan dari abad ke-3 sampai ke-2 SM (periode Negara-Negara Berperang sampai Dinasti Han)."
# BLEU Score: 0.3571
# --------------------------------------------------
# Key: 883
# Input: "September 18 – Beginning of the 13th Baktun, in the Mesoamerican Long Count calendar (12.0.0.0.0)."
# Predicted: 9 Desember - Mulai bertahun-tahun kedua seribu tunggal barat di kalender mesaeroerius lama berjumlah .(literal translation might be slightly different due to complexity) : September 18 dhuh unggul semester catur saptomo ninyambulu pada kisaran juta duasa dengan batuketab menyelenggarakan bilampara rantik pun ituh saturnalia indika oleha mawarasuraka ulawan ikawannya budayapura raja watak anusuri serepana katupon peperdina hamp
# Reference: 19 September - Awal baktun ke-13 (terakhir) Kalender Hitung Panjang putaran ke-4 (12.0.0.0.1).
# BLEU Score: 0.0981
# --------------------------------------------------
# Key: 884
# Input: German Protestants rejected any “Papal Peace” as insulting.
# Predicted: İngilis protestanlar Alman paşala fermanın "Paopsal Barlama" kabul ederseydik daha bir incelemekçe zararsızdırlardır.
# Reference: "Protestan Jerman menolak ""Perdamaian Paus"" sebagai penghinaan."
# BLEU Score: 0.1705
# --------------------------------------------------
# Key: 885
# Input: "The City of Palatka hopes to revitalize interest in the house by marketing it once again as a wedding and event venue, as well as a vital cultural and historical resource for Floridians."
# Predicted: Kota Palahtika berharap mengelola sekali lagi kepunahan rumah untuk memperbarui minat melalui penjualikan di ujiannya opsi pesta dan acara serta sumber kulturalistiknya penting bagi orang-orang Florida.
# Reference: Saoraja Kampung Adat Karampuang adalah tempat tinggal para pemangku adat dan sekaligus juga sebagai tempat atau pusat kegiatan budaya dan tradisi masyarakat adat Kampung Adat Karampuang.
# BLEU Score: 0.2427
# --------------------------------------------------
# Key: 886
# Input: "However, the Board of Ethics determine this to be a gift over $50 due to the secondary market markup on the tickets."
# Predicted: ,"Tetapi Komite Etis bagi laporan inilah sebagai hadiah lebih dari USD 50 karena penjualannya di markettrakt mengalami dukung gaji kedua"。
# Reference: Akan tetapi pembajakan kaset turut andil dalam valuasi tersebut dengan menghasilkan pendapatan sebesar 2 dollar per kaset di pasaran.
# BLEU Score: 0.2380
# --------------------------------------------------
# Key: 887
# Input: "As of 1997, there were only 13 addiction psychiatry programs that the Accreditation Council for Graduate Medical Education(ACGME) recognized."
# Predicted: 20 Tahun Membesarnya Pada tahun 1997 Ada hanya sejumlah pelatihan psikiatri adiktif program saat ini dilaras oleh Lising Program Meslek Dewasa (AGCM), kelilingan itulak tercatat empat puluh treis jalansara .
# Reference: "Pada tahun 1993 Sekolah Perawat Kesehatan (SPK) Tasikmalaya ditingkatkan statusnya menjadi Akademi Keperawatan (AKPER), Akedemi Kebidanan (AKBID) dan Akademi Kesehatan Gigi (AKG)."
# BLEU Score: 0.2222
# --------------------------------------------------
# Key: 888
# Input: They have a recurring sense of bitterness and apocalypse.
# Predicted: mereka memiliki rasa ketegelamaan dan kalamitan global itulah dengan nyata noda siksik serta pengharapan kolosalisasinya .
# Reference: Mereka mendapat tentangan tajam dari Helmi dan Syukur.
# BLEU Score: 0.1736
# --------------------------------------------------
# Key: 889
# Input: Plumbane may be obtained in a reaction between metallic lead and atomic hydrogen.
# Predicted: Pembuluhan mungkin dicapai reaksi antara lempel metalik dan hidrojen atomisal.
# Reference: Plumbana dapat dihasilkan melalui reaksi antara logam timbal dan atom hidrogen.
# BLEU Score: 0.4960
# --------------------------------------------------
# Key: 890
# Input: The seedlings of some flowering plants have no cotyledons at all.
# Predicted: Serapan benih beberapa tanaman penghancuran berbunga tidak memiliki kulit cotylon tetapi punya semua gantikelompoknya sendiri inipun ya?
# Reference: "Selain itu, sebagian jamur lendir seluler tidak memiliki tahapan berflagel."
# BLEU Score: 0.2695
# --------------------------------------------------
# Key: 891
# Input: "After spending two months in Genoa, Henry continued on to Pisa by ship, where he was eagerly received by the inhabitants, who were the traditional enemies of Florence and were Ghibelline."
# Predicted: Ingatlah bahasa Jerman dan Ital diikutan dengan kata-kata dalam Bahasa Indoniesia pada berita tersebut sebagai sedikit persamaannya:
# Reference: "Setelah menghabiskan waktu selama dua bulan di Genova, Heinrich melanjutkan ke Pisa dengan kapal laut, dimana ia dengan semangat diterima oleh penduduk, yang merupakan musuh bebuyutan Firenze dan Ghibellin."
# BLEU Score: 0.1961
# --------------------------------------------------
# Key: 892
# Input: "Believing that Hang Tuah was unjustly murdered by the sultan he served, Hang Jebat turned against the ruler to avenge his friend's death."
# Predicted: Pertanda bahwa Raja Puteri Tanggal-tangal dihantarkan dilaras oleh Sultan serta itu maka Sri Setia Budi Suci (HangJabath) berpindah kepada tujuannya mencoba memutus hukum tua tersebut melawan pemimpinnyanya agar mengkembali jiwa temankayam inilah.
# Reference: "Percaya bahwa Hang Tuah dibunuh tidak adil oleh Sultan yang ia layani, Hang Jebat berbalik melawan Sultan untuk membalas kematian sahabatnya."
# BLEU Score: 0.2803
# --------------------------------------------------

# %%
# import torch
# import csv
# import numpy as np
# import os
# from nltk.translate.bleu_score import sentence_bleu
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# batch_size = 4
# translations = []
# bleu_scores = []

# # Open file once
# key=0
#     # Process in batches
# for i in range(0, len(data_test['src']), batch_size):
#     batch_inputs = data_test['src'][i:i + batch_size]
#     batch_references = data_test['tgt'][i:i + batch_size]

#     # Create prompts
#     prompt_template = """
# Translate the following sentences from English to Indonesian:

# English: {input_text}
# Indonesian:
# #answer
# """
#     batch_prompts = [prompt_template.format(input_text=input_text) for input_text in batch_inputs]

#     # Tokenize
#     inputs = tokenizer(batch_prompts, return_tensors="pt", padding=True, truncation=True, return_attention_mask=True).to("cuda")

#     # Generate translations
#     # generate_ids = model.generate(inputs['input_ids'], max_length=300)
#     with torch.amp.autocast('cuda'):
#         generate_ids = peft_model.generate(
#             input_ids=inputs["input_ids"],
#             max_new_tokens=300,
#             do_sample=True,
#             top_k=10,
#             top_p=0.9,
#             temperature=0.2,
#             repetition_penalty=1.15,
#             num_return_sequences=1,
#             eos_token_id=tokenizer.eos_token_id,
#         )
#     batch_outputs = tokenizer.batch_decode(generate_ids, skip_special_tokens=True)

#     # Extract translations and calculate BLEU
#     for idx, (input_text, output_text_real, output_text) in enumerate(zip(batch_inputs, batch_references, batch_outputs)):

#         # Extract the sentence one line below `#answer`
#         translated_text = ""
#         if "#answer" in output_text:
#             # Split by lines and find the text after '#answer'
#             lines = output_text.split("\n")
#             try:
#                 # index = lines.index("#answer") + 1  # Get the line after '#answer'
#                 index = next((i for i, line in enumerate(lines) if line.startswith("#answer")), -1) +1
#                 translated_text = lines[index].strip()  # Clean up any extra spaces
#                 translated_text = translated_text.replace("Indonesian:", "").strip()
#             except IndexError:
#                 translated_text = "Translation not found."
#         else:
#             translated_text = "No '#answer' marker in output."
#         # Calculate BLEU score for this sentence
#         bleu_score = sentence_bleu([output_text_real], translated_text)
#         with open('predictions_phi35_finetune_test.csv', mode='a', newline='') as file:
#             writer = csv.writer(file)
#             if not os.path.exists('predictions_phi35_finetune_test.csv'):
#                 writer.writerow(['Index', 'Input', 'Predicted Output', 'Correct Output', 'BLEU Score'])
#             writer.writerow([key + 1, input_text, translated_text, output_text_real, bleu_score])
#         # Print the results
#         print(f"Input: {input_text}")
#         print(f"Predicted: {translated_text}")
#         print(f"Reference: {output_text_real}")
#         print(f"BLEU Score: {bleu_score:.4f}")
#         print("-" * 50)
#         bleu_scores.append(bleu_score)
#         key +=1

# # Print average BLEU score
# print(f"Average BLEU Score: {np.mean(bleu_scores):.4f}")
