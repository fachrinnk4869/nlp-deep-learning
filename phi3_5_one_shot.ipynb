# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset

# Load the 'google/fleurs' dataset for 'hi_in' (Hindi - India)
dset = load_dataset("SEACrowd/indo_general_mt_en_id", trust_remote_code=True)

# %%
import torch
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM
checkpoint = "microsoft/Phi-3.5-mini-instruct"
tokenizer = AutoTokenizer.from_pretrained(checkpoint, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    checkpoint,
    torch_dtype=torch.bfloat16,  # Use bfloat16 for memory efficiency
    trust_remote_code=True,
    device_map="auto"  # Automatically map the model to available GPUs
)
# Out:
# 2024-12-15 16:54:33.653565: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-15 16:54:34.038726: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-15 16:54:34.038807: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-15 16:54:34.107724: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-15 16:54:34.248061: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-15 16:54:35.072731: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.

# %%
# Split the dataset into training, validation, and test sets
train_data = dset['train']
val_data = dset['validation']
test_data = dset['test']

# %%
pip install flash-attn
# Out:
# Requirement already satisfied: flash-attn in /home/fachri/nusax/.conda/lib/python3.11/site-packages (2.7.2.post1)
# Requirement already satisfied: torch in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from flash-attn) (2.5.1)
# Requirement already satisfied: einops in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from flash-attn) (0.8.0)
# Requirement already satisfied: filelock in /home/fachri/.local/lib/python3.11/site-packages (from torch->flash-attn) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/fachri/.local/lib/python3.11/site-packages (from torch->flash-attn) (4.12.2)
# Requirement already satisfied: networkx in /home/fachri/.local/lib/python3.11/site-packages (from torch->flash-attn) (3.4.2)
# Requirement already satisfied: jinja2 in /home/fachri/.local/lib/python3.11/site-packages (from torch->flash-attn) (3.1.4)
# Requirement already satisfied: fsspec in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/fachri/.local/lib/python3.11/site-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/fachri/nusax/.conda/lib/python3.11/site-packages (from torch->flash-attn) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/fachri/.local/lib/python3.11/site-packages (from torch->flash-attn) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fachri/.local/lib/python3.11/site-packages (from sympy==1.13.1->torch->flash-attn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fachri/.local/lib/python3.11/site-packages (from jinja2->torch->flash-attn) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import csv
import numpy as np
import os
from nltk.translate.bleu_score import sentence_bleu
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

batch_size = 4
translations = []
bleu_scores = []

# Open file once
key=0
    # Process in batches
for i in range(0, len(test_data['src']), batch_size):
    batch_inputs = test_data['src'][i:i + batch_size]
    batch_references = test_data['tgt'][i:i + batch_size]

    # Create prompts
    prompt_template = """
Translate the following sentences from English to Indonesian:

English: {input_text}
Indonesian:
#answer
"""
    batch_prompts = [prompt_template.format(input_text=input_text) for input_text in batch_inputs]

    # Tokenize
    inputs = tokenizer(batch_prompts, return_tensors="pt", padding=True, truncation=True, return_attention_mask=True).to(device)

    # Generate translations
    generate_ids = model.generate(inputs['input_ids'], max_length=300)
    batch_outputs = tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)

    # Extract translations and calculate BLEU
    for idx, (input_text, output_text_real, output_text) in enumerate(zip(batch_inputs, batch_references, batch_outputs)):

        # Extract the sentence one line below `#answer`
        translated_text = ""
        if "#answer" in output_text:
            # Split by lines and find the text after '#answer'
            lines = output_text.split("\n")
            try:
                index = lines.index("#answer") + 1  # Get the line after '#answer'
                translated_text = lines[index].strip()  # Clean up any extra spaces
                translated_text = translated_text.replace("Indonesian:", "").strip()
            except IndexError:
                translated_text = "Translation not found."
        else:
            translated_text = "No '#answer' marker in output."
        # Calculate BLEU score for this sentence
        bleu_score = sentence_bleu([output_text_real], translated_text)
        with open('predictions_phi35_test.csv', mode='a', newline='') as file:
            writer = csv.writer(file)
            if not os.path.exists('predictions_phi35_test.csv'):
                writer.writerow(['Index', 'Input', 'Predicted Output', 'Correct Output', 'BLEU Score'])
            writer.writerow([key + 1, input_text, translated_text, output_text_real, bleu_score])
        # Print the results
        print(f"Input: {input_text}")
        print(f"Predicted: {translated_text}")
        print(f"Reference: {output_text_real}")
        print(f"BLEU Score: {bleu_score:.4f}")
        print("-" * 50)
        bleu_scores.append(bleu_score)
        key +=1

# Print average BLEU score
print(f"Average BLEU Score: {np.mean(bleu_scores):.4f}")
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# `get_max_cache()` is deprecated for all Cache classes. Use `get_max_cache_shape()` instead. Calling `get_max_cache()` will raise error from v4.48
# You are not running the flash-attention implementation, expect numerical differences.
# Input: "Since the distribution of political power is determined by power over production, or power over capital, it is no surprise that the bourgeois class uses their wealth to legitimatize and protect their property and consequent social relations."
# Predicted: Dalam hal distribusi kekuasaan politik yang ditentukan oleh kekuasaan pada produksi atau kekuasaan kapital, tidak fantastis bahwa kelas baugean menggunakan kekayaan mereka untuk mendukung dan melindungi hak milik dan hubungan sosial yang disebabkan.
# Reference: "Dalam pandangan laissez-faire, kewajiban negara bukanlah melakukan intervensi untuk menstabilkan distribusi kekayaan atau untuk menjadikan sebuah negara makmur untuk melindungi rakyatnya dari kemiskinan, melainkan bersandar pada sumbangan dan sistem pasar."
# BLEU Score: 0.4321
# --------------------------------------------------
# Input: "According to his son and biographer Vinayak Mehta, he wanted to write a historical novel on the pivotal incident in the history of Gujarat."
# Predicted: Dasarkan dari anaknya dan biografi Vinayak Mehta, dia berharap menulis novel historis tentang peristiwa penting dalam sejarah Gujarat.
# Reference: Novelis Akmal Nasery Basral dan Haidar Musyafa masing-masing menulis novel dwilogi tentang kisah perjalanan Hamka.
# BLEU Score: 0.3427
# --------------------------------------------------
# Input: The acid catalyzed conversion of an enol to the keto form proceeds by a two step mechanism in an aqueous acidic solution.
# Predicted: Reaksi katalisasi konversi dari enol ke keto di dalam air aku berlangsung dua kali mekanisme di dalam lingkungan asam
# Reference: Konversi enol ke bentuk keto yang dikatalisis oleh asam dihasilkan oleh dua tahap mekanisme dalam larutan asam berair.
# BLEU Score: 0.5582
# --------------------------------------------------
# Input: "The global superiority of British military and commerce was aided by a divided and relatively weak continental Europe, and the presence of the Royal Navy on all of the world's oceans and seas."
# Predicted: Penggunaan kekuasaan militer dan bisnis global yang lebih tinggi oleh Britanya dipergantung pada kemiskinan dan pembagian yang kecil di kontinent Eropa, dan adanya Kesultanan Laut di semua laut dan samudra dunia.
# Reference: "Keunggulan perdagangan global dan militer Britania turut didukung oleh situasi negara-negara di benua Eropa yang sedang melemah, serta kehadiran Royal Navy di setiap laut dan samudera di seluruh dunia."
# BLEU Score: 0.4885
# --------------------------------------------------
# Input: "The resulting story, which may have been inspired by the 1936 musical comedy Three Smart Girls, was Tiga Dara."
# Predicted: Hadir cerita yang mungkin diinspirasi oleh komedian musik 1936 "Tiga Sisah Wanita," adalah Tiga.
# Reference: "Cerita yang dihasilkan, yang terinspirasi oleh film komedi musikal 1936 Three Smart Girls (Tiga Gadis Cerdas), adalah Tiga Dara."
# BLEU Score: 0.4387
# --------------------------------------------------
# Input: "Mars stated he wanted to improve his songwriting, shows, music videos, and make a better album than the previous two."
# Predicted: Mars mendukung karya lagu, video-skrip, dan membuat album yang lebih baik daripada album sebelumnya dua
# Reference: "Dia ingin untuk mengembangkan penulisan lagu, pertunjukan, video musiknya dan membuat sebuah album yang lebih baik dibandingkan dua album sebelumnya."
# BLEU Score: 0.4518
# --------------------------------------------------
# Input: "However, Sobekhotep III's mother was Jewhetibew whereas Neferhotep I, Sihathor and Sobekhotep IV were the sons of ""The King's Mother Kemi""."
# Predicted: selainnya, ibu Sobekhotep III adalah Jewhetibew, Sihathor, Neferhotep I dan Sobekhotep IV adalah anak-anak dari "Ibu Raja Kemi".
# Reference: "Ibu Sobekhotep III ibu adalah Jewhetibew sedangkan Neferhotep I, Sihathor dan Sobekhotep IV adalah anak-anak ""Ibu Suri Kemi""."
# BLEU Score: 0.7928
# --------------------------------------------------
# Input: "Korea portal List of border incidents involving North Korea Korean conflict Korean reunification North Korea–South Korea relations History of North Korea History of South Korea Partition of Vietnam Buzo, Adrian (2002)."
# Predicted: Korea portal List of border incidents involving North Korea Korean conflict Korean reunification North Korea–South Korea relations History of North Korea History of South Korea Partition of Vietnam Buzo, Adrian (2002).
# Reference: "Sejarah Korea Utara Sejarah Korea Selatan Penyatuan kembali Korea Partai Buruh Korea untuk informasi mengenai pembentukan Korea Utara ^ Perang Dunia II dan Korea Andrea Matles Savada dan William Shaw, editor."
# BLEU Score: 0.3075
# --------------------------------------------------
# Input: "Each labourer produces only some part of a whole, and each part having no value or utility of itself, there is nothing on which the labourer can seize, and say: 'This is my product, this will I keep to myself'""."
# Predicted: "Setiap pekerjaanannya hanya menghasilkan bagian kecil dari keseluruhan, dan setiap bagian itu tidak memiliki nilai atau kegunaan sendiri, jadi tidak ada yang diperintahkan pekerjaanannya untuk menyaksikan, 'Ini adalah produk saya, ini akan saya tinggal sendiri'"
# Reference: "Setiap buruh hanya memproduksi beberapa bagian dari keseluruhan, dan setiap bagian tak memiliki nilai atau manfaat sendiri, tak ada buruh yang dapat merebut, dan berrkata: 'Ini adalah produkku, ini akan aku simpan sendiri'""."
# BLEU Score: 0.5803
# --------------------------------------------------
# Input: "Although Jinnah did not win the Caucus Case, he posted a successful record, becoming well known for his advocacy and legal logic."
# Predicted: Jinnah tidak menang dalam Kasus Caucus, tetapi dikenal dirinya untuk pembelajaran dan logika hukum yang berhasil, menjadi terkenal.
# Reference: "Meskipun Jinnah tidak memenangkan Kasus Kaukus, ia sukses mencetak rekor, menjadikannya dikenal karena advokasi dan logika hukumnya."
# BLEU Score: 0.5374
# --------------------------------------------------
# Input: "Total authorized capital and paid up capital of the companies limited by shares amounted to Rs.50 billion and Rs.2 billion, respectively."
# Predicted: Total authorized capital dan capital yang diberikan oleh perusahaan terbatas sebesar Rs.50 juta dan Rs.2 juta, kemudian
# Reference: "Asuransi Marannu disertai dengan peningkatan modal dasar dan modal disetor, masing-masing menjadi Rp.60 miliar dan Rp.15 miliar."
# BLEU Score: 0.2112
# --------------------------------------------------
# Input: "In particular, he was a fine scholar and performer of music by J. S. Bach."
# Predicted: In particular, it was a fine scholar and performer of music by J. S. Bach.
# Reference: "Ia pada awalnya belajar musik gereja yang bercorak Lutheran, dan berguru pada J.S Bach."
# BLEU Score: 0.1884
# --------------------------------------------------
# Input: She fought in various battles alongside the Tokugawa clan.
# Predicted:
# Reference: Ia bertarung dalam berbagai pertempuran bersama klan Tokugawa.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "Other major ethnic groups counted in the 1926 census were Armenians (25,677, or 12.7 percent), Greeks (14,045, or 7 percent), and Russians (12,553, or 6.2 percent)."
# Predicted: "Golongan etnis lain yang diukur dalam kepulauan 1926 adalah Armenia (25,677, atau 12,7 persen), Grieks (14,045, atau 7 persen), dan Rusia (12,553, atau 6,2 persen)."
# Reference: "Sementara itu, kelompok etnis besar lainnya yang dihitung dalam sensus tahun 1926 adalah orang Armenia (25.677 atau 12,7%), orang Yunani (14.045, atau 7%), dan orang Rusia (12.553, atau 6,2%)."
# BLEU Score: 0.5292
# --------------------------------------------------
# Input: "The Canadian Kennel Club also recognizes these breeds, as well as the American Staffordshire Terrier."
# Predicted: The Australian Shepherd is a breed of dog that originated in Australia. It is a medium-sized, short-coated, hardy, and versatile breed. The Australian Shepherd is a medium-sized, short-coated, hardy, and versatile breed.
# Reference: "Canadian Kennel Club juga mengakui trah ini, dan juga American Staffordshire Terrier."
# BLEU Score: 0.0720
# --------------------------------------------------
# Input: The Mancunion is based within the Students' Union but retains editorial independence from it.
# Predicted:
# Reference: Daerah ini berada dalam wilayah Edom tetapi tidak dikuasai oleh Edom seluruhnya.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: He is also a highly revered saint in the Coptic Orthodox Church of Alexandria and other churches of Oriental Orthodoxy.
# Predicted: Dia juga dipercaya sangat diri di Gereja Orta Oriental di Alexandria dan diandaan Gereja-gereja Orta Oriental lainnya.
# Reference: Ia juga merupakan orang kudus paling dimuliakan dalam Gereja Ortodoks Koptik Aleksandria dan gereja-gereja Ortodoks Oriental lainnya.
# BLEU Score: 0.5215
# --------------------------------------------------
# Input: "On March 2017, he joined Bali United on a one year-contract, to team up with old friend of Ajax, Irfan Bachdim."
# Predicted: Pada Maret 2017, dia ikut Bali United dengan kontrakt satu tahun, untuk menyerahkan diri dengan teman tua dari Ajax, Irfan Bachdim.
# Reference: "Pada Maret 2017, ia bergabung dengan Bali United pada satu tahun kontrak, untuk bekerjasama dengan teman lama dari Ajax, Irfan Bachdim."
# BLEU Score: 0.7256
# --------------------------------------------------
# Input: "Within half an hour, the lead roof was melting, and the books and papers in the crypt caught with a roar."
# Predicted: Dengan waktu seperempat saat, kandungan atap tersebut melemah, dan buku-buku dan tulisan di krypton terbentang dengan suara yang kencang.
# Reference: "Dalam waktu setengah jam, atap timbal mencair, buku-buku dan kertas-kertas di ruang bawah tanah katedral menyerbuk dimamah api."
# BLEU Score: 0.3803
# --------------------------------------------------
# Input: Good afternoon.
# Predicted:
# Reference: Selamat siang.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "(At that time, the Royal Malaysian Navy; RMN main base was known as KD Malaya (Kapal Diraja Malaya; His Majesty's Ship Malaya), formerly known as HMS Malaya before independence, in Woodlands, Singapore, which was later transferred to the new naval base in Lumut, Perak when it was completed in 1979."
# Predicted: Pada zaman tersebut, Pusat Tentara Laut Malaysia (RMN) diperlakukan sebagai KD Malaya (Kapal Diraja Malaya; Kapal Yang Diraja Malaya), sebelumnya dikenal sebagai HMS Malaya sebelum kemerdekaan, di Kampung Woodlands, Singapor, yang kemudian dipergantian ke pusat laut baru di Lumut, Perak ketika itu selesai pada tahun 1979.
# Reference: "Pada saat itu, basis utama TLDM dikenal sebagai KD Malaya (Kapal Diraja Malaya), sebelumnya dikenal sebagai HMS Malaya sebelum kemerdekaan, di Woodlands, Singapura yang kemudian ditransfer ke pangkalan angkatan laut baru di Lumut, Perak ketika selesai tahun 1979."
# BLEU Score: 0.6745
# --------------------------------------------------
# Input: "1933: Richard Edwin Shope discovered cottontail rabbit papillomavirus or Shope papillomavirus, the first mammalian tumor virus."
# Predicted: The term "Shope papilloma" is a misspelling term that is not recognized in the English language. It seems to be a misspelling or a typographical the term "Shope papilloma" might be a misspellingth or a typothe term from another question.
# Reference: "Pada tahun 1933, Shope papilloma virus atau cottontail rabbit papilloma virus (CRPV)yang ditemukan oleh Dr Richard E Shope merupakan model kanker pertama pada manusia yang disebabkan oleh virus."
# BLEU Score: 0.2253
# --------------------------------------------------
# Input: "The changing chemical composition of the lake means that it changes colors often, ranging from red, dark green, and even to dark blue."
# Predicted:
# Reference: "Komposisi kimiawi yang berubah dari danau berarti warnanya sering berubah warna, mulai dari merah, hijau tua, dan bahkan biru gelap."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "On 23 May 1947, Ann Hui was born in Anshan, Liaoning province, Manchuria to a Chinese father and a Japanese mother."
# Predicted: :
# Reference: "Pada 23 Mei 1947, Ann Hui lahir di Anshan, provinsi Liaoning, Manchuria dari ayah Tionghoa dan ibu Jepang."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "Wahi started his acting career with the 2004 ""Rose Audio Visuals"" television series Remix, where he portrayed the lead role of Ranveer Sisodia, the angry lover boy character, opposite Shweta Gulati."
# Predicted: Wahi memulai kariernya diisi dunia sinema dengan seri televisi 2004 "Rose Audio Visuals", di mana dia menggambar peran utama Ranveer Sisodia, karakter kepompong gembira di sisi Shweta Gulati.
# Reference: "Wahi memulai karier aktingnya dengan serial televisi ""Rose Audio Visuals"" 2004 , Remix , di mana dia menggambarkan peran utama Ranveer Sisodia, karakter anak laki-laki yang marah, berlawanan dengan Shweta Gulati."
# BLEU Score: 0.6680
# --------------------------------------------------
# Input: He founded the Janspeed automotive engineering company and racing team.
# Predicted:
# Reference: Tugasnya adalah menangani fasilitas tes Reynard dan bisnis konsultan engineering.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "In 1998, the total population of the West Indian Ocean coelacanth was estimated to have been 500 or fewer, a number that would threaten the survival of the species."
# Predicted: Tahun 1998, jumlah kitajen laut Indo Barat di estimasi telah lebih dari 500, sehingga dapat merusaknya kelangsungan spesiesnya.
# Reference: "Pada tahun 1998, total populasi coelacanth Samudra Hindia Barat diperkirakan berjumlah 500 atau lebih sedikit, jumlah yang sangat kecil yang mengancam kelangsungan hidup spesies ini."
# BLEU Score: 0.3679
# --------------------------------------------------
# Input: Wae (spreaders) were made from the curved stilt roots of ʻōhiʻa.
# Predicted: Wae (spreaders) are made from the stilt roots of ʻōhiʻa.
# Reference: Kemaron besar yaitu wadah terbuat dari tanah liat (dibakar menjadi warna merah bata).
# BLEU Score: 0.0000
# --------------------------------------------------
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Input: "In the aftermath of that attack, Morocco became a focus of attention for anti-terrorist authorities in Spain."
# Predicted: Setiap setelah peristiattakan, Morocco menjadi fokus pembohongan pemerintah Spanyol untuk menghadapi peristiattakan.
# Reference: "Setelah peristiwa ini, Christiane menjadi seorang pendukung fanatik partai sosialis."
# BLEU Score: 0.3318
# --------------------------------------------------
# Input: "Those factions loyal to Siad Barre, especially amongst his own Marehan clan, formed the Somali National Front after he was deposed from power, were based primarily in this region, where they withdrew to following the end of the civil war."
# Predicted: "Fraksi-fraksi yang tulus kepada Siad Barre, khususnya di kelompok Marehannya, membentuk Somali National Front setelah dia dibongkar dari kekuasaan, berbasis secara khusus di wilayah ini, dan menyusui setelah berakhirnya perang kota."
# Reference: "Faksi-faksi yang setia kepada Siad Barre, terutama dari klannya sendiri, Marehan, membentuk Front Nasional Somalia setelah dia digulingkan dari kekuasaan, sebagian besar berbasis di wilayah ini, dimana mereka menarik diri untuk mengikuti berakhirnya perang sipil."
# BLEU Score: 0.6225
# --------------------------------------------------
# Input: "Mukhtaran reportedly told Attiya Inayatullah, the Women’s Development Minister who gave her the cheque that she ""would have committed suicide if the government had not come to her help."""
# Predicted: Mukhtaran beriturkan kepada Attiya Inayatullah, Menteri Pembangunan Wanita yang menyampaikan bahwa dia "seharusnya menembus diri jika pemerintah tidak membantu"
# Reference: "Mukhtaran konon mengatakan kepada Attiya Inayatullah, Menteri Pengembangan Perempuan yang memberikan cek itu kepadanya bahwa ia ""tentu sudah bunuh diri andaikan pemerintah tidak datang untuk menolongnya."""
# BLEU Score: 0.5400
# --------------------------------------------------
# Input: It is uncertain how many speakers survive; the dialect could be moribund.
# Predicted: The word "moribund" (#1 in Indonesian is "moribund" and which translates to "moribund" in English. It is used to describe someone who is on the brink of death or in a state of extreme weakness or frailty.
# Reference: Masih belum diketahui berapa banyak penutur bahasa ini yang masih hidup; dialek ini bahkan mungkin sudah mati.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "At WrestleMania 21, Jericho participated in the first ever Money in the Bank ladder match."
# Predicted:
# Reference: "Di WrestleMania 21, Edge menang pertandingan tangga Money in the Bank yang pertama kali."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "On 27 June, the day before the first date, Entwistle was found dead of a heart attack at 57 at the Hard Rock Hotel in Las Vegas."
# Predicted: 27 Juni 27, hari sebelum pertama dari tanggal ini, Entwistle telah meninggal akhir di Hard Rock Hotel di Las Vegas.
# Reference: "Pada 27 Juni 2002, tepat sebelum dimulainya tur mereka di Amerika Serikat, Entwistle ditemukan meninggal di Hard Rock Hotel Las Vegas."
# BLEU Score: 0.5569
# --------------------------------------------------
# Input: "Adapted from Ben Mezrich's 2009 book The Accidental Billionaires: The Founding of Facebook, a Tale of Sex, Money, Genius and Betrayal, the film portrays the founding of social networking website Facebook and the resulting lawsuits."
# Predicted: Adaptasi dari buku Ben Mezrich tahun 2009, "The Accidental Billionaires: The Founding of Facebook, a Tale of Sex, Money, Genius and Betrayal", film menggambarkan perkembangan situs berbasis sosial Facebook dan keluaran hukum yang diikuti.
# Reference: "The Accidental Billionaires: The Founding of Facebook, A Tale of Sex, Money, Genius, and Betrayal adalah sebuah buku tahun 2009 karya Ben Mezrich yang bercerita tentang pendirian Facebook."
# BLEU Score: 0.6213
# --------------------------------------------------
# Input: "If she cannot be found, the Moon Orb will find her."
# Predicted:
# Reference: "Jika tidak ditemukan, maka kemudian melihat sunnah."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: These forces included a naval force operating on the Shannon.
# Predicted: The word "Shannon" is a name that can be derived from the name of a river in Ireland. It is a town in County Clare, located in the province of Clare, Ireland.
# Reference: Perusahaan ini juga memiliki armada bus yang dioperasikan di negara bagian Penang.
# BLEU Score: 0.0529
# --------------------------------------------------
# Input: "The series is published in HDTV format and broadcasts on TV3 began on 13 March 2011, on Disney Channel Asia from 11 June 2011 and on NTV7 from 24 May 2014."
# Predicted: Seri tersebut dipublikasikan dalam format HDTV dan seringkali terdengar di TV3, mulai pada 13 Maret 2011 di Disney Channel Asia dan pada 24 Mei 2014 di NTV7.
# Reference: "Serial BoBoiBoy ditayangkan dalam format gambar HDTV, dan disiarkan di TV3 mulai 13 Maret 2011, serta di Disney Channel Asia mulai 18 Juni 2011."
# BLEU Score: 0.5731
# --------------------------------------------------
# Input: "On August 10, the group performed the song on the popular Japanese music program, Coming Soon!!"
# Predicted: 10 Agustus, kelompok itu melaksanak lagu dalam program musik yang populer di Japan, Coming Soon!
# Reference: "Pada 10 Agustus 2011, Secret menampilkan versi Jepang ""Madonna"" di acara musik ""Coming Soon!!"""
# BLEU Score: 0.3873
# --------------------------------------------------
# Input: A Short History of Biblical Interpretation.
# Predicted:
# Reference: Sejarah Singkat Penafsiran Alkitab.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "The biscuit joining system was invented in 1956 in Liestal, Switzerland by Hermann Steiner."
# Predicted: "Sistem kekusuhan bisuit diinventasikan pada tahun 1956 di Liestal, Sukarela, Suzana
# Reference: Alat ini ditemukan pada tahun 1956 di Liestal Swiss oleh Hermann Steiner.
# BLEU Score: 0.4704
# --------------------------------------------------
# Input: "Soon afterward, the Polish army started massing for an expedition against the Ottomans, and in August was joined by Bavarians and Saxon allies under Charles of Lorraine."
# Predicted: Setelah itu, Tentara Polanya mulai menggabungkan jumlah besar untuk perjalanan ekspedisi terhadap Ottoman, dan pada Agustus diikuti oleh alliansi Bavarians dan Saxon dibantu oleh Charlesa Lorraine.
# Reference: "Pada bulan Agustus, bala tentara sekutu dari Bayern dan Sachsen datang bergabung, di bawah pimpinan Karl dari Lothringen."
# BLEU Score: 0.2646
# --------------------------------------------------
# Input: The cemetery was established in 1891 by Peter Wall.
# Predicted: The cemetery was established in 1891 by Peter Wall.
# Reference: Makam itu ditemukan pada tahun 1894 oleh Jacques de Morgan.
# BLEU Score: 0.1180
# --------------------------------------------------
# Input: "Later that year, though, when selecting a new empress, she was considered."
# Predicted: Later that year, when selecting a new empress, was considered.
# Reference: "Kemudian pada tahun itu, ketika sedang memilih seorang permaisuri yang baru, ia dipertimbangkan sebagai calonnya."
# BLEU Score: 0.0517
# --------------------------------------------------
# Input: "The Complex of Goguryeo Tombs lies in Pyongyang, Pyong'an South Province, and Nampo City, South Hwanghae Province, North Korea."
# Predicted: Goguryeo Tombs, Pyongyang, Pyong'an, South Hwanghae Province, North Korea
# Reference: "Komplek Makam Goguryeo berada di wilayah negara Korea Utara, seperti di Pyongyang, provinsi Pyongan Selatan, dan kota Nampo (Hwanghae Selatan)."
# BLEU Score: 0.2282
# --------------------------------------------------
# Input: This caused great grief to her husband.
# Predicted: The word "Indian" is is a noun that refers to a person from a person from India.
# Reference: Sangat mungkin dia berkabung secara tulus untuk suaminya.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "Kraemer lost his parents when he was 12 years old, so he stayed in an orphanage."
# Predicted: Kraken was 12 years old when he stayed in an orphanage.
# Reference: Kraemer kehilangan orang tuanya pada usia 12 tahun sehingga ia tinggal di panti asuhan.
# BLEU Score: 0.1236
# --------------------------------------------------
# Input: Vincent Willem van Gogh (Dutch:  (listen); 30 March 1853 – 29 July 1890) was a Dutch Post-Impressionist painter who is among the most famous and influential figures in the history of Western art.
# Predicted: Vincent Willem van Gogh (Dutch: (listen); 30 Maret 1853 – 29 Juli 1890) adalah pemain saksi Post-Impressionisme Belanda yang dianggap salah satu dari para para terkemuka dan mempengaruhi dunia saksi-saksi modernisme di Asia Timur.
# Reference: "Vincent Willem van Gogh (Belanda:   ( dengarkan); (lahir di Zundert, Belanda, 30 Maret 1853 – meninggal di Auvers-sur-Oise, Prancis, 29 Juli 1890 pada umur 37 tahun) adalah seorang pelukis pascaimpresionis Belanda yang menjadi salah satu tokoh paling terkenal dan berpengaruh dalam sejarah seni di Barat."
# BLEU Score: 0.4352
# --------------------------------------------------
# Input: "To start off the F/W 2017 season, Hadid walked for Alexander Wang, Sies Marjan, Carolina Herrera, Brandom Maxwell, Michael Kors, Anna Sue, Ralph Lauren; and opened for Prabal Gurung and Zadig et Voltaire; and closed for Oscar de la Renta, during NYFW."
# Predicted: Untuk memulai musim F/W 2017, Hadid berjalan untuk Alexander Wang, Sies Marjan, Carolina Herrera, Brandom Maxwell, Michael Kors, Anna Sue, Ralph Lauren; dan menghadapi Prabal Gurung dan Zadig et Voltaire; dan akhirnya menghadapi Oscar de la Renta di NYFW.
# Reference: "Untuk memulai musim F/W 2017, Hadid menjadi model catwalk di Alexander Wang, Sies Marjan, Carolina Herrera, Brandom Maxwell, Michael Kors, Anna Sue, Ralph Lauren; dan membuka pertunjukan untuk Prabal Gurung dan Zadig et Voltaire; dan menutup untuk Oscar de la Renta, selama NYFW."
# BLEU Score: 0.7926
# --------------------------------------------------
# Input: The hyperactive squirrel This is derived from their extreme speed.
# Predicted: daugh
# Reference: Hiperplasia ini terjadi dengan kecepatan yang signifikan.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: The Belarusian ruble or rouble (Belarusian: рубель rubieĺ; sign: Br; code: BYN) is the official currency of Belarus.
# Predicted: The official currency of Belarus is the Belarusian ruble (Belarusian: беларускі рубль, ISO 4217: BYN).
# Reference: "Rubel Belarusia atau rouble (bahasa Belarus: рубель rubieĺ, jamak: рублі rubli, jamak genitif: рублёў rublioŭ) adalah mata uang resmi Belarus."
# BLEU Score: 0.2632
# --------------------------------------------------
# Input: The agglutinates form at the lunar surface by micrometeorite impacts that cause small-scale melting which fuses adjacent materials together with tiny specks of metallic iron (Fe0) embedded in each dust particle’s glassy shell.
# Predicted: Aglutinates diperasan pada permuka lunar dengan impacts micrometeoris yang menyebabkan pembentukan kristal kecil yang mengandungan kristal logamet iron (Fe0) di dalam setiap partikel keramat.
# Reference: Aglutinat yang terbentuk di permukaan bulan oleh dampak mikrometeorit menyebabkan pelelehan skala kecil yang menyatukan bahan yang berdekatan bersama-sama dengan bintik kecil besi logam (Fe0) yang tersematkan di setiap kepingan kaca partikel debu.
# BLEU Score: 0.4757
# --------------------------------------------------
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Input: This period ended in 1127 when the city fell to Jurchen invaders during the Jingkang Incident.
# Predicted: Periode ini berakhir pada tahun 1127 ketika kota terancam oleh peladjar Jurchen pada peristiwa Jingkang.
# Reference: "Periode ini berakhir pada 1127, ketika kota ini jatuh ke tangan para penyerbu Jurchen dan kemudian jatuh ke tangan pemerintahan Dinasti Jin."
# BLEU Score: 0.4491
# --------------------------------------------------
# Input: Foremost among many changes is that forests are today centre-stage in the global debate on how to tackle climate change.
# Predicted: Di atas banyak perubahan, salah satu perubahan utama adalah bahwa hutan saat ini menjadi pusat perdebatan global tentang cara menghadapi perubahan iklim.
# Reference: Dari semua perubahan tersebut yang terpenting adalah hutan saat ini menjadi poros perdebatan global tentang perubahan Iklim.
# BLEU Score: 0.5709
# --------------------------------------------------
# Input: Unencrypted satellite feeds allowed anyone with the correct equipment to view the program material.
# Predicted: Pembukaan feed satelit yang tidak kunci membuat setiap orang yang memiliki alat yang sesuai dapat melihat materi programnya.
# Reference: Umpan satelit yang tidak terenkripsi memungkinkan siapa pun dengan peralatan yang benar untuk melihat materi program.
# BLEU Score: 0.5129
# --------------------------------------------------
# Input: Iron-deficiency anemia can cause mental retardation and growth insufficiency in children.
# Predicted: Defekan besi-besi dapat menyebabkan retardasi mental dan insufikasi pertumbuhan anak
# Reference: Kretinisme adalah penyakit hipotiroidisme bawaan yang dapat menyebabkan keterbelakangan mental dan kelainan pertumbuhan pada anak.
# BLEU Score: 0.3564
# --------------------------------------------------
# Input: "Technical analysis employs models and trading rules based on price and volume transformations, such as the relative strength index, moving averages, regressions, inter-market and intra-market price correlations, business cycles, stock market cycles or, classically, through recognition of chart patterns."
# Predicted: The term "technical analysis" refers to the study of price and volume data of a security, with the aim of identifying and interpreting the underlying trends and patterns that drive the price of a security.
# Reference: "Analisis teknikal dapat menggunakan berbagai model dan dasar misalnya, untuk pergerakan harga digunakan metode seperti misalnya Indeks Kekuatan Relatif, Indeks pergerakan rata-rata, regresi, korelasi antar pasar dan intra pasar, siklus ataupun dengan cara klasik yaitu menganalisis pola grafik."
# BLEU Score: 0.0869
# --------------------------------------------------
# Input: "Mansour Rahbani (Arabic: منصور الرحباني, Manṣūr Al-Raḥbāni‎), (March 17, 1925 – January 13, 2009) was a Lebanese composer, musician, poet, philosopher, thinker and producer, known as one of the Rahbani brothers, and the brother-in-law of the famous singer Fairuz."
# Predicted: Manṣūr Al-Raḥbāni (17 March 1925 – 13 Januari 2009) adalah komponen, musiker, poet, filosof, pensiaster, dan produsen yang dikenal sebagai satu dari Rahbani bersama-sama dengan suami Fairuz, seorang artis pop Lebanese.
# Reference: "Mansour Rahbani (bahasa Arab: منصور الرحباني, Manṣūr Al-Raḥbāni‎), (lahir 17 Maret 1925 – meninggal 13 Januari 2009 pada umur 83 tahun) adalah seorang komponis, musisi, penyair, filsuf, pemikir dan produser rekaman asal Lebanon."
# BLEU Score: 0.5118
# --------------------------------------------------
# Input: "Yan Baihu had become the head of a loose confederation composed of bandits and local officials, including Wang Lang, and he again gathered soldiers numbering tens of thousands."
# Predicted: daughers of the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19th century, the 19
# Reference: "Yan Baihu telah menjadi kepala konfederasi longgar yang terdiri dari bandit dan pejabat lokal, termasuk Wang Lang, dan dia kembali mengumpulkan tentara berjumlah puluhan ribu."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "In Roman areas, this was done using ceramic containers known as briquetage."
# Predicted: let' daugh
# Reference: "Di daerah Banyumas, wayang gremeng dikenal dengan nama wayang jemblung."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "He then went to the University of Kristiania (now University of Oslo), graduating in medicine in 1922."
# Predicted: Saya sampai menjatuhkan di Universitas Kristiania (sekarang Universitas Oslo) di 1922.
# Reference: "Kemudiabn, ia pergi ke Universitas Kristiania di Oslo dan lulus kedokteran pada tahun 1922."
# BLEU Score: 0.4546
# --------------------------------------------------
# Input: Šćepan Polje (pronounced ) is a village in Montenegro.
# Predicted:
# Reference: Polski Senovets ) merupakan desa di Bulgaria.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "Before databases can be mined for data using evolutionary algorithms, it first has to be cleaned, which means incomplete, noisy or inconsistent data should be repaired."
# Predicted: Dibelakang data sebelum dapat dipelukusi menggunakan algoritma evolusi, sebaiknya dibersihakan, yang artinya tidak lengkap, kosong atau tidak konsisten.
# Reference: Sedangkan pada data mining dilakukan proses yang dimulai dari data yang tidak terstruktur lalu diekstrak agar mendapatkan suatu pengetahuan ataupun sebuah pola yang belum diketahui.
# BLEU Score: 0.3378
# --------------------------------------------------
# Input: "He was married to Upasika Pandita Vimaladewi Salim, S.H. (Chinese: Oei Lat Nio), who died on April 16, 2017 at the age of 88 years old."
# Predicted: "Dia perkawinan Upasika Pandita Vimaladewi Salim, S.H. (Chinese: Oei Lat Nio), yang mati pada tanggal 16 April 2017 dengan usia 88 tahun."
# Reference: "Ia menikahi Upasika Pandita Vimaladewi Salim, S.H. (Tionghoa: Oei Lat Nio), yang meninggal pada 16 April 2017 pada usia 88 tahun."
# BLEU Score: 0.7531
# --------------------------------------------------
# Input: "They also commanded that whenever a new batch of Holy Myron was made, they add to it the old holy myron to keep the first holy myron continually with all that would ever be made afterwards."
# Predicted: "Maka pun juga, ketika dibuat umpan baru dari Holy Myron, dipadatkan pada itu old Holy Myron untuk mengelupasi peringatan perintah awal Holy Myron selama semua yang dibuat seterusnya."
# Reference: "Mereka juga memerintahkan bahwa setiap kali suatu batch baru dari Kudus Myron dibuat, mereka menambahkan untuk itu suci tua myron untuk menjaga pertama kudus myron terus dengan semua yang akan dibuat setelah itu."
# BLEU Score: 0.4721
# --------------------------------------------------
# Input: "Ich faints, and everyone returns to Manderley."
# Predicted:
# Reference: "Seusai perkawinan, mereka semua kembali ke Kuparman."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "Other type of house is uma kamadungu (""bald house"") which contains no central peak."
# Predicted: Umuran rumah adalah rumah yang tidak memiliki puncak
# Reference: "Jenis lainnya adalah rumah uma kamadungu (""rumah botak"") yang tidak memiliki puncak tengah."
# BLEU Score: 0.3728
# --------------------------------------------------
# Input: American General Mark Clark secretly lands in Algeria to confer with Vichy officials and Resistance groups in preparation for impending Allied invasion.
# Predicted: Amerika Generaal Mark Clark terserakan dengan anggota Vichy dan kelompok Resisten sebelum persenyalewa Allied invasion
# Reference: 22: Jenderal Amerika Mark Clark secara terang-terangan mendarat di Aljazair untuk bergabung dengan petinggi Vichy dan grup Pemberontak dalam persiapan serangan Sekutu selanjutnya.
# BLEU Score: 0.3067
# --------------------------------------------------
# Input: "Celebrations were different in every state, depending on each one's traditions and culture."
# Predicted: The word "celebration" is is a noun that refers to a festive or joyous occasion or event, often marked by special activities, gatherings, or ceremonies. It is derived from from the Latin word "celebrare," which means "to honor" or "to celebrate." The term is commonly used to describe a variety of events, such as birthdays, holidays, weddings, anniversaries, and other significant milestones.
# Reference: Hari khusus ini berbeda-beda di setiap negara atau kebudayaan.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "They thus claim that current evolutionary theory is likely to undergo such a revolution in the future, on the basis that it is a ""theory in crisis"" for one reason or another."
# Predicted: The Indonesian translation for "They thus claim that the current evolutionary theory is likely to undergo a revolution in the future, on the basis that it is a theory in crisis for one reason or another.
# Reference: "Sehingga mereka mengklaim bahwa teori evolusi modern sangat mungkin menjalani revolusi seperti itu pada masa depan dengan dasar bahwa evolusi adalah ""teori dalam krisis""."
# BLEU Score: 0.1861
# --------------------------------------------------
# Input: "In narrower usage, platonism, rendered as a common noun, refers to the philosophy that affirms the existence of abstract objects, which are asserted to ""exist"" in a ""third realm"" distinct both from the sensible external world and from the internal world of consciousness, and is the opposite of nominalism."
# Predicted: Dalam ketergantungan ketebalan ketentuan, platonisme, diubah sebagai nama kelas, merujuk pada filosofi yang mengkonfirmasikan adanya objek abstrak, yang dianggap memiliki kelangsungan di "realm ketiga" yang berbeda dari dunia sensori luar dan dunia kebijaksanaan internal, dan merupakan tujuhlawan dari nominalisme.
# Reference: "Secara sempit, penggunaan platonisme, sebagai nama jenis (dengan huruf ""p"" kecil), mengacu pada filsafat yang mengakui keberadaan objek-objek abstrak, yang diyakini ""ada"" di suatu ""alam ketiga"" yang berbeda baik dari alam eksternal yang dapat diindrai maupun dari alam internal kesadaran, dan merupakan lawan dari nominalisme."
# BLEU Score: 0.5731
# --------------------------------------------------
# Input: "The festival opened with the US film Moonrise Kingdom, directed by Wes Anderson and closed with the late Claude Miller's final film Thérèse Desqueyroux."
# Predicted: The film The Moon is a 1999 American drama film directed by Wes Anderson and starring Bill Murray, John Cusack, and John Goodman. It is based on the 1985 novel of the same name by John Irving.
# Reference: "Festival dibuka dengan film AS Moonrise Kingdom, disutradarai oleh Wes Anderson dan ditutup dengan akhir film final Claude Miller, Thérèse Desqueyroux."
# BLEU Score: 0.2525
# --------------------------------------------------
# Input: "A Mangy is Damned, 2008."
# Predicted:
# Reference: "Alkisah, Silampukau menetas pada 2008 silam."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "The 1970 Bhola cyclone made landfall on the East Pakistan coastline during the evening of 12 November, around the same time as a local high tide, killing an estimated 300,000 to 500,000 people."
# Predicted: "Benda bintang 1970 Bhola memasuki pantai Utara Pakistan pada malam hari 12 November, sekitar waktu kali tinggi lokal, menyebabkan kematian estimasi 300,000 hingga 500,000 orang."
# Reference: "Siklon Bhola 1970 tiba di pantai Pakistan Timur pada sore tanggal 12 November, dalam waktu yang sama dengan air pasang lokal, menyebabkan kira-kira 300.000 sampai 500.000 orang tewas."
# BLEU Score: 0.5723
# --------------------------------------------------
# Input: Average attendances since 1992.
# Predicted:
# Reference: Yayasan LKiS berdiri sejak 1992.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: """France Football's World Cup Top-100 1930–1990""."
# Predicted: The 1930s The 1930s The 1930s The 1930s The 1930s The 1930s The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 1930 The 193
# Reference: "Daftar final Kejuaraan Sepak Bola Eropa UEFA Utama ""World Cup 1930-2010""."
# BLEU Score: 0.0146
# --------------------------------------------------
# Input: "Caffa Cembalo Soldaia Vosporo Sarsona Capitanatu Gotia (territory of Theodoro) Aside of Crimea, Genoa possessed several castles on the western coast of Black Sea such as the castle of Maurocastro (Bilhorod-Dnistrovsky) in the estuary of Dniester, the castle of Ginestra near Odessa, the castle of Licostomo (Kiliya), the colony of Constanca, the colony of Caladda (upstream of Danube)."
# Predicted: Perangkat Caffa Cembalo Soldaia Vosporo Sarsona Gotia (territori Theodoro) di luar Crimea, Genoa memiliki banyak kastilah di utara Laut Black Sea seperti kastilah Maurocastro (Bilhorod-Dnistrovsky) di estuari Dniester, kastilah Ginestra dean Odessa, kastilah Licostomo (Kiliya), koloni Constanca, koloni Caladda (atas Danube).
# Reference: "Selain di Krimea, Genova juga menguasai beberapa kastil di pesisir barat Laut Hitam, seperti kastil Maurocastro (Bilhorod-Dnistrovsky) di muara Sungai Dniester, kastil Ginestra di dekatOdessa, kastil Licostomo (Kiliya), koloni Constanca serta koloni Caladda (di kawasan Sungai Donau)."
# BLEU Score: 0.6078
# --------------------------------------------------
# Input: "Fendrich’s writing began with the publication of an essay in The Chronicle of Higher Education (1999) entitled, “Why Painting Still Matters,” which later became the basis for a short book."
# Predicted: The Chronicle of Higher Education
# Reference: "Banyak pelajaran yang disampaikan Alberto yang dimulai dengan pertanyaan singkat (seperti ""Mengapa Lego merupakan mainan yang paling kreatif di dunia?"") dan dia diberikan waktu untuk berpikir sebelum pelajaran berikutnya tiba."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: """IPB Kini Rebranding Jadi 'IPB University', Apa Alasannya?"". detiknews (in Indonesian)."
# Predicted: :**:
# Reference: """IPB Kini Rebranding Jadi 'IPB University', Apa Alasannya?"". detiknews."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: 1878: Joseph Hudson makes the first whistle ever to be used by a football referee.
# Predicted: daugh
# Reference: "Pada tahun 1868, Joseph Hudson dari Birmingham, Inggris, membuat peluit pertama yang digunakan oleh wasit sepak bola."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "If the model is overidentified, there is information available which may be used to test this assumption."
# Predicted: Jika model ini overidentifikasi, ada informasi yang bisa digunakan untuk menguas kegira tersebut.
# Reference: Digit yang tersisa dapat ditampilkan/ditebak atas informasi ini..
# BLEU Score: 0.3197
# --------------------------------------------------
# Input: "After its publication, Germany retaliated against Italy, freeing Mussolini and attacking Italian forces in Italy, the South of France and the Balkans."
# Predicted: Setelah publikasi, Jerman menanggapi Italia, mengembangkannya Mussolini dan melancarkan keseluruhan keselamatan Italia di Belanda Selatan, Balkan dan Lautan Timur.
# Reference: "Setelah penerbitannya, Jerman berbalik melawan Italia, menyerang pasukan Italia di Italia, Prancis Selatan dan Balkan."
# BLEU Score: 0.4568
# --------------------------------------------------
# Input: "The Commission is composed of the Senate President, the ex officio Chairman, twelve Senators and twelve members of the House of Representatives."
# Predicted: "Komisi terdiri dari Presiden Dewan Perwakilan Rakyat, Pemimpin Wajib, dua-dua Senator dan dua-dua anggota Dewan Rakyat."
# Reference: "Komisi ini terdiri dari Presiden Senat (ketua ex officio), dua belas Senator, dan dua belas anggota Dewan Perwakilan Rakyat."
# BLEU Score: 0.6715
# --------------------------------------------------
# Input: "As of 2009, 87% of the population was Italian."
# Predicted: Pada tahun 2009, 87 persen dari populasi telah italia.
# Reference: "Per tahun 2009, 87% populasi Verona adalah orang Italia."
# BLEU Score: 0.5676
# --------------------------------------------------
# Input: The manga follows Maeda (and his friends and rivals) as he struggles through three years of high school while becoming one of the strongest and best known high school fighters in all of Tokyo.
# Predicted: Batik manga mengikuti Maeda (dan teman-temannya dan lawan-lawannya) sekaligus berjuang melalui tiga tahun sekolah menengah sambil menjadi salah satu pencetak dan terkenal terbesar pemain perlawanan sekolah di Tokyo.
# Reference: Manga tersebut mengisahkan Maeda (dan teman-temannya dan rival-rivalnya) yang berjuang selama tiga tahun di sekolah tinggi sementara ia berusaha menjadi salah satu petarung sekolah tinggi terkuat dan paling dikenal di seluruh Tokyo.
# BLEU Score: 0.6014
# --------------------------------------------------
# Input: "At very young age, she is a victim of a raid from a strange tribe to her people."
# Predicted: Pertumbuhkan
# Reference: "Di waktu muda, ia ditangkap dalam sebuah serangan dari bangsa Turki."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "On 12 October 2000, Saakashvili became Minister of Justice for the government of President Shevardnadze."
# Predicted: 12 Oktober 2000, Saakashvili menjadi Menteri Pembebanan Hukum bagi pemerintah Presiden Shevardnadze.
# Reference: "Pada 12 Oktober 2000, dia menjadi Menteri Kehakiman pada pemerintahan Shevardnadze."
# BLEU Score: 0.5945
# --------------------------------------------------
# Input: "However, the enemy would not give up so easily and was determined to take the position."
# Predicted: Tetapi, pencemar tidak bisa diberhentikan dengan mudah dan akan diambil posisi.
# Reference: "Namun saat itu Wang merasa belum siap untuk memberontak, sehingga ia menerima keputusan tersebut."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: Sea rods are designed for use with fish from the ocean.
# Predicted: Selainnya diri dari laut, ikan adalah desainan yang digunakan untuk kelahiran ikan dari laut.
# Reference: Jaring ini digunakan untuk menciduk ikan dari air.
# BLEU Score: 0.3484
# --------------------------------------------------
# Input: "These groups appear to interact with each other, especially at forest clearings."
# Predicted: Kelompok-kelompok ini sering terinteraksi, terutamanya di daerah hutan, terutama di kawasan pemadun.
# Reference: "Kelompok ini tampak berinteraksi dengan kelompok lain, terutama di tanah terbuka."
# BLEU Score: 0.5362
# --------------------------------------------------
# Input: Built 1877.
# Predicted:
# Reference: Didirikan tahun 1877.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "A new national park, Dovre National Park, between Rondane and Dovrefjell-Sunndalsfjella National Park was also opened."
# Predicted: "Park nasional baru Dovre National Park, antara Rondane dan Dovrefjell-Sunndalsfjella National Park juga dibuka."
# Reference: "Sebagai tambahan, area dengan perlindungan lebih longgar di antara Rondane dan Dovrefjell-Sunndalsfjella National Park juga dibuka. ^ Rondane"
# BLEU Score: 0.5448
# --------------------------------------------------
# Input: From 31 submissions EastChem was the largest in UK Chemistry.
# Predicted: Dari 31 submisi, EastChem adalah paling banyak di UK Chemistry.
# Reference: "Dari penjualannya, Lanxess adalah grup kimia terbesar keempat di Jerman."
# BLEU Score: 0.2477
# --------------------------------------------------
# Input: Perfect Symmetry was released in the same year.
# Predicted: Perfect Symmetry diumasirkan di tahun yang sama.
# Reference: Perfect Symmetry dirilis pada tahun yang sama.
# BLEU Score: 0.7501
# --------------------------------------------------
# Input: Faculty at Southwestern reached out to four other colleges and universities in Texas to create an intercollegiate honor society.
# Predicted: Fakultas di Swinburne menghubungkan dengan empat kampus lain di Texas untuk membangun sindikat honor interuniversitasi.
# Reference: Keluarga Stanford mengunjungi beberapa Universitas besar di timur untuk mengumpulkan ide.
# BLEU Score: 0.3264
# --------------------------------------------------
# ...
# Predicted: Ungkapusatnya pemberontakan kekalahan Kristen di Anatolia Utara, terutamanya Ottoman Greek, mempunyai kesamaan kepada kebijakan terhadap Armenia, sepernya dikutip oleh ambasor Henry Morgau dan historis Arnold Toynbee.
# Reference: "Pengusiran paksa penduduk Kristen di Anatolia barat, terutama warga Yunani Utsmaniyah, memiliki banyak kemiripan dengan kebijakan terhadap orang Armenia, seperti diamati oleh duta besar AS Henry Morgenthau dan sejarawan Arnold Toynbee."
# BLEU Score: 0.5605
# --------------------------------------------------
# Input: Animal sacrifice is the ritual killing of an animal as part of a religion.
# Predicted: The word "sacrifice" is in Indonesian language is is pronounced as "sacriks" (sacriks). The word "sacriks" is derived from the English word "sacrifice," which means to sacrifice or to offer up something of value or importance. In Indonesian, the pronunciation and spelling of "sacriks" follows the same "sacrifice" pattern, with the stress on the first syllable and the "ks" sound on the second syllable.
# Reference: Penyembelihan ritual dilakukan dalam kaidah agama yang juga untuk menyebleih hewan sebagai bahan pangan.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "The Italians repeatedly carried out raids on Gibraltar's harbour using human torpedoes and divers operating from the Spanish shore, damaging a number of merchant ships and sinking one."
# Predicted: Italian: "Sebagian besar sering melakukan pencurian di pelabuhan Gibraltar menggunakan torpedo manusia dan penerbangan dari bumi Spanyol, merusak jumlah kapal pelanggan dan mengendalikan satu."
# Reference: "Kapal perang Amerika Serikat pun beberapa kali melancarkan tembakan dan menggencarkan pengepungan kawasan lingkungan pulau Kiska yang merugikan sejumlah kapal perang, kapal pengangkut dan kapal selam milik kekaisaran Jepang akibat tenggelam dan kecacatan pada masing-masing kerangka kapal."
# BLEU Score: 0.3073
# --------------------------------------------------
# Input: Author of the following researches.
# Predicted:
# Reference: Mengidentifikasi topik riset selanjutnya.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "Accessed on line September 17, 2008. * bet Dra -- Star in double system, database entry, SIMBAD."
# Predicted: Ditambahkan pada linie tanggal 17 September 2008. * Betara dalam sistem dua, entry database SIMBAD.
# Reference: "Diakses tanggal 13 Juni 2012.  ^ Young, Catch a Falling Star, hal.214."
# BLEU Score: 0.1760
# --------------------------------------------------
# Input: I don't need an answer right now.
# Predicted: The word "Indonesia" in English translates to "Indonesia" in Indonesian.
# Reference: Aku tidak membutuhkan jawaban saat ini.
# BLEU Score: 0.0000
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 27
#      24 inputs = tokenizer(batch_prompts, return_tensors="pt", padding=True, truncation=True, return_attention_mask=True).to(device)
#      26 # Generate translations
# ---> 27 generate_ids = model.generate(inputs['input_ids'], max_length=300)
#      28 batch_outputs = tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)
#      30 # Extract translations and calculate BLEU
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/transformers/generation/utils.py:2252, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2244     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2245         input_ids=input_ids,
#    2246         expand_size=generation_config.num_return_sequences,
#    2247         is_encoder_decoder=self.config.is_encoder_decoder,
#    2248         **model_kwargs,
#    2249     )
#    2251     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2252     result = self._sample(
#    2253         input_ids,
#    2254         logits_processor=prepared_logits_processor,
#    2255         stopping_criteria=prepared_stopping_criteria,
#    2256         generation_config=generation_config,
#    2257         synced_gpus=synced_gpus,
#    2258         streamer=streamer,
#    2259         **model_kwargs,
#    2260     )
#    2262 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2263     # 11. prepare beam search scorer
#    2264     beam_scorer = BeamSearchScorer(
#    2265         batch_size=batch_size,
#    2266         num_beams=generation_config.num_beams,
#    (...)
#    2271         max_length=generation_config.max_length,
#    2272     )
#
# File ~/nusax/.conda/lib/python3.11/site-packages/transformers/generation/utils.py:3254, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3252     is_prefill = False
#    3253 else:
# -> 3254     outputs = model_forward(**model_inputs, return_dict=True)
#    3256 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3257 model_kwargs = self._update_model_kwargs_for_generation(
#    3258     outputs,
#    3259     model_kwargs,
#    3260     is_encoder_decoder=self.config.is_encoder_decoder,
#    3261 )
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3.5-mini-instruct/af0dfb8029e8a74545d0736d30cb6b58d2f0f3f0/modeling_phi3.py:1243, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1240 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1242 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1243 outputs = self.model(
#    1244     input_ids=input_ids,
#    1245     attention_mask=attention_mask,
#    1246     position_ids=position_ids,
#    1247     past_key_values=past_key_values,
#    1248     inputs_embeds=inputs_embeds,
#    1249     use_cache=use_cache,
#    1250     output_attentions=output_attentions,
#    1251     output_hidden_states=output_hidden_states,
#    1252     return_dict=return_dict,
#    1253 )
#    1255 hidden_states = outputs[0]
#    1256 logits = self.lm_head(hidden_states)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3.5-mini-instruct/af0dfb8029e8a74545d0736d30cb6b58d2f0f3f0/modeling_phi3.py:1121, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1111     layer_outputs = self._gradient_checkpointing_func(
#    1112         decoder_layer.__call__,
#    1113         hidden_states,
#    (...)
#    1118         use_cache,
#    1119     )
#    1120 else:
# -> 1121     layer_outputs = decoder_layer(
#    1122         hidden_states,
#    1123         attention_mask=attention_mask,
#    1124         position_ids=position_ids,
#    1125         past_key_value=past_key_values,
#    1126         output_attentions=output_attentions,
#    1127         use_cache=use_cache,
#    1128     )
#    1130 hidden_states = layer_outputs[0]
#    1132 if use_cache:
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3.5-mini-instruct/af0dfb8029e8a74545d0736d30cb6b58d2f0f3f0/modeling_phi3.py:855, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     853 residual = hidden_states
#     854 hidden_states = self.post_attention_layernorm(hidden_states)
# --> 855 hidden_states = self.mlp(hidden_states)
#     856 hidden_states = residual + self.resid_mlp_dropout(hidden_states)
#     858 outputs = (hidden_states,)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3.5-mini-instruct/af0dfb8029e8a74545d0736d30cb6b58d2f0f3f0/modeling_phi3.py:235, in Phi3MLP.forward(self, hidden_states)
#     232 gate, up_states = up_states.chunk(2, dim=-1)
#     233 up_states = up_states * self.activation_fn(gate)
# --> 235 return self.down_proj(up_states)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164 def new_forward(module, *args, **kwargs):
# --> 165     args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     166     if module._hf_hook.no_grad:
#     167         with torch.no_grad():
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/hooks.py:355, in AlignDevicesHook.pre_forward(self, module, *args, **kwargs)
#     347         if (
#     348             value is not None
#     349             and self.tied_params_map is not None
#     350             and value.data_ptr() in self.tied_params_map
#     351             and self.execution_device not in self.tied_params_map[value.data_ptr()]
#     352         ):
#     353             self.tied_pointers_to_remove.add((value.data_ptr(), self.execution_device))
# --> 355         set_module_tensor_to_device(
#     356             module,
#     357             name,
#     358             self.execution_device,
#     359             value=value,
#     360             fp16_statistics=fp16_statistics,
#     361             tied_params_map=self.tied_params_map,
#     362         )
#     364 return send_to_device(args, self.execution_device), send_to_device(
#     365     kwargs, self.execution_device, skip_keys=self.skip_keys
#     366 )
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/utils/modeling.py:329, in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     327             module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     328 elif isinstance(value, torch.Tensor):
# --> 329     new_value = value.to(device)
#     330 else:
#     331     new_value = torch.tensor(value, device=device)
#
# KeyboardInterrupt:

# %%
# import torch
# import csv
# import numpy as np
# import os
# from nltk.translate.bleu_score import sentence_bleu
# # Check if CUDA (GPU) is available
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# # List to store translations
# translations = []
# bleu_scores = []
# # Process each sentence in the test dataset
# for key, (input_text, output_text_real) in enumerate(zip(test_data['src'], test_data['tgt'])):
#     # Create the prompt for the current sentence
#     prompt = f"""
# Translate the following sentences from English to Indonesian:

# English: I am going to the market.
# Indonesian: Saya akan pergi ke pasar.

# English: {input_text}
# Indonesian:
# #answer
# """
#     # Tokenize the prompt
#     inputs = inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True, return_attention_mask=True).to(device)

#     # Generate the translation
#     generate_ids = model.generate(inputs['input_ids'], max_length=500)
    
#     # Decode the output and extract the translation
#     output_text = tokenizer.decode(generate_ids[0], skip_special_tokens=True, clean_up_tokenization_spaces=False)
    
#     # Extract the sentence one line below `#answer`
#     translated_text = ""
#     if "#answer" in output_text:
#         # Split by lines and find the text after '#answer'
#         lines = output_text.split("\n")
#         try:
#             index = lines.index("#answer") + 1  # Get the line after '#answer'
#             translated_text = lines[index].strip()  # Clean up any extra spaces
#             translated_text = translated_text.replace("Indonesian:", "").strip()
#         except IndexError:
#             translated_text = "Translation not found."
#     else:
#         translated_text = "No '#answer' marker in output."
#     # Calculate BLEU score for this sentence
#     bleu_score = sentence_bleu([output_text_real], translated_text)
#     with open('predictions_phi35_test.csv', mode='a', newline='') as file:
#         if not os.path.exists('predictions_phi35_test.csv'):
#             writer.writerow(['Index', 'Input', 'Predicted Output', 'Correct Output', 'BLEU Score'])
#         writer = csv.writer(file)
#         writer.writerow([key + 1, input_text, translated_text, output_text_real, bleu_score])
#     # Print the results
#     print(f"Input: {input_text}")
#     print(f"Predicted: {translated_text}")
#     print(f"Reference: {output_text_real}")
#     print(f"BLEU Score: {bleu_score:.4f}")
#     print("-" * 50)
#     bleu_scores.append(bleu_score)
# print(np.mean(bleu_scores))
# Out:
# Input: Indira Gandhi imposed emergency rule in India.
# Predicted: Indira Gandhi memperintah kebebasan operasi di India.
# Reference: Kemudian Thoha Hanafi mendirikan perusahaan ekspor impor di Rengat.
# BLEU Score: 0.1928
# --------------------------------------------------
# Input: "After a brief fight, the North Korean minelayer was sunk with a loss of all crew and no South Korean casualties were reported."
# Predicted: "Setelah perang singkat, minelayer North Korea diperintahkan menghancurkan dengan kegagalan semua anggota dan tidak ada kasus kematian South Korea diperiksa."
# Reference: "Setelah pertempuran singkat, kapal ranjau Korea Utara tenggelam dengan hilangnya semua awak dan tidak ada korban yang dilaporkan dari pihak Korea Selatan."
# BLEU Score: 0.5412
# --------------------------------------------------
# Input: "Promoting culture as distinct to other goods and services, mapping and measuring the sectors adequately."
# Predicted: "Mempromosikan budaya sebagai bagian yang unik dari barang dan tugas lainnya, mengkartografi dan mengukur sektor secara tepat."
# Reference: Karakteristik tak langsung seperti gesekan yang terjadi antara bahan pertanian dan bahan pertanian dengan media lain serta kerusakan mekanik dan fisik juga dianalisis.
# BLEU Score: 0.2866
# --------------------------------------------------
# Input: Jackie Robinson-Burnette was named the Chief of the Corps' Small Business Program in May 2010.
# Predicted: Jackie Robinson-Burnette diberi nama Kepala Program Usaha Kecil Korps pada Mei 2010.
# Reference: Huntington-Whiteley terpilih sebagai ikon rumah mode Burberry pada bulan Juli 2011.
# BLEU Score: 0.2018
# --------------------------------------------------
# Input: "At around that time, he was also made a member of the College of Pontiffs and of the Sodales Augustales."
# Predicted: "Pada waktu seperti itu, dia juga diberi anggaran menjadi anggota Koleksior Pontifikat dan Sodales Augustales."
# Reference: "Pada sekitar saat itu, ia juga dijadikan anggota Perguruan Tinggi Pontiffs dan Sodales Augustales."
# BLEU Score: 0.6034
# --------------------------------------------------
# Input: "On February 29, Miss A won the Champion Song on MBC MUSIC's Show Champion with the song ""Touch""."
# Predicted: "Pada 29 Februari, Miss A menang pada Lagu Pilih Dengan MBC MUSIC's Show Champion dengan lagu "Touch"
# Reference: "Pada 29 Februari, Miss A memenangkan penghargaan Champion Song di MBC Show Champion dengan lagu ""Touch""."
# BLEU Score: 0.6740
# --------------------------------------------------
# Input: "William of Malmesbury also alleged that Alan IV had Constance poisoned to death, but this was unverified However, Orderic Vitalis wrote that as duchess, Constance did all she could to further the welfare of the Bretons, who grieved deeply at her death in 1090."
# Predicted: "William of Malmesbury juga melanggar bahwa Alan IV menyebabkan kematian Constance dengan toksisinya, tetapi ini belum verifikasi. Namun, Orderic Vitalis menulis bahwa sebagai dukesi, Constance melakukan semua upaya untuk meningkatkan kesejahteraan Breton, yang sangat rungkum-rungkum kecelakaan hari-harinya pada tahun 1090."
# Reference: "William dari Malmesbury juga menyatakan bahwa Alain IV meracuni Constance, namun hal tersebut belum terbukti kebenarannya Akan tetapi, Ordericus Vitalis menulis bahwa Constance berusaha semaksimal mungkin untuk memajukan kesejahteraan Breton, yang sangat berkabung atas kematiannya pada tahun 1090."
# BLEU Score: 0.6564
# --------------------------------------------------
# Input: "More recent research has found that human populations over the past 50,000 years have changed from dark-skinned to light-skinned and vice versa."
# Predicted: "Penelitian terbaru menemukan bahwa populasi manusia selama 50,000 tahun terakhir telah berubah dari kulit cokelat ke kulit lembut dan sebaliknya."
# Reference: "Penelitian yang lebih baru menemukan bahwa populasi manusia selama 50,000 tahun telah berubah dari berkulit gelap ke berkulit terang dan sebaliknya."
# BLEU Score: 0.8109
# --------------------------------------------------
# Input: Ronan won five awards for her performance including Best Actress in a Supporting Role at the 5th Irish Film & Television Awards and Best Young Actress from the Women Film Critics Circle.
# Predicted: Ronan memenangkan lima hadiah untuk performansya termasuk Best Actress in a Supporting Role pada 5th Irish Film & Television Awards dan Best Young Actress dari Women Film Critics Circle.
# Reference: Ronan memenangkan lima penghargaan untuk penampilannya yang meliputi Aktris Terbaik dalam sebuah Peran Pendukung di Penghargaan Film & Televisi Irlandia ke-5 dan Aktris Muda Terbaik dari Women Film Critics Circle.
# BLEU Score: 0.4772
# --------------------------------------------------
# Input: "Other positions were created for important counties, such as the Lancastrian King of Arms, but the balance of power between them and those charged with larger regions remains unclear."
# Predicted: "Posisi lain dibuat untuk kabupaten penting seperti Prancetrian Raja Arus, namun keseimbangan kekuatan antara mereka dengan yang dihadapan dengan daerah lebih besar tetap kesulitan."
# Reference: "Kekaisaran yang sudah terpecah-belah umumnya juga tetap mempertahankan gelar ""kaisar"" untuk pemimpin mereka, meskipun wilayah kekuasaannya sudah tidak lebih luas lagi dari kerajaan dan kadipaten di sekitarnya."
# BLEU Score: 0.3617
# --------------------------------------------------
# Input: "DB2 traces its roots back to the beginning of the 1970s when Edgar F. Codd, a researcher working for IBM, described the theory of relational databases, and in June 1970 published the model for data manipulation."
# Predicted: "DB2 menjalin kembangannya kembali ke awalan tahun 1970-an ketika Edgar F. Codd, peneliti bekerja untuk IBM, mengungkapkan teori database relasi, dan pada Juni 1970, mengembangkan model manipulasi data."
# Reference: "Asal muasal DB2 bermula pada era tahun 1970an saat Edgar F. Codd yang saat itu merupakan karyawan IBM, menjabarkan teori basisdata relasional yang dipublikasikannya pada bulan juni 1970."
# BLEU Score: 0.4805
# --------------------------------------------------
# Input: "He began his independent research career at the University of Minnesota and introduced kinetic, isotopic, and chemical methods for investigating enzyme mechanisms."
# Predicted: Dia mulai kariernya penelitian kepentingan sendiri di Universitas Minnesota dan mengintroduksi metode kinetis, isotopik, dan kimiaisel untuk mengkaji mekanisme enzim.
# Reference: Ia memulai penelitian independen di Universitas Minnesota mengenai mekanisme enzimatik.
# BLEU Score: 0.4116
# --------------------------------------------------
# Input: Their strip is royal blue and white.
# Predicted: Kain mereka merah putih darah royaltis.
# Reference: Seragam mereka berwarna biru royal dan putih.
# BLEU Score: 0.4373
# --------------------------------------------------
# Input: "An intrauterine device (IUD) is a small contraceptive device, often 'T'-shaped and containing either copper or the hormone levonorgestrel, which is implanted into the uterus."
# Predicted: "Sistem kontraktip intrauterin (IUD) adalah alat kontraktip kecil, sering dibentuk 'T'-form dan mengandung kupingan kupingan kupingan atau hormon levonorgestrel, yang diimplantasikan ke dalam usus."
# Reference: "Sebuah alat kontrasepsi (IUD atau coil) adalah perangkat kontrasepsi berukuran kecil, sering berbentuk 'T', mengandung tembaga atau levonorgestrel, yang dimasukkan ke dalam rahim."
# BLEU Score: 0.5773
# --------------------------------------------------
# Input: "London contains four World Heritage Sites: the Tower of London; Kew Gardens; the site comprising the Palace of Westminster, Westminster Abbey, and St Margaret's Church; and the historic settlement in Greenwich where the Royal Observatory, Greenwich defines the Prime Meridian, 0° longitude, and Greenwich Mean Time."
# Predicted: "London memiliki empat Tentang Budaya Dunia: Bambu Tower London; Kebun Kew; situs yang menggabungkan Istana Westminster, Abadang Westminster, dan Gereja St Margaret's; dan kota historis di Greenwich di mana Observatorium Kota Royal mengklarifikasi Meridian Prime, 0° longitude, dan Waktu Mean Greenwich."
# Reference: "London memiliki empat Situs Warisan Dunia, yaitu: Menara London; Kebun Botani Kew; komplek situs bersejarah yang terdiri dari Istana Westminster, Westminster Abbey dan Gereja St. Margaret; serta permukiman bersejarah Greenwich (tempat Observatorium Kerajaan menandai meridian utama, yaitu 0° garis bujur, dan GMT)."
# BLEU Score: 0.5843
# --------------------------------------------------
# Input: "Predictably, the songs where she expresses wonderment that 'Impossible Is Nothing' are more relatable than the ones where she flaunts her liquid assets."
# Predicted: "Secara teratur, lagu-lagu yang mengungkapkan kagenahan bahwa 'Impossible Is Nothing' lebih relatable daripada yang menggemburkan asetnya yang likuid."
# Reference: "Jika ditafsirkan secara masuk akal, pernyataan Smith bahwa nilai guna bisa saja lebih sedikit daripada nilai tukar jelas-jelas merupakan pernyataan moral yang tidak dipedulikan oleh para pemilik berlian."
# BLEU Score: 0.2599
# --------------------------------------------------
# Input: "He also set up two newspapers, the Sunday Observer and the Sunday Review."
# Predicted: Dia juga membangun dua surat kabar, yaitu Observer Harian dan Review Harian.
# Reference: "Ia juga mendirikan 2 surat kabar, Sunday Observer dan Sunday Review."
# BLEU Score: 0.5516
# --------------------------------------------------
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Input: Most people here are of religious nature.
# Predicted: Paling banyak orang di sini memiliki benda-benda religius.
# Reference: Sebagian besar penduduknya beragama Islam.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "D. V-VIII; Gregory-Aland no. A or 02, Soden δ 4) is a fifth-century manuscript of the Greek Bible, containing the majority of the Septuagint and the New Testament."
# Predicted: "D. V-VIII; Gregory-Aland no. A vau 02, Soden δ 4) adalah manusikra gereja yang berasal dari abad ke-VIII, yang mengandung sebagian besar Septuagint dan Teologi Baru."
# Reference: "D. V-VIII; Gregory-Aland no. A or 02, Von Soden δ 4) adalah naskah Alkitab bahasa Yunani dari abad ke-5 M, memuat sebagian besar dari Perjanjian Lama (PL) versi Septuaginta, yaitu terjemahan bahasa Yunani dari Alkitab Ibrani, dan Perjanjian Baru (PB)."
# BLEU Score: 0.4039
# --------------------------------------------------
# Input: """Everybody wanted to buy something for his or her family,"" she recalled."
# Predicted: "Semua ingin membeli sesuatu untuk keluarganya," kata dia ucapkan.
# Reference: """Setiap orang ingin membeli suatu hal untuk keluarganya,"" katanya."
# BLEU Score: 0.6605
# --------------------------------------------------
# Input: "It shares land borders with Zambia and Angola to the north, Botswana to the east and South Africa to the south and east."
# Predicted: "Mengambil tenggara yang berbatasan tanah dengan Zambia dan Angola di utara, Botswana di timur dan South Africa di bawah dan utara."
# Reference: "Negeri ini berbatasan dengan Angola dan Zambia di sebelah utara, Botswana di timur dan Afrika Selatan di selatan."
# BLEU Score: 0.6173
# --------------------------------------------------
# Input: Refined cuisine could be moralized as a sign of either civilized progress or decadent decline.
# Predicted: Kue refinement bisa moralisasi sebagai tanda dari kemajuan sosial yang civilisasi atau kegagalan kegembiraan.
# Reference: Penyaringan masakan yang dikonsumsi menjadi pertanda kemajuan peradaban atau penurunan dekaden.
# BLEU Score: 0.3121
# --------------------------------------------------
# Input: "This is an archontological list of Serbian monarchs, containing monarchs of the medieval principalities, to heads of state of modern Serbia."
# Predicted: "Ini adalah daftar archeologi Serbia monark, mengandung monark medieval principalitas, hingga pemimpin modern Serbia."
# Reference: Berikut adalah daftar penguasa monarki bangsa Serbia dari abad pertengahan hingga masa modern.
# BLEU Score: 0.4271
# --------------------------------------------------
# Input: "Montenegrin nationalism became a major political issue in World War I when a schism arose between Montenegro's clans over plans to merge Montenegro with the Kingdom of Serbia, between the pro-independence Green clans, that included the King of Montenegro amongst them, versus the pro-unification White clans."
# Predicted: "Nasionalisme Montenegro menjadi isu politik utama di Perang Dunia I ketika kesetaraan muncul antara klan-klan Montenegro terkait dengan rencana merger Montenegro dengan Kerajaan Serbia, antara klan-klan Green yang mengharuskan kemerdekaan, termasuk Raja Montenegro di dalamnya, dan klan-klan Whitenya yang mendukung unifikasi."
# Reference: "Nasionalisme Montenegro menjadi isu politik utama dalam Perang Dunia I ketika sebuah skisma muncul di antara klan Montenegro tentang rencana penggabungan Montenegro dengan Kerajaan Serbia, antara klan hijau pro-kemerdekaan, di mana Raja Montenegro termasuk di dalamnya, versus kelompok klan putih pro-penyatuan."
# BLEU Score: 0.7272
# --------------------------------------------------
# Input: "Combined, these conditions have left very little physical evidence of the structures."
# Predicted: "Dengan kombinasinya, sifat-sifat ini telah membuat belum banyak alamat fisik dari struktur tersebut."
# Reference: Namun hingga saat ini kedua pandangan tersebut tidak memiliki banyak bukti-bukti fisik.
# BLEU Score: 0.3776
# --------------------------------------------------
# Input: "It centers on a family struggling to make ends meet, relocates to a suburban home and, like the original, the youngest daughter is kidnapped by spirits that possess the house."
# Predicted: "Sebagai pusatnya, adalah keluarga yang berjuang untuk menyusun kebenaran, pergi ke rumah subur dan, seperti pada orang pertama, adalah perempuan terkecil yang ditahan oleh semangat yang memanipulasi rumahnya."
# Reference: "Rumah di bagian paling hulu diperuntukkan sebagai tempat bagi masyarakat yang mempunyai usia lebih tua dalam garis keluarga, dan seterusnya hingga ke rumah paling hilir yang harus ditempati oleh keturunan yang berumur paling muda."
# BLEU Score: 0.4324
# --------------------------------------------------
# Input: "Because of this, Balderic also kept close contact with Henry's other son and successor, King Otto I (936-973)."
# Predicted: "Karena itu, Balderic juga menghentikan kontak yang dekat dengan anak laki-laki dan suksesornya, Kronik Otto I (936-973)."
# Reference: Perluasan wilayah terjadi pada masa pemerintahan Heinrich I (919-936) dan anaknya Otto I Agung (936-973).
# BLEU Score: 0.3316
# --------------------------------------------------
# Input: A CSTR often refers to a model used to estimate the key unit operation variables when using a continuous agitated-tank reactor to reach a specified output.
# Predicted: CSTR sering kasus merujuk pada model yang digunakan untuk estimasi variabel utama operasi unit kontinu agitasi-tank untuk mencapai hasil tertentu.
# Reference: RAP digunakan sebagai model untuk mengestimasi variabel unit operasi untuk mendapatkan hasil output tertentu.
# BLEU Score: 0.5587
# --------------------------------------------------
# Input: "Additional tasks At the cybercafe, teams must access the MSN Search website at the internet cafe's computers and search for the words ""Amazing Race Asia"" to find their next clue, which they may print out or receive from an attendant."
# Predicted: "Tugas tambahan di kafé cyber, tim-tim harus mengakses situs web MSN Pencarian di komputer internet kafé dan cari kata "Amazing Race Asia" untuk menemukan petunjuk keluarganya, yang bisa diprint atau diberikan oleh petugas."
# Reference: "Tambahan tugas (s) Di warnet, tim harus mengakses situs MSN Search di komputer kafe internet dan mencari kata-kata ""Amazing Race Asia"" untuk menemukan petunjuk berikutnya mereka, yang dapat mereka cetak keluar atau diterima dari petugas."
# BLEU Score: 0.6787
# --------------------------------------------------
# Input: "O'Donis sings the interlude in the same range as Gaga followed by an R&B-influenced interlude by her, after which the chorus is repeated with O'Donis providing backup vocals and the marching beats."
# Predicted: "O'Donis menyanyik pergelangan sama rungkum seperti Gaga yang diikuti dengan pergelangan interlude yang mempengaruhi R&B, setelah itu kuartet kembali dengan O'Donis memberikan vocal backup dan batas marching."
# Reference: "Colby O'Donis menyanyikan bagian interludenya dengan rentang vokal yang sama dengan Gaga diikuti dengan gaya vokal R&Bnya, dimana setelah chorusnya diulang, O'Donis ikut mendukung vokal belakang lagu."
# BLEU Score: 0.5373
# --------------------------------------------------
# Input: "Labour market pressures have increased as skilled labour shortages have become more widespread, despite illegal immigration, and real earnings growth has accelerated."
# Predicted: "Presipitasi pasar tenaga kerja telah meningkat seiring dengan kekurangan tenaga kerja khusus yang semakin luas, meskipun terdengar ada imigrasi ilegal, dan pertumbuhan pendapatan nyata telah bergerak cepat."
# Reference: Tekanan pasar tenaga kerja telah meningkat karena kurangnya tenaga kerja yang terampil meskipun imigran ilegal terus berdatangan.
# BLEU Score: 0.4786
# --------------------------------------------------
# Input: "In May, Quintana won the team's first Grand Tour since Valverde's 2009 Vuelta victory, the 2014 Giro d'Italia."
# Predicted: "Sepuluh Mei, Quintana memenangkan olahraga kelompok pertama Grand Tour sejak triumf Valverde pada Vuelta 2009, yang dikutip dari Giro d'Italia 2014."
# Reference: "Pada bulan Mei, Quintana meraih kemenangan umum pada Gran Tuor pertama bagi tim setelah kemenangan Valverde pada Vuelta 2009, dengan kemenangan di Giro d'Italia 2014."
# BLEU Score: 0.5750
# --------------------------------------------------
# Input: "One etymology of Kinneret, the Hebrew name of the Sea of Galilee, is that it derives from kinnor, on account of the shape of the lake resembling that of the instrument."
# Predicted: "Salah satu etimologi Kinneret, nama Hebrew untuk Laut Galilea, ialah karena ia berasal dari kinnor, karena bentuk laut mirip dengan bentuk instrument tersebut."
# Reference: "Sebuah sinonim untuk Prancis kontinental adalah l'Hexagone, karena bentuknya yang heksagon."
# BLEU Score: 0.2391
# --------------------------------------------------
# Input: "Television series My Little Pony: Friendship Is Magic, theatrical film My Little Pony: The Movie, as well as other related media accompany the current line-up."
# Predicted: "Seri televisi My Little Pony: Keprihatian Bersama, film teater My Little Pony: Film, serta media lainnya menghadiri kumpulan saat ini."
# Reference: "Sesuai sifat dari acara Kartun My Little Pony: Friendship is Magic, yaitu adanya referensi dengan acara kartun atau film lain, para Brony juga membuat video yang juga mengandung referensi."
# BLEU Score: 0.2711
# --------------------------------------------------
# Input: The rituals vary from one place to another.
# Predicted: Ritual-nya berbeda dari satu tempat ke tempat lainnya.
# Reference: Musim berpijah tongkol bervariasi dari satu tempat ke tempat lain.
# BLEU Score: 0.5408
# --------------------------------------------------
# Input: The development of cities was synonymous with the rise of civilization.
# Predicted: Kembangnya kota sama dengan kembangnya zaman civilisasi.
# Reference: Perkembangan kota-kota berarti kemunculan peradaban.
# BLEU Score: 0.3438
# --------------------------------------------------
# Input: "Similarly, the art topic assigned was Romantic art in the European tradition."
# Predicted: "Secara sama-sama, tema seni yang diberikan adalah seni romantis dalam tradisi Eropa."
# Reference: Karakteristik lainnya adalah unsur cerita yang di romantisasi.
# BLEU Score: 0.3463
# --------------------------------------------------
# Input: Now a damane.
# Predicted:
# Reference: Tuan Ankir Damanik.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: Marzano was named executive director.
# Predicted: Marzano diberi pangsa direktur eksekutif.
# Reference: Marzuki diangkat sebagai Direktur Utama PT.
# BLEU Score: 0.3242
# --------------------------------------------------
# Input: "Operating weight is the basic weight of a vehicle or machine, including the driver/operator and fuel."
# Predicted: "Kegembiraan berat operasional adalah berat alat sambil mengandung pengendara/operator dan bahan bakar."
# Reference: "Weight gaya berat adalah kombinasi berat dari muatan pesawat itu sendiri, awak pesawat, bahan bakar, dan kargo atau bagasi."
# BLEU Score: 0.3695
# --------------------------------------------------
# Input: "As in most radiotherapy departments, the one at ION uses a treatment planning system (TPS) to calculate the resulting dose distributions and determine treatment times."
# Predicted: "Selain di banyak departmen radioterapi, yang di ION digunakan sistem perencanaan pelayanan (TPS) untuk menghitung distribusi dosis yang dihasilkan dan mengatur waktu pelayanan."
# Reference: "Dalam kasus kehamilan, Ultrasonografi (USG) digunakan oleh dokter spesialis kandungan (DSOG) untuk memperkirakan usia kandungan dan memperkirakan hari persalinan."
# BLEU Score: 0.3287
# --------------------------------------------------
# Input: "He was born in Springfield, Illinois and graduated from Harvard College before serving on the staff of Ulysses S. Grant as a captain in the Union Army in the closing days of the American Civil War."
# Predicted: Dia lahir di Springfield, Illinois dan mendapatkan pelajaran di Harvard College sebelum melayani di sekretariat Ulysses S. Grant sebagai tenaga di bangunan Perguruan Tentara Persatuan di akhir periode Perang Amerika Serikat.
# Reference: "Lincoln masuk Harvard University, dan kemudian bertugas pada staf Ulysses S. Grant sebagai seorang kapten dalam Union Army pada masa-masa menjelang akhir Perang Saudara Amerika."
# BLEU Score: 0.3890
# --------------------------------------------------
# Input: "The quality of those bungalows ranges from comparably cheap, basic accommodations to very luxurious and expensive."
# Predicted: "Kualitas bungalows itu bervariasi dari semakin murah, taman sederhana penghuni sampai sangat luksus dan mahal."
# Reference: "Kualitas dari bungalow-bungalow tersebut amat beragam, mulai dari yang murah meriah, standar, hingga bungalow bertarif mahal yang menyajikan kemewahan."
# BLEU Score: 0.3344
# --------------------------------------------------
# Input: These competitions are similar to professional mixed martial arts.
# Predicted: Disiplin ini mirip dengan bersaing profesional bersatu olahraga martial.
# Reference: Kompetisi ini mirip dengan seni bela diri campuran profesional.
# BLEU Score: 0.4971
# --------------------------------------------------
# Input: His first top-5 would come one year later in the fall race of 1994 at Dover Downs.
# Predicted: Bahasa Indonesia: Pertamanya kali top-5nya akan datang satu tahun setelah itu pada permainan Dover Downs pada musim gugur 1994.
# Reference: Kemenangan pertamanya di ajang NASCAR di raih di Food City 5000 tahun 2002.
# BLEU Score: 0.2040
# --------------------------------------------------
# Input: "An air attack was launched early on the 9th; twelve Fairey Albacore torpedo bombers attacked the ship in three groups, and Tirpitz successfully evaded the torpedoes."
# Predicted: "Pembesaran aerial di awal 9; sembilan bomber torpedo Fairey Albacore bertindak terpisahan tiga kelompok, dan Tirpitz berhasil evakuasi torpedo."
# Reference: "Serangan udara diluncurkan awal pada tanggal 9; dua belas pesawat pembom torpedo Fairey Albacore menyerang kapal dalam tiga kelompok, dan Tirpitz berhasil menghindari semua torpedo yang diluncurkan sehingga hanya tiga awak kapalnya yang terluka dalam serangan itu."
# BLEU Score: 0.3101
# --------------------------------------------------
# Input: "In 1998, VH1 ranked the Who ninth in their list of the ""100 Greatest Artists of Rock 'n' Roll""."
# Predicted: "Pada tahun 1998, VH1 menebar The Who ke posisi ketiga dalam daftar "100 Penggemar Rock 'n' Roll Terbesar"."
# Reference: "Pada 1998, VH1 menempatkan The Who dalam urutan ke-9 dalam daftar 100 Artis Terbesar Rock 'n' Roll."
# BLEU Score: 0.6353
# --------------------------------------------------
# Input: Serranilla Bank was first shown on Spanish maps in 1510.
# Predicted: Bank Serranilla pertama diperlihatkan pada kartu Spanyol pada tahun 1510.
# Reference: Tepi Serranilla pertama kali ditampilkan pada peta Spanyol tahun 1510.
# BLEU Score: 0.6914
# --------------------------------------------------
# Input: """RTB Bambang Wisanggeni Soerjaatmadja: Berangkat dengan Rasa Persatuan untuk Memajukan Banten""."
# Predicted: Wisanggeni Bambang: Berangkat dengan Rasa Persatuan untuk Memajukan Banten
# Reference: """RTB Bambang Wisanggeni Soerjaatmadja : Berangkat dengan Rasa Persatuan untuk Memajukan Banten""."
# BLEU Score: 0.6813
# --------------------------------------------------
# Input: "Its relations with the government became strained after 1980, however, when Chun Doo Hwan forced TBC to merge with KBS."
# Predicted: Bandingan dengan pemerintah menjadi lemah setelah 1980, tetapi ketika Chun Doo Hwan memaksa TBC untuk menyangkirkan dengan KBS.
# Reference: "Pada tahun 1980, sesuai kebijakan pembatasan pers oleh Presiden Chun Doo-hwan, radio DBS ditutup untuk merger dengan KBS."
# BLEU Score: 0.4326
# --------------------------------------------------
# Input: "Today, Reform synagogues in North America typically hold confirmation ceremonies on Shavuot for students aged 16 to 18 who are completing their religious studies."
# Predicted: Bahasa Indonesia: "Hari ini, sinagoga reform di Amerika Utara biasanya melakukan perjudian ceremonial pada Shavuot untuk pelajar usia 16 sampai 18 yang selesai mendidik keagamaan."
# Reference: Sinagoge Yahudi Reformasi biasanya mengadakan perayaan Penetapan untuk anak-anak kelas sepuluh pada pagi Shavuot.
# BLEU Score: 0.3288
# --------------------------------------------------
# Input: "Finally, on 13 October, an agreement was reached on a joint congress."
# Predicted: "Selanjutnya, pada 13 Oktober, kesepakatan diperoleh tentang Kongres yang bersama."
# Reference: "Pada tanggal 1 Oktober, kesepakatan tersebut ditetapkan dalam protokol trilateral."
# BLEU Score: 0.4425
# --------------------------------------------------
# Input: "The film is set in the future, when Earth is at war with the Kaiju, colossal sea monsters which have emerged from an interdimensional portal on the bottom of the Pacific Ocean."
# Predicted: "Film disetel di masa akan datang, ketika Bumi bersorot di bawah kepala Kaiju, monster laut kolosal yang terbentuk dari portal interdimensional di bawah laut Pacific."
# Reference: "Film berlatar pada tahun 2020-an, ketika bumi sedang berperang melawan Kaiju yaitu monster-monster raksasa yang muncul dari sebuah portal antardimensi di dasar Samudera Pasifik."
# BLEU Score: 0.4293
# --------------------------------------------------
# Input: It is now used largely for designation of newer cytokine molecules and bears little relation to their presumed function.
# Predicted: Saat ini digunakan sering untuk deskripsi molekul cytokine baru dan memiliki sedikit hubungan dengan fungsi yang diperkirakan.
# Reference: Sekarang ini istilah interleukin digunakan sebagian besar untuk molekul sitokin yang lebih baru dan tidak banyak berhubungan dengan fungsi yang diduga.
# BLEU Score: 0.5226
# --------------------------------------------------
# Input: "It is the smallest of all the 22 regions in area with 6,993 km2 (2,700 sq mi), and is the most densely populated region after Analamanga."
# Predicted: "Itu terendah dari semua 22 daerah yang memiliki kawasan 6,993 km² (2,700 sq mi), dan adalah daerah dengan kelompok penduduk terbesar setelah Analamanga."
# Reference: "Kawasan tersebut adalah kawasan terkecil dari seluruh 22 kawasan dengan luas 6993 km2 (2700 sq mi), dan merupakan kawasan paling padat setelah Analamanga."
# BLEU Score: 0.5036
# --------------------------------------------------
# Input: "Jung's sister, Krystal, is a member of the Korean girl group f(x)."
# Predicted: "Kusus Krystal, adalah anggota grup perempuan Korea f(x)."
# Reference: "Adik perempuannya, Krystal Jung, adalah salah satu anggota dari girl band f(x), yang juga berada di bawah label S.M. Entertainment."
# BLEU Score: 0.1753
# --------------------------------------------------
# Input: "Rich was the winner of the Swiss national final for the 1987 Contest, held on January 31."
# Predicted: "Berhasil sangat, Rich adalah pemenang final nasional Sukri di periode 1987, diadakan pada tanggal 31 Desember."
# Reference: "Rich adalah pemenang final nasional Swiss untuk kontes 1987, yang diadakan pada 31 Januari."
# BLEU Score: 0.5726
# --------------------------------------------------
# Input: This gift is the largest in USC history.
# Predicted: Ini hadiah terbesar dalam sejarah USC.
# Reference: Expo ini adalah yang termahal dalam sejarah.
# BLEU Score: 0.4416
# --------------------------------------------------
# Input: "Mao: A Reinterpretation was reviewed by academic Sinologists such as Ross Terrill, Arthur Waldron, and Gregor Benton."
# Predicted: "Mao: Reinterpretasi: Dijamin oleh sinolog pendidikan seperti Ross Terrill, Arthur Waldron, dan Gregor Benton."
# Reference: "Mao: A Reinterpretation diulas oleh sinolog-sinolog akademik seperti Ross Terrill, Arthur Waldron, dan Gregor Benton."
# BLEU Score: 0.7642
# --------------------------------------------------
# Input: "Tanaka was born in Shimonoseki, Yamaguchi, Japan."
# Predicted: "Tanaka dilahirkan di Shimonoseki, Yamaguchi, Jepang."
# Reference: "Tanaka lahir di Shimonoseki, Prefektur Yamaguchi, Jepang."
# BLEU Score: 0.7602
# --------------------------------------------------
# Input: The shell is nodose at the shoulder.
# Predicted: Kepala kelapa memiliki kepala kusut di sisi bahu.
# Reference: Selendang selalu dikenakan di bahu.
# BLEU Score: 0.2335
# --------------------------------------------------
# Input: Bridge construction started in 1993 and was completed in 2000 at a cost of 677.7 billion won.
# Predicted: Pembangunan jembatan dimulai pada tahun 1993 dan selesai pada tahun 2000 dengan biaya 677,7 juta rupiah.
# Reference: "Pembangunan jembatan dimulai pada 1993 dan selesai pada 2000 dengan biaya 677,7 miliar won."
# BLEU Score: 0.7669
# --------------------------------------------------
# Input: During the Lace week local craftspeople arrange small exhibitions in the Old Rauma area.
# Predicted: Dalam minggu Lace, kasrawan lokal bersusun pameran kecil di daerah Old Rauma.
# Reference: "Pada masa Perang Paderi, para pedagang Minang banyak yang membawa etnis Batak ke wilayah Rao."
# BLEU Score: 0.1086
# --------------------------------------------------
# Input: They called for a change in the way that the church was run and insisted that the buying and selling of indulgences and religious positions be stopped as well as the papal corruption that had been allowed to occur.
# Predicted: Bersama-sama: Mereka meminta perubahan cara bangunan gereja dan memvermasukkan bahkan penghentian belanja dan penjualan indulgensi dan posisi-posisi sosial yang telah terjadi.
# Reference: Mereka menyerukan perubahan tata kelola Gereja dan bersikeras bahwa praktik jual beli indulgensi dan posisi-posisi keagamaan dihentikan seperti halnya yang mereka lihat sebagai korupsi kepausan yang telah dibiarkan terjadi.
# BLEU Score: 0.4813
# --------------------------------------------------
# Input: He endured this for a while but in the end could not bear to control his incontinence....
# Predicted: Dia berusaha dengan itu sejak lama tetapi akhirnya tidak dapat mengatasinya untuk mengendalikan incontinensi...
# Reference: "Dia melakukan ini selama beberapa waktu, tetapi akhirnya tidak dapat menahan nafsunya..."
# BLEU Score: 0.5007
# --------------------------------------------------
# Input: "On October 15, Thorne revealed her debut album was canceled, saying she wasn't happy with the ""auto-tuned bad music"" she had in the works."
# Predicted: "Pada 15 Oktober, Thorne mengungkapkan album awalnya dilarang, menegaskan dia tidak bersedia dengan musik "terkontaminasi" yang sedang diperbaikkan.
# Reference: "Pada tanggal 15 Oktober Thorne mengungkapkan album debutnya dibatalkan, dan mengatakan dia tidak suka dengan efek ""auto-tune"" yang mereka gunakan di albumnya."
# BLEU Score: 0.5493
# --------------------------------------------------
# Input: "This work was superseded by The Queensland Flora, published in six volumes between 1899 and 1902 with an index published three years later."
# Predicted: "Proses ini dipergantian oleh Flora Queensland, dipublikasikan dalam seibu volume antara 1899 hingga 1902 dengan indeks dipublikasikan tiga tahun setelah itu."
# Reference: "Karya ini digantikan oleh The Queensland Flora, yang diterbitkan dalam enam volume antara 1899 dan 1902 dengan indeks yang diterbitkan tiga tahun kemudian."
# BLEU Score: 0.6306
# --------------------------------------------------
# Input: "Starting in the mid-10th century, the Tivertsi frequently fought against the neighbouring Pechenegs and Cumans."
# Predicted: "Di tengah abad ke-10, Tivertsi sering bertarung terhadap Pechenegs dan Cumans dekat."
# Reference: "Pada masa colonial belanda pertama pada abad 17-an, sering terjadi sengketa dengan para penjajah belandadengan para tokoh dan masyarakat kedongdong dan sekitarnya."
# BLEU Score: 0.1715
# --------------------------------------------------
# Input: "It effectively operated underground throughout most of the 1980s, with membership lists a closely guarded secret."
# Predicted: "Dia efektif beroperasi di bawah tanah selama sebagian dari 1980-an, dengan daftar anggota yang dipelindung segera tersembunyi."
# Reference: "Ini secara efektif beroperasi dibawah tanah di sebagian besar tahun 1980-an, dengan daftar keanggotaan rahasia yang dijaga ketat."
# BLEU Score: 0.6662
# --------------------------------------------------
# Input: The ringing chamber is accessed via a wooden staircase of 54 steps.
# Predicted: Gedung keliling berbentuk berjalanan dipupuk oleh tinggi 54 tahun bambu.
# Reference: Anak tangga dari pekarangan masjid menuju tangga terpanjang berjumlah 45 anak tangga.
# BLEU Score: 0.1776
# --------------------------------------------------
# /home/fachri/nusax/.conda/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Input: They should be impatient.
# Predicted: Mereka seharusnya nyobolan.
# Reference: Rakyat merasa tidak sabar menunggu.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "As the young king's senior tutor, Buchanan subjected James to regular beatings but also instilled in him a lifelong passion for literature and learning."
# Predicted: "Buchanan, tutor senior dari reksa muda, mengusung James secara rutin penggandaan tetapi juga mendorong pada dia rasa takberuntung untuk keahlian sastra dan belajar-belajar."
# Reference: "Sebagai guru senior raja muda, Buchanan menjadikan James sebagai bantingan biasa tetapi juga menanamkan hasrat seumur hidup untuk sastra dan pembelajaran."
# BLEU Score: 0.5104
# --------------------------------------------------
# Input: "A ""living language"" is simply one that is used as the primary form of communication of a group of people."
# Predicted: "Bahasa hidup adalah jenis bahasa yang hanya digunakan sebagai bentuk komunikasi utama oleh kelompok orang."
# Reference: """Bahasa hidup"" sederhananya adalah bahasa yang secara luas digunakan sebagai bentuk komunikasi utama oleh kelompok tertentu dari masyarakat."
# BLEU Score: 0.6193
# --------------------------------------------------
# Input: 1993 : Hautes-Pyrénées uses the song for their ski resort.
# Predicted: 1993 : Hautes-Pyrénées digunakan lagu untuk skieran mereka.
# Reference: 1993 – Pentas keliling Jawa-Bali sebagai piñata tari dalam repertoar Gendowor.
# BLEU Score: 0.0695
# --------------------------------------------------
# Input: "On July 17, the group announced the release of their second compilation album Love Yourself: Answer for August 24, 2018, with seven new tracks added to the release."
# Predicted: "Pada 17 Juli, kelompok itu mengumumkan pengiriman album kompilasi kedua Love Yourself: Answer pada 24 Agustus 2018 dengan setelahnya sebanyak tujuh lagu baru yang ditambahkan."
# Reference: "Pada tanggal 17 Juli, grup ini mengumumkan album kompilasi kedua mereka Love Yourself: Answer pada tanggal 24 Agustus 2018, dengan tujuh lagu baru ditambahkan di album ini."
# BLEU Score: 0.7354
# --------------------------------------------------
# Input: "The anime revolves around four teenage humans named Guren, Ceylan, Toxsa, and Chooki, who find an interdimensional portal to Quarton where they are chosen by the Guardians to become the new generation of Tenkai Knights and prevent Vilius to take control of both worlds."
# Predicted: Bahasa Indonesia: "Anime ini berpusat pada empat adolesen manusia yang disebut Guren, Ceylan, Toxsa, dan Chooki, yang menemukan portal interdimensional ke Quarton di mana mereka dipilih oleh Pengawal untuk menjadi generasi baru Tenkai Knight dan mencegah Vilius menahan kontrol kedua dunia."
# Reference: "Sekarang di planet Bumi pada tahun 2034, empat manusia remaja bernama Guren, Ceylan, Toxsa, dan Chooki menemukan sebuah portal interdimensional untuk Quarton mana mereka dipilih oleh Wali untuk menjadi generasi baru dari Tenkai Knights dan mencegah Vilius untuk mengambil kendali dari kedua dunia."
# BLEU Score: 0.7272
# --------------------------------------------------
# Input: "Minnesota headquartered 31 publicly traded companies in the top 1,000 U.S. companies by revenue in 2011."
# Predicted: "Minnesota menyusun 31 perusahaan yang diumumkan di luar badan publik terbesar 1,000 perusahaan di Amerika Serikum tersebut pada tahun 2011."
# Reference: "Secara global, IBM menempati peringkat terbesar ke-31 dalam hal pendapatan pada tahun 2011."
# BLEU Score: 0.3162
# --------------------------------------------------
# Input: We knew that a lot of great bands fall through the cracks.
# Predicted: Kami tahu banyak band yang menyentuh kelabu.
# Reference: "Artinya, banyak panah-panah yang berjatuhan."
# BLEU Score: 0.3394
# --------------------------------------------------
# Input: He was one of the five rulers dubbed the Five Hegemons by Xunzi and attempted to wrest control of China from King Ding of Zhou.
# Predicted: Dia adalah satu dari lima pemerintah yang diberdiktirian lima hegemon oleh Xunzi dan melakukan usaha untuk mengambil kontrol China oleh Raja Ding Zhou.
# Reference: Dia adalah salah satu dari lima penguasa yang dijuluki Lima Hegemoni oleh Xunzi dan berusaha merebut kendali Tiongkok dari Raja Ding dari Zhou.
# BLEU Score: 0.5817
# --------------------------------------------------
# Input: The basic pitot tube consists of a tube pointing directly into the fluid flow.
# Predicted: Tubuh basis pitot tube terdiri dari tulang yang menghadirkan ke arah aliran cairan.
# Reference: Tabung pitot sederhana terdiri dari tabung yang mengarah secara langsung ke aliran fluida.
# BLEU Score: 0.5555
# --------------------------------------------------
# Input: "T3 magazine is available in most countries, and has syndicated/localised versions in over 20 countries."
# Predicted: "T3 magazin tersedia di banyak negara, dan memiliki versi syndikat/terdokumentasional di lebih dari 20 negara."
# Reference: "T3 diterbitkan sebagai versi lokal di lebih dari 20 negara lain, termasuk di Indonesia."
# BLEU Score: 0.4739
# --------------------------------------------------
# Input: Rehoboam was 41 years old when he ascended the throne.
# Predicted: Rehoboam memiliki usia 41 tahun ketika menyangkut kepala.
# Reference: Rehabeam berusia 41 tahun ketika ia naik takhta.
# BLEU Score: 0.4568
# --------------------------------------------------
# Input: "These conflicts have dramatically reduced national output and government revenue, increased external debt, and resulted in deaths of more than five million people from war and associated famine and disease."
# Predicted: "Perbedaan-perbedaan ini telah mengurangi produksi nasional dan pendapatan pemerintah, meningkatkan kewajiban eksternal, dan menyebabkan kematian lebih dari lima juta orang dari perang dan kemiskinan yang terkait."
# Reference: "Durasi peperangan yang cukup lama mengakibatkan kehancuran Italia dan penurunan populasi Italia dari 7 juta jiwa menjadi 2,5 juta jiwa sebagai akibat dari peperangan, kelaparan, dan wabah penyakit."
# BLEU Score: 0.3995
# --------------------------------------------------
# Input: Police and military forces pushed the remaining protesters back until they were confined to the Onentokon Treatment Centre and surrounded by the military.
# Predicted: Bersenang-senang: Polisi dan kader militer mempertahankan protester terakhir ke Pusat Terapi Onentokon dan diberikan oleh militer.
# Reference: Infantri dan unit pendukung lainnya menyerang sisi musuh (enemy flank) dalam rangka melengkapi hubungan dengan kelompok lainnya sekaligus mengepung musuh dan atau menguasai posisi strategis.
# BLEU Score: 0.1642
# --------------------------------------------------
# Input: "Allowing for 10% per annum depreciation, her book value at the time of the loss was £10,828 0s 2d."
# Predicted: "Dengan alokasi depreciasi 10% per tahun, nilai tabelan tertua pada saat kegagalan sebesar £10,828 0s 2d."
# Reference: Sementara Pemda Gianyar yang memiliki jatah 60 % sesuai MOU seharusnya menerima uang sekitar Rp 10.870.186.762.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: This timbre is mimicked and reproduced using the voice or rich harmonic producing instruments.
# Predicted: Timbang ini diimitir dan diproduksi dengan suara atau instrument yang menghasilkan harmoni berwarna-warni.
# Reference: Susu tersebut diasamkan dengan menggunakan rennet alami ataupun buatan.
# BLEU Score: 0.2417
# --------------------------------------------------
# Input: "Qin Zongquan, however, refused to abide by that decision."
# Predicted: "Qin Zongquan, tetapi, tidak menghormati perdecisi itu."
# Reference: Tentu saja Kyai Hasan tidak setuju dengan keputusan itu.
# BLEU Score: 0.2457
# --------------------------------------------------
# Input: He was cleared on both murder charges at his trial in December 1987.
# Predicted: Dia diberhentikan pada dua kasus pelanggaran ahli diadilah pada Desember 1987.
# Reference: Ia didakwa atas keterlibatan dalam Pembunuhan Desember pada tanggal 8 Desember 1982.
# BLEU Score: 0.3815
# --------------------------------------------------
# Input: "He led 1.000 soldiers to capture Castle Seokmun of Mohe, but the Mohe counter-attacked in the Sulcheon region of Baekje."
# Predicted: Dia menerka 1.000 peladun untuk mengambil Kerajaan Seokmun Mohe, tetapi keterusan Mohe terus berusaha di wilayah Sulcheon Baekje.
# Reference: "Ia memimpin 1,000 pasukan untuk merebut Kastil Seokmun di Mohe, namun suku Mohe membalas serangan tersebut di Sulcheon, wilayah Baekje."
# BLEU Score: 0.5220
# --------------------------------------------------
# Input: The fantasy game setting is based on medieval Europe.
# Predicted: Pembentukan setting fantasi permainan berbentuk pada Medelada Europa.
# Reference: Prinsip jure uxoris didasarkan pada prinsip feodal abad pertengahan Eropa.
# BLEU Score: 0.2577
# --------------------------------------------------
# Input: Development work was approved in 1986 and the first prototypes were completed by 1988.
# Predicted: Bangunan perkembangan dipergunakan pada tahun 1986 dan prototipe pertama selesai diperoleh pada tahun 1988.
# Reference: "Persiapan dimulai pada tahun 1986, dan edisi pertama diterbitkan pada 1988."
# BLEU Score: 0.4345
# --------------------------------------------------
# Input: "It is bordered by Overijssel to the south, Friesland to the west, Groningen to the north, and Germany (districts of Emsland and Bentheim, Lower Saxony) to the east."
# Predicted: "Dijunjung batasnya di bawah Overijssel selatan, Friesland barat, Groningen utara, dan Jerman (daerah Emsland dan Bentheim, Nedestan) di sebelah utara."
# Reference: "Provinsi ini berbatasan dengan Overijssel di selatan, Friesland di barat, Groningen di utara, dan Jerman (distrik Emsland dan Bentheim) di timur."
# BLEU Score: 0.6764
# --------------------------------------------------
# Input: "In some cases, the rondalla also sings while the performers dance to the music."
# Predicted: "Di beberapa kasus, rondalla juga melodi diambil bersama dengan performer yang melodi diantaranya tari pada musik."
# Reference: "Selain menari, para penari juga ikut bernyanyi kidng dengan diiringi musik gambelan batel."
# BLEU Score: 0.3100
# --------------------------------------------------
# Input: """Die Antwoord: 'Are we awful or the best thing in the universe?'""."
# Predicted: Bahasa Indonesia: "Apakah kita buruk atau sesuatu paling baik di dalam alam semesta?"
# Reference: "Ia bertanya, “Bisakah kita membuat sebuah mobil mewah terbaik di dunia?”"
# BLEU Score: 0.3089
# --------------------------------------------------
# Input: They examined residues that were left after dissolving crude platinum from the Ural Mountains in aqua regia.
# Predicted: Mereka memeriksa residu yang tersisa setelah menggoreng platinum kuat dari Gunung Ural di dengan aqua regia.
# Reference: Mereka meneliti residu yang ditinggalkan setelah melarutkan platina mentah dari Pegunungan Ural dalam air raja.
# BLEU Score: 0.5461
# --------------------------------------------------
# Input: "As a former Episcopal priest, Fr."
# Predicted: "Fr. seorang pengurus Episkopal lalu."
# Reference: "Bertindak sebagai Penahbis Utama adalah Uskup Agung Palembang, Mgr."
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "His heritage is widely appreciated and shared by Azerbaijan, Iran, Afghanistan and Tajikistan."
# Predicted: "Kehidupannya dipercaya dan diberikan oleh Azerbayjan, Iran, Afghanistan dan Tajikistan."
# Reference: "Kebudayaannya secara luas diapresiasikan dan terbagi di Azerbaijan, Iran, Afganistan dan Tajikistan."
# BLEU Score: 0.5932
# --------------------------------------------------
# Input: "Supplemented by civil statutes and regulations, it became the basis for later dynastic codes not only in China but elsewhere in East Asia."
# Predicted: "Dikembangkan oleh peraturan sivil dan regulasi, itu menjadi dasar bagi kode dynasiti selanjutnya tidak hanya di China tetapi juga di lapisan Asia Tengah."
# Reference: "Namun dengan hadir dan dijadikannnya standar sistem komunikasi seluler membuat sistem analog perlahan menghilang, tidak hanya di Indonesia, tetapi juga di Eropa."
# BLEU Score: 0.4401
# --------------------------------------------------
# Input: "In his Ecclesiastical History, Book IV, chapter 3, Eusebius records that: 1."
# Predicted: "Dalam Tragedia Eklesiastik IV, Kapitol III, Eusebius mengatakan: 1."
# Reference: "Dalam bukunya Ecclesiastical History, Buku IV, bab 3, Eusebius mencatat bahwa: 1."
# BLEU Score: 0.4365
# --------------------------------------------------
# Input: "There are also a few Ahmadiyya Muslims, though unrecognised by the country."
# Predicted: "Dia juga ada beberapa Muslim Ahmadiyah, tetapi tidak diperiksa oleh negara."
# Reference: "Ada juga komunitas kecil Ahmadiyah, meskipun belum diakui oleh negara."
# BLEU Score: 0.4812
# --------------------------------------------------
# Input: "He and the webcomic have developed a large fanbase, and shortly after graduating from college, he became a professional webcomic artist."
# Predicted: "Dua orang dan webkomik telah membangun fanbase besar, dan sekitar setelah menyurutkan dipergulat, dia menjadi artis webkomik profesional."
# ...
# BLEU Score: 0.6265
# --------------------------------------------------
# Input: List of magazines in Sweden David Riff (16 August 2007).
# Predicted: Sistem pusat magazines di Sverige David Riff (16 Agustus 2007).
# Reference: "Daftar surat kabar di California ^ MacMillan, Robert (16 Agustus 2008)."
# BLEU Score: 0.3139
# --------------------------------------------------
# Input: "In the People's Republic of China (PRC), house churches or family churches (Chinese: 家庭教会; pinyin: jiātíng jiàohuì) are Protestant assemblies that operate independently from the state-sanctioned Three-Self Patriotic Movement (TSPM) and China Christian Council (CCC), and came into existence due to the change in religious policy after the end of the Cultural Revolution in the early 1980s."
# Predicted: "Di Republik Rakyat Cina (PRC), kongregasi rumah tangga atau kongregasi keluarga (Cina: 家庭教会; pinyin: jiātíng jiàohuì) adalah pertemuan Protestan yang operasional melawan gerakan Tiga Sepenuhnya Patriotik (TSPM) dan Dewan Kristen Cina (CCC), dan terbentuk karena perubahan politik keagamaan setelah berakhirnya Revolusi Kemanjang pada awal abad ke-1980."
# Reference: "Di Tiongkok, gereja rumah atau gereja keluarga (Hanzi: 家庭教会; Pinyin: jiātíng jiàohuì) adalah persekutuan umat Kristen di Republik Rakyat Tiongkok yang berjalan secara independen dari Gerakan Patriotik Tiga Pendirian (TSPM) dan Dewan Kristen Tiongkok (CCC) yang diizinkan negara, dan muncul karena perubahan dalam kebijakan agama setelah berakhirnya Revolusi Kebudayaan pada awal tahun 1980-an."
# BLEU Score: 0.6142
# --------------------------------------------------
# Input: "In Artaxerxes' later years, Philip II of Macedon's power was increasing in Greece, where he tried to convince the Greeks to revolt against the Achaemenid Empire."
# Predicted: "Di tahun-tahun akhir Artaxerxes, kekuasaan Philip II Macedoni di Grecia meningkat, di mana ia berusaha mengajak Greeks untuk melawan Imperium Achemenid."
# Reference: "Pada tahun-tahun Artaxsaca, kekuasaan Filipus II dari Makedonia meningkat di Yunani, di mana ia mencoba meyakinkan orang-orang Yunani untuk memberontak melawan Akhemeniyah Persia."
# BLEU Score: 0.5125
# --------------------------------------------------
# Input: See also: Minimum bounding rectangle.
# Predicted: Pandang lanjut: Rotang minimum kawali.
# Reference: Tangerang: Panca Anugrah Sakti.
# BLEU Score: 0.0000
# --------------------------------------------------
# Input: "In April 1942, she took part in the Indian Ocean raid, striking the British naval bases at Colombo and Trincomalee on Ceylon, and sinking the Royal Navy aircraft carrier HMS Hermes and the heavy cruisers HMS Cornwall and Dorsetshire, also with the help of Shōkaku."
# Predicted: "Sepuluh Maret 1942, ia ikut bersiap dalam raid Laut India, memaksa pusat naval di Colombo dan Trincomalee di Ceylon, dan menghancurkan korsel HMS Hermes dan kruis kuat HMS Cornwall dan Dorsetshire, juga dengan bantuan Shōkaku."
# Reference: "Pada bulan April tahun 1942, ia mengambil bagian dalam serangan Samudera Hindia, mencolok pangkalan angkatan laut Inggris di Kolombo dan Trincomalee di Ceylon, dan menenggalamkan HMS Hermes dan kapal penjelajah berat HMS Cornwall dan Dorsetshire, juga dengan bantuan Shōkaku."
# BLEU Score: 0.5825
# --------------------------------------------------
# Input: "Since the distribution of political power is determined by power over production, or power over capital, it is no surprise that the bourgeois class uses their wealth to legitimatize and protect their property and consequent social relations."
# Predicted: "Dikarenakan pengaruh kontrol politik ditetapkan oleh kekuasaan pada produksi atau kekuasaan kapital, tidak fantastis bahwa kelas baugean menggunakan kekayaan mereka untuk mendukung dan melindungi harta dan hubungan sosial yang sampai."
# Reference: "Dalam pandangan laissez-faire, kewajiban negara bukanlah melakukan intervensi untuk menstabilkan distribusi kekayaan atau untuk menjadikan sebuah negara makmur untuk melindungi rakyatnya dari kemiskinan, melainkan bersandar pada sumbangan dan sistem pasar."
# BLEU Score: 0.3664
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 37
#      34 inputs = inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True, return_attention_mask=True).to(device)
#      36 # Generate the translation
# ---> 37 generate_ids = model.generate(inputs['input_ids'], max_length=500)
#      39 # Decode the output and extract the translation
#      40 output_text = tokenizer.decode(generate_ids[0], skip_special_tokens=True, clean_up_tokenization_spaces=False)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/transformers/generation/utils.py:2252, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2244     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2245         input_ids=input_ids,
#    2246         expand_size=generation_config.num_return_sequences,
#    2247         is_encoder_decoder=self.config.is_encoder_decoder,
#    2248         **model_kwargs,
#    2249     )
#    2251     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2252     result = self._sample(
#    2253         input_ids,
#    2254         logits_processor=prepared_logits_processor,
#    2255         stopping_criteria=prepared_stopping_criteria,
#    2256         generation_config=generation_config,
#    2257         synced_gpus=synced_gpus,
#    2258         streamer=streamer,
#    2259         **model_kwargs,
#    2260     )
#    2262 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2263     # 11. prepare beam search scorer
#    2264     beam_scorer = BeamSearchScorer(
#    2265         batch_size=batch_size,
#    2266         num_beams=generation_config.num_beams,
#    (...)
#    2271         max_length=generation_config.max_length,
#    2272     )
#
# File ~/nusax/.conda/lib/python3.11/site-packages/transformers/generation/utils.py:3254, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3252     is_prefill = False
#    3253 else:
# -> 3254     outputs = model_forward(**model_inputs, return_dict=True)
#    3256 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3257 model_kwargs = self._update_model_kwargs_for_generation(
#    3258     outputs,
#    3259     model_kwargs,
#    3260     is_encoder_decoder=self.config.is_encoder_decoder,
#    3261 )
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3.5-mini-instruct/af0dfb8029e8a74545d0736d30cb6b58d2f0f3f0/modeling_phi3.py:1243, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1240 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1242 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1243 outputs = self.model(
#    1244     input_ids=input_ids,
#    1245     attention_mask=attention_mask,
#    1246     position_ids=position_ids,
#    1247     past_key_values=past_key_values,
#    1248     inputs_embeds=inputs_embeds,
#    1249     use_cache=use_cache,
#    1250     output_attentions=output_attentions,
#    1251     output_hidden_states=output_hidden_states,
#    1252     return_dict=return_dict,
#    1253 )
#    1255 hidden_states = outputs[0]
#    1256 logits = self.lm_head(hidden_states)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3.5-mini-instruct/af0dfb8029e8a74545d0736d30cb6b58d2f0f3f0/modeling_phi3.py:1121, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1111     layer_outputs = self._gradient_checkpointing_func(
#    1112         decoder_layer.__call__,
#    1113         hidden_states,
#    (...)
#    1118         use_cache,
#    1119     )
#    1120 else:
# -> 1121     layer_outputs = decoder_layer(
#    1122         hidden_states,
#    1123         attention_mask=attention_mask,
#    1124         position_ids=position_ids,
#    1125         past_key_value=past_key_values,
#    1126         output_attentions=output_attentions,
#    1127         use_cache=use_cache,
#    1128     )
#    1130 hidden_states = layer_outputs[0]
#    1132 if use_cache:
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3.5-mini-instruct/af0dfb8029e8a74545d0736d30cb6b58d2f0f3f0/modeling_phi3.py:839, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     819 """
#     820 Args:
#     821     hidden_states (`torch.FloatTensor`):
#    (...)
#     834     past_key_value (`Tuple(torch.FloatTensor)`, *optional*): cached past key and value projection states
#     835 """
#     837 residual = hidden_states
# --> 839 hidden_states = self.input_layernorm(hidden_states)
#     841 # Self Attention
#     842 attn_outputs, self_attn_weights, present_key_value = self.self_attn(
#     843     hidden_states=hidden_states,
#     844     attention_mask=attention_mask,
#    (...)
#     848     use_cache=use_cache,
#     849 )
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/nusax/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164 def new_forward(module, *args, **kwargs):
# --> 165     args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     166     if module._hf_hook.no_grad:
#     167         with torch.no_grad():
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/hooks.py:355, in AlignDevicesHook.pre_forward(self, module, *args, **kwargs)
#     347         if (
#     348             value is not None
#     349             and self.tied_params_map is not None
#     350             and value.data_ptr() in self.tied_params_map
#     351             and self.execution_device not in self.tied_params_map[value.data_ptr()]
#     352         ):
#     353             self.tied_pointers_to_remove.add((value.data_ptr(), self.execution_device))
# --> 355         set_module_tensor_to_device(
#     356             module,
#     357             name,
#     358             self.execution_device,
#     359             value=value,
#     360             fp16_statistics=fp16_statistics,
#     361             tied_params_map=self.tied_params_map,
#     362         )
#     364 return send_to_device(args, self.execution_device), send_to_device(
#     365     kwargs, self.execution_device, skip_keys=self.skip_keys
#     366 )
#
# File ~/nusax/.conda/lib/python3.11/site-packages/accelerate/utils/modeling.py:329, in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     327             module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     328 elif isinstance(value, torch.Tensor):
# --> 329     new_value = value.to(device)
#     330 else:
#     331     new_value = torch.tensor(value, device=device)
#
# KeyboardInterrupt:
